# %%
import lightgbm as lgbm
import pandas as pd
import numpy as np
from pandas.api.types import is_numeric_dtype
import matplotlib
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import pickle
from sklearn import preprocessing
from sklearn.metrics import roc_curve
from scipy import stats
from scipy.stats import zscore
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold as SKF
from sklearn import metrics
# from fancyimpute import *

from utils import *
# %matplotlib inline

dtype = load_obj('dict_dtype')
my_dict = load_obj('my_dict')

# %%
data = pd.read_csv("atec_anti_fraud_train.csv",parse_dates=['date'], dtype = dtype)
test = pd.read_csv("atec_anti_fraud_test_b.csv",parse_dates=['date'], dtype = dtype)

data = process_dates(data, 'date')
test = process_dates(test, 'date')

# %%
# set the label of unlabeled data to 1
data.loc[data['label']==-1,'label'] = 1

# sort the data with date
data.sort_values('date',inplace=True)

print(data.shape)
# Out:
# (994731, 304)

# %% [markdown]
# **** Tune the parameter ****

# %%
# use the last 20% data as validation set
valid = data.iloc[data.shape[0]*4//5:,:]
data = data.iloc[:data.shape[0]*4//5,:]

print(data.shape[0] + valid.shape[0], data.shape[1])

test_id = test.id
cv_pred = np.zeros(len(test_id))
xgtest = xgb.DMatrix(test.drop(['id','date','Day'],axis=1).values)

valid_pred = np.zeros(valid.shape[0])
valid_id = valid.id
xgvalid = xgb.DMatrix(valid.drop(['id','date','label','Day'],axis=1).values, valid.label.values)
# Out:
# 994731 304

# %%
# set up the parameters
params = {'max_depth': 6, 'eta': 0.1, 'silent': 1, 'objective': 'binary:logistic'}
params['nthread'] = 4
params['eval_metric'] = ['logloss','auc']
params["scale_pos_weight"] = 2
params["subsample"] = 0.7
params["colsample_bytree "] = 0.8
num_rounds = 10000
early_stopping_rounds = 50

# set up the random seed for testing
params["seed"] = 6

xgtrain = xgb.DMatrix(data.drop(['id','date','label','Day'],axis=1).values, data.label.values)

evallist = [(xgtrain, 'train'), (xgvalid, 'valid')]
bst = xgb.train(params,
                xgtrain,
                num_rounds,
                evallist,
                # feval=my_score3,
                early_stopping_rounds=early_stopping_rounds)
# save the model
bst.save_model('model_log/single_1/0001.model')

cv_pred += bst.predict(xgtest)
valid_pred += bst.predict(xgvalid, ntree_limit=bst.best_iteration)

print('Final score of validation is {}'.format(my_score1(valid.label.values, valid_pred)))
pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0003.csv', index=False)
# Out:
# [0]	train-logloss:0.604044	train-auc:0.941349	valid-logloss:0.604034	valid-auc:0.947099
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 50 rounds.
# [1]	train-logloss:0.530796	train-auc:0.946747	valid-logloss:0.53089	valid-auc:0.951374
# [2]	train-logloss:0.469686	train-auc:0.947711	valid-logloss:0.469786	valid-auc:0.953093
# [3]	train-logloss:0.417964	train-auc:0.948178	valid-logloss:0.418133	valid-auc:0.953384
# [4]	train-logloss:0.373585	train-auc:0.955091	valid-logloss:0.373701	valid-auc:0.95957
# [5]	train-logloss:0.335449	train-auc:0.959321	valid-logloss:0.335654	valid-auc:0.961897
# [6]	train-logloss:0.302421	train-auc:0.960279	valid-logloss:0.302757	valid-auc:0.962137
# [7]	train-logloss:0.273406	train-auc:0.96028	valid-logloss:0.273724	valid-auc:0.962356
# [8]	train-logloss:0.248045	train-auc:0.96322	valid-logloss:0.248446	valid-auc:0.964191
# [9]	train-logloss:0.225845	train-auc:0.963805	valid-logloss:0.226363	valid-auc:0.964436
# [10]	train-logloss:0.206195	train-auc:0.964288	valid-logloss:0.206899	valid-auc:0.964613
# [11]	train-logloss:0.188789	train-auc:0.964732	valid-logloss:0.189639	valid-auc:0.964845
# [12]	train-logloss:0.173339	train-auc:0.965099	valid-logloss:0.174305	valid-auc:0.964943
# [13]	train-logloss:0.159659	train-auc:0.965243	valid-logloss:0.160676	valid-auc:0.965012
# [14]	train-logloss:0.147464	train-auc:0.965315	valid-logloss:0.14857	valid-auc:0.965036
# [15]	train-logloss:0.13649	train-auc:0.965523	valid-logloss:0.137681	valid-auc:0.965177
# [16]	train-logloss:0.126579	train-auc:0.965214	valid-logloss:0.12791	valid-auc:0.965201
# [17]	train-logloss:0.117868	train-auc:0.9653	valid-logloss:0.119358	valid-auc:0.965193
# [18]	train-logloss:0.109947	train-auc:0.96855	valid-logloss:0.111584	valid-auc:0.965679
# [19]	train-logloss:0.1029	train-auc:0.968796	valid-logloss:0.10469	valid-auc:0.966205
# [20]	train-logloss:0.096506	train-auc:0.971825	valid-logloss:0.098405	valid-auc:0.967214
# [21]	train-logloss:0.090785	train-auc:0.972643	valid-logloss:0.092784	valid-auc:0.96876
# [22]	train-logloss:0.085649	train-auc:0.972503	valid-logloss:0.087739	valid-auc:0.968858
# [23]	train-logloss:0.081029	train-auc:0.974464	valid-logloss:0.0833	valid-auc:0.969309
# [24]	train-logloss:0.076777	train-auc:0.974802	valid-logloss:0.079074	valid-auc:0.969624
# [25]	train-logloss:0.073037	train-auc:0.975014	valid-logloss:0.075484	valid-auc:0.969733
# [26]	train-logloss:0.06963	train-auc:0.975357	valid-logloss:0.072202	valid-auc:0.969891
# [27]	train-logloss:0.066496	train-auc:0.9756	valid-logloss:0.069169	valid-auc:0.970109
# [28]	train-logloss:0.063658	train-auc:0.976243	valid-logloss:0.066395	valid-auc:0.970457
# [29]	train-logloss:0.061159	train-auc:0.976636	valid-logloss:0.06395	valid-auc:0.971429
# [30]	train-logloss:0.058891	train-auc:0.976878	valid-logloss:0.061763	valid-auc:0.971447
# [31]	train-logloss:0.056796	train-auc:0.977183	valid-logloss:0.059765	valid-auc:0.971626
# [32]	train-logloss:0.054893	train-auc:0.977707	valid-logloss:0.057997	valid-auc:0.972057
# [33]	train-logloss:0.053152	train-auc:0.978101	valid-logloss:0.056407	valid-auc:0.972216
# [34]	train-logloss:0.051592	train-auc:0.978295	valid-logloss:0.05495	valid-auc:0.972264
# [35]	train-logloss:0.050231	train-auc:0.978575	valid-logloss:0.053696	valid-auc:0.972546
# [36]	train-logloss:0.048924	train-auc:0.97876	valid-logloss:0.05246	valid-auc:0.972637
# [37]	train-logloss:0.047744	train-auc:0.978999	valid-logloss:0.051369	valid-auc:0.972828
# [38]	train-logloss:0.046559	train-auc:0.979204	valid-logloss:0.050315	valid-auc:0.973005
# [39]	train-logloss:0.045619	train-auc:0.979356	valid-logloss:0.049482	valid-auc:0.973182
# [40]	train-logloss:0.04475	train-auc:0.979824	valid-logloss:0.048665	valid-auc:0.97334
# [41]	train-logloss:0.043923	train-auc:0.980109	valid-logloss:0.047904	valid-auc:0.973477
# [42]	train-logloss:0.043086	train-auc:0.980549	valid-logloss:0.047216	valid-auc:0.973871
# [43]	train-logloss:0.042421	train-auc:0.980867	valid-logloss:0.046672	valid-auc:0.974146
# [44]	train-logloss:0.041734	train-auc:0.981145	valid-logloss:0.046052	valid-auc:0.974472
# [45]	train-logloss:0.041127	train-auc:0.981366	valid-logloss:0.045512	valid-auc:0.974556
# [46]	train-logloss:0.040568	train-auc:0.981567	valid-logloss:0.045028	valid-auc:0.974636
# [47]	train-logloss:0.040104	train-auc:0.981767	valid-logloss:0.044586	valid-auc:0.974749
# [48]	train-logloss:0.039668	train-auc:0.982143	valid-logloss:0.044199	valid-auc:0.975182
# [49]	train-logloss:0.039262	train-auc:0.982469	valid-logloss:0.043918	valid-auc:0.97529
# [50]	train-logloss:0.038856	train-auc:0.982718	valid-logloss:0.043565	valid-auc:0.975577
# [51]	train-logloss:0.038502	train-auc:0.982929	valid-logloss:0.043255	valid-auc:0.975729
# [52]	train-logloss:0.038164	train-auc:0.983057	valid-logloss:0.042939	valid-auc:0.975955
# [53]	train-logloss:0.037815	train-auc:0.983267	valid-logloss:0.042641	valid-auc:0.9761
# [54]	train-logloss:0.037535	train-auc:0.983394	valid-logloss:0.04244	valid-auc:0.976126
# [55]	train-logloss:0.037287	train-auc:0.983626	valid-logloss:0.042219	valid-auc:0.976426
# [56]	train-logloss:0.037005	train-auc:0.983774	valid-logloss:0.041976	valid-auc:0.976497
# [57]	train-logloss:0.036775	train-auc:0.983924	valid-logloss:0.041801	valid-auc:0.976668
# [58]	train-logloss:0.036591	train-auc:0.984042	valid-logloss:0.041655	valid-auc:0.976822
# [59]	train-logloss:0.036384	train-auc:0.984172	valid-logloss:0.041529	valid-auc:0.976946
# [60]	train-logloss:0.036175	train-auc:0.984331	valid-logloss:0.041375	valid-auc:0.977044
# [61]	train-logloss:0.035987	train-auc:0.98447	valid-logloss:0.041214	valid-auc:0.97707
# [62]	train-logloss:0.035831	train-auc:0.984608	valid-logloss:0.041161	valid-auc:0.977054
# [63]	train-logloss:0.035665	train-auc:0.9847	valid-logloss:0.041007	valid-auc:0.977137
# [64]	train-logloss:0.035528	train-auc:0.984794	valid-logloss:0.040917	valid-auc:0.977185
# [65]	train-logloss:0.035374	train-auc:0.984917	valid-logloss:0.04082	valid-auc:0.977248
# [66]	train-logloss:0.035223	train-auc:0.985041	valid-logloss:0.040694	valid-auc:0.977281
# [67]	train-logloss:0.035121	train-auc:0.985157	valid-logloss:0.04062	valid-auc:0.977349
# [68]	train-logloss:0.034989	train-auc:0.985275	valid-logloss:0.040602	valid-auc:0.977354
# [69]	train-logloss:0.034844	train-auc:0.985437	valid-logloss:0.040571	valid-auc:0.977389
# [70]	train-logloss:0.034695	train-auc:0.985558	valid-logloss:0.040451	valid-auc:0.977438
# [71]	train-logloss:0.034617	train-auc:0.985609	valid-logloss:0.040389	valid-auc:0.977487
# [72]	train-logloss:0.034499	train-auc:0.98575	valid-logloss:0.040355	valid-auc:0.977562
# [73]	train-logloss:0.034396	train-auc:0.985842	valid-logloss:0.040294	valid-auc:0.977582
# [74]	train-logloss:0.034309	train-auc:0.98593	valid-logloss:0.040283	valid-auc:0.977552
# [75]	train-logloss:0.034221	train-auc:0.986021	valid-logloss:0.040256	valid-auc:0.977571
# [76]	train-logloss:0.034125	train-auc:0.986107	valid-logloss:0.04019	valid-auc:0.97762
# [77]	train-logloss:0.033991	train-auc:0.986184	valid-logloss:0.040142	valid-auc:0.977678
# [78]	train-logloss:0.033908	train-auc:0.986236	valid-logloss:0.040137	valid-auc:0.977673
# [79]	train-logloss:0.033813	train-auc:0.986325	valid-logloss:0.040083	valid-auc:0.977713
# [80]	train-logloss:0.033739	train-auc:0.986413	valid-logloss:0.040069	valid-auc:0.977736
# [81]	train-logloss:0.033655	train-auc:0.986496	valid-logloss:0.04005	valid-auc:0.977761
# [82]	train-logloss:0.0336	train-auc:0.986556	valid-logloss:0.040031	valid-auc:0.977767
# [83]	train-logloss:0.033505	train-auc:0.986681	valid-logloss:0.04005	valid-auc:0.977685
# [84]	train-logloss:0.03344	train-auc:0.986739	valid-logloss:0.040043	valid-auc:0.977702
# [85]	train-logloss:0.033337	train-auc:0.986841	valid-logloss:0.040053	valid-auc:0.977731
# [86]	train-logloss:0.033216	train-auc:0.986965	valid-logloss:0.039952	valid-auc:0.977796
# [87]	train-logloss:0.033164	train-auc:0.987011	valid-logloss:0.039917	valid-auc:0.97782
# [88]	train-logloss:0.033076	train-auc:0.987097	valid-logloss:0.039908	valid-auc:0.977803
# [89]	train-logloss:0.033048	train-auc:0.987132	valid-logloss:0.039924	valid-auc:0.977801
# [90]	train-logloss:0.032981	train-auc:0.987213	valid-logloss:0.039919	valid-auc:0.977828
# [91]	train-logloss:0.032938	train-auc:0.987238	valid-logloss:0.039915	valid-auc:0.977819
# [92]	train-logloss:0.032869	train-auc:0.987316	valid-logloss:0.03988	valid-auc:0.977827
# [93]	train-logloss:0.032799	train-auc:0.987392	valid-logloss:0.039832	valid-auc:0.97789
# [94]	train-logloss:0.032745	train-auc:0.987442	valid-logloss:0.039792	valid-auc:0.977925
# [95]	train-logloss:0.032699	train-auc:0.987471	valid-logloss:0.039781	valid-auc:0.977949
# [96]	train-logloss:0.032641	train-auc:0.987527	valid-logloss:0.039789	valid-auc:0.977924
# [97]	train-logloss:0.032567	train-auc:0.987596	valid-logloss:0.039782	valid-auc:0.97796
# [98]	train-logloss:0.032537	train-auc:0.987636	valid-logloss:0.039803	valid-auc:0.977909
# [99]	train-logloss:0.03245	train-auc:0.987708	valid-logloss:0.039768	valid-auc:0.978046
# [100]	train-logloss:0.032369	train-auc:0.987814	valid-logloss:0.039726	valid-auc:0.978116
# [101]	train-logloss:0.03234	train-auc:0.987858	valid-logloss:0.03971	valid-auc:0.978151
# [102]	train-logloss:0.032228	train-auc:0.987972	valid-logloss:0.039667	valid-auc:0.978143
# [103]	train-logloss:0.032174	train-auc:0.988016	valid-logloss:0.039646	valid-auc:0.978157
# [104]	train-logloss:0.032147	train-auc:0.988043	valid-logloss:0.039631	valid-auc:0.978179
# [105]	train-logloss:0.032098	train-auc:0.988085	valid-logloss:0.039615	valid-auc:0.978193
# [106]	train-logloss:0.03204	train-auc:0.988149	valid-logloss:0.039615	valid-auc:0.978188
# [107]	train-logloss:0.031982	train-auc:0.988199	valid-logloss:0.039599	valid-auc:0.978201
# [108]	train-logloss:0.031933	train-auc:0.988244	valid-logloss:0.039625	valid-auc:0.978194
# [109]	train-logloss:0.031843	train-auc:0.988321	valid-logloss:0.039597	valid-auc:0.978239
# [110]	train-logloss:0.031787	train-auc:0.988377	valid-logloss:0.039607	valid-auc:0.978228
# [111]	train-logloss:0.031745	train-auc:0.988423	valid-logloss:0.039592	valid-auc:0.978276
# [112]	train-logloss:0.031702	train-auc:0.988451	valid-logloss:0.039584	valid-auc:0.978299
# [113]	train-logloss:0.031671	train-auc:0.988492	valid-logloss:0.039581	valid-auc:0.978318
# [114]	train-logloss:0.031576	train-auc:0.98856	valid-logloss:0.039589	valid-auc:0.978302
# [115]	train-logloss:0.031512	train-auc:0.988607	valid-logloss:0.039572	valid-auc:0.978325
# [116]	train-logloss:0.031467	train-auc:0.988658	valid-logloss:0.039544	valid-auc:0.978335
# [117]	train-logloss:0.031394	train-auc:0.988748	valid-logloss:0.039539	valid-auc:0.978335
# [118]	train-logloss:0.031313	train-auc:0.988826	valid-logloss:0.039546	valid-auc:0.978316
# [119]	train-logloss:0.031298	train-auc:0.988851	valid-logloss:0.039547	valid-auc:0.978327
# [120]	train-logloss:0.031267	train-auc:0.988877	valid-logloss:0.039547	valid-auc:0.978324
# [121]	train-logloss:0.031247	train-auc:0.988921	valid-logloss:0.039554	valid-auc:0.978328
# [122]	train-logloss:0.031224	train-auc:0.988946	valid-logloss:0.039583	valid-auc:0.978316
# [123]	train-logloss:0.031175	train-auc:0.989006	valid-logloss:0.039582	valid-auc:0.97828
# [124]	train-logloss:0.031138	train-auc:0.989044	valid-logloss:0.039573	valid-auc:0.978308
# [125]	train-logloss:0.031082	train-auc:0.989099	valid-logloss:0.039542	valid-auc:0.978352
# [126]	train-logloss:0.031027	train-auc:0.989164	valid-logloss:0.03954	valid-auc:0.978393
# [127]	train-logloss:0.03097	train-auc:0.989242	valid-logloss:0.039514	valid-auc:0.978416
# [128]	train-logloss:0.030921	train-auc:0.989281	valid-logloss:0.039511	valid-auc:0.978417
# [129]	train-logloss:0.030876	train-auc:0.989333	valid-logloss:0.0395	valid-auc:0.978411
# [130]	train-logloss:0.03084	train-auc:0.989362	valid-logloss:0.039495	valid-auc:0.978423
# [131]	train-logloss:0.030792	train-auc:0.989399	valid-logloss:0.039488	valid-auc:0.978383
# [132]	train-logloss:0.03072	train-auc:0.989454	valid-logloss:0.039469	valid-auc:0.978378
# [133]	train-logloss:0.030683	train-auc:0.989492	valid-logloss:0.039456	valid-auc:0.978377
# [134]	train-logloss:0.030657	train-auc:0.98952	valid-logloss:0.039471	valid-auc:0.978383
# [135]	train-logloss:0.030596	train-auc:0.989569	valid-logloss:0.039487	valid-auc:0.978325
# [136]	train-logloss:0.030555	train-auc:0.989606	valid-logloss:0.039505	valid-auc:0.978295
# [137]	train-logloss:0.030522	train-auc:0.989651	valid-logloss:0.039513	valid-auc:0.978306
# [138]	train-logloss:0.030472	train-auc:0.989684	valid-logloss:0.039486	valid-auc:0.978321
# [139]	train-logloss:0.030431	train-auc:0.989726	valid-logloss:0.039512	valid-auc:0.978239
# [140]	train-logloss:0.030383	train-auc:0.989753	valid-logloss:0.039497	valid-auc:0.978271
# [141]	train-logloss:0.030319	train-auc:0.98979	valid-logloss:0.03947	valid-auc:0.978252
# [142]	train-logloss:0.030262	train-auc:0.98984	valid-logloss:0.039462	valid-auc:0.978278
# [143]	train-logloss:0.030211	train-auc:0.98989	valid-logloss:0.03948	valid-auc:0.978265
# [144]	train-logloss:0.030153	train-auc:0.989948	valid-logloss:0.039405	valid-auc:0.978378
# [145]	train-logloss:0.030105	train-auc:0.989976	valid-logloss:0.039413	valid-auc:0.978381
# [146]	train-logloss:0.030074	train-auc:0.989999	valid-logloss:0.039404	valid-auc:0.978384
# [147]	train-logloss:0.030011	train-auc:0.990066	valid-logloss:0.039406	valid-auc:0.978409
# [148]	train-logloss:0.029971	train-auc:0.99011	valid-logloss:0.03942	valid-auc:0.978374
# [149]	train-logloss:0.029923	train-auc:0.990144	valid-logloss:0.039438	valid-auc:0.978358
# [150]	train-logloss:0.029884	train-auc:0.990182	valid-logloss:0.039429	valid-auc:0.978375
# [151]	train-logloss:0.029855	train-auc:0.990205	valid-logloss:0.039424	valid-auc:0.978357
# [152]	train-logloss:0.029849	train-auc:0.990216	valid-logloss:0.039252	valid-auc:0.97843
# [153]	train-logloss:0.029827	train-auc:0.990234	valid-logloss:0.039249	valid-auc:0.978435
# [154]	train-logloss:0.029789	train-auc:0.990263	valid-logloss:0.039236	valid-auc:0.978439
# [155]	train-logloss:0.029729	train-auc:0.990307	valid-logloss:0.039214	valid-auc:0.978471
# [156]	train-logloss:0.029691	train-auc:0.990339	valid-logloss:0.03923	valid-auc:0.978432
# [157]	train-logloss:0.029639	train-auc:0.990379	valid-logloss:0.039216	valid-auc:0.978466
# [158]	train-logloss:0.029583	train-auc:0.990426	valid-logloss:0.039219	valid-auc:0.978453
# [159]	train-logloss:0.029532	train-auc:0.990473	valid-logloss:0.039214	valid-auc:0.978429
# [160]	train-logloss:0.029487	train-auc:0.990514	valid-logloss:0.039208	valid-auc:0.978447
# [161]	train-logloss:0.029458	train-auc:0.990532	valid-logloss:0.039189	valid-auc:0.978452
# [162]	train-logloss:0.029389	train-auc:0.990586	valid-logloss:0.039163	valid-auc:0.978462
# [163]	train-logloss:0.029331	train-auc:0.990649	valid-logloss:0.039145	valid-auc:0.978507
# [164]	train-logloss:0.029299	train-auc:0.990688	valid-logloss:0.03912	valid-auc:0.978528
# [165]	train-logloss:0.02925	train-auc:0.990723	valid-logloss:0.039141	valid-auc:0.978547
# [166]	train-logloss:0.02921	train-auc:0.990753	valid-logloss:0.039139	valid-auc:0.978543
# [167]	train-logloss:0.029159	train-auc:0.990815	valid-logloss:0.039123	valid-auc:0.978562
# [168]	train-logloss:0.029099	train-auc:0.990875	valid-logloss:0.039125	valid-auc:0.978549
# [169]	train-logloss:0.029053	train-auc:0.990913	valid-logloss:0.039107	valid-auc:0.978577
# [170]	train-logloss:0.029013	train-auc:0.990942	valid-logloss:0.039068	valid-auc:0.978612
# [171]	train-logloss:0.028985	train-auc:0.990968	valid-logloss:0.039057	valid-auc:0.978626
# [172]	train-logloss:0.028916	train-auc:0.99103	valid-logloss:0.039048	valid-auc:0.978612
# [173]	train-logloss:0.028892	train-auc:0.991059	valid-logloss:0.039056	valid-auc:0.978608
# [174]	train-logloss:0.028837	train-auc:0.991088	valid-logloss:0.039051	valid-auc:0.978602
# [175]	train-logloss:0.028788	train-auc:0.991141	valid-logloss:0.039045	valid-auc:0.978566
# [176]	train-logloss:0.028745	train-auc:0.991175	valid-logloss:0.039001	valid-auc:0.978612
# [177]	train-logloss:0.028734	train-auc:0.991183	valid-logloss:0.03901	valid-auc:0.978608
# [178]	train-logloss:0.02868	train-auc:0.991238	valid-logloss:0.038979	valid-auc:0.978656
# [179]	train-logloss:0.028635	train-auc:0.991282	valid-logloss:0.038953	valid-auc:0.97866
# [180]	train-logloss:0.028613	train-auc:0.991302	valid-logloss:0.038951	valid-auc:0.978632
# [181]	train-logloss:0.028573	train-auc:0.991334	valid-logloss:0.038957	valid-auc:0.978635
# [182]	train-logloss:0.028524	train-auc:0.991362	valid-logloss:0.038933	valid-auc:0.978639
# [183]	train-logloss:0.028487	train-auc:0.991391	valid-logloss:0.038929	valid-auc:0.978644
# [184]	train-logloss:0.028445	train-auc:0.991421	valid-logloss:0.038935	valid-auc:0.978646
# [185]	train-logloss:0.02842	train-auc:0.991435	valid-logloss:0.038937	valid-auc:0.978625
# [186]	train-logloss:0.028382	train-auc:0.991464	valid-logloss:0.038928	valid-auc:0.978628
# [187]	train-logloss:0.028305	train-auc:0.991513	valid-logloss:0.038941	valid-auc:0.978575
# [188]	train-logloss:0.028269	train-auc:0.991541	valid-logloss:0.038905	valid-auc:0.978606
# [189]	train-logloss:0.028224	train-auc:0.991589	valid-logloss:0.038898	valid-auc:0.978633
# [190]	train-logloss:0.028175	train-auc:0.991644	valid-logloss:0.038886	valid-auc:0.978672
# [191]	train-logloss:0.028157	train-auc:0.991666	valid-logloss:0.038892	valid-auc:0.978665
# [192]	train-logloss:0.028116	train-auc:0.991687	valid-logloss:0.03887	valid-auc:0.978702
# [193]	train-logloss:0.028077	train-auc:0.991715	valid-logloss:0.038858	valid-auc:0.978698
# [194]	train-logloss:0.028029	train-auc:0.991759	valid-logloss:0.03887	valid-auc:0.978698
# [195]	train-logloss:0.028003	train-auc:0.991783	valid-logloss:0.038846	valid-auc:0.978709
# [196]	train-logloss:0.027946	train-auc:0.991824	valid-logloss:0.03886	valid-auc:0.978646
# [197]	train-logloss:0.027889	train-auc:0.991869	valid-logloss:0.038859	valid-auc:0.97866
# [198]	train-logloss:0.027818	train-auc:0.991938	valid-logloss:0.038842	valid-auc:0.978689
# [199]	train-logloss:0.027786	train-auc:0.991962	valid-logloss:0.038848	valid-auc:0.978705
# [200]	train-logloss:0.027743	train-auc:0.991996	valid-logloss:0.038846	valid-auc:0.978714
# [201]	train-logloss:0.027703	train-auc:0.992025	valid-logloss:0.038835	valid-auc:0.978747
# [202]	train-logloss:0.027671	train-auc:0.992058	valid-logloss:0.038855	valid-auc:0.97872
# [203]	train-logloss:0.027633	train-auc:0.992084	valid-logloss:0.038871	valid-auc:0.9787
# [204]	train-logloss:0.027589	train-auc:0.992124	valid-logloss:0.038884	valid-auc:0.97871
# [205]	train-logloss:0.02755	train-auc:0.992159	valid-logloss:0.038892	valid-auc:0.978709
# [206]	train-logloss:0.027522	train-auc:0.992172	valid-logloss:0.038894	valid-auc:0.978698
# [207]	train-logloss:0.027498	train-auc:0.992188	valid-logloss:0.038903	valid-auc:0.978697
# [208]	train-logloss:0.027472	train-auc:0.992207	valid-logloss:0.03889	valid-auc:0.978702
# [209]	train-logloss:0.02746	train-auc:0.992219	valid-logloss:0.038896	valid-auc:0.978696
# [210]	train-logloss:0.027421	train-auc:0.992246	valid-logloss:0.038891	valid-auc:0.978698
# [211]	train-logloss:0.02738	train-auc:0.992275	valid-logloss:0.038889	valid-auc:0.978702
# [212]	train-logloss:0.027336	train-auc:0.992303	valid-logloss:0.038881	valid-auc:0.978695
# [213]	train-logloss:0.027304	train-auc:0.992338	valid-logloss:0.038885	valid-auc:0.978692
# [214]	train-logloss:0.02728	train-auc:0.992362	valid-logloss:0.038886	valid-auc:0.978711
# [215]	train-logloss:0.027236	train-auc:0.992393	valid-logloss:0.038882	valid-auc:0.978718
# [216]	train-logloss:0.027187	train-auc:0.992437	valid-logloss:0.038893	valid-auc:0.978728
# [217]	train-logloss:0.027169	train-auc:0.992445	valid-logloss:0.038888	valid-auc:0.978735
# [218]	train-logloss:0.027123	train-auc:0.992492	valid-logloss:0.038891	valid-auc:0.978704
# [219]	train-logloss:0.027071	train-auc:0.992539	valid-logloss:0.038905	valid-auc:0.978696
# [220]	train-logloss:0.027043	train-auc:0.992575	valid-logloss:0.038918	valid-auc:0.978659
# [221]	train-logloss:0.027041	train-auc:0.992578	valid-logloss:0.038934	valid-auc:0.978657
# [222]	train-logloss:0.026999	train-auc:0.992602	valid-logloss:0.038921	valid-auc:0.978667
# [223]	train-logloss:0.026979	train-auc:0.992618	valid-logloss:0.038927	valid-auc:0.978643
# [224]	train-logloss:0.026917	train-auc:0.992658	valid-logloss:0.038905	valid-auc:0.978698
# [225]	train-logloss:0.026872	train-auc:0.99269	valid-logloss:0.0389	valid-auc:0.978696
# [226]	train-logloss:0.026841	train-auc:0.992726	valid-logloss:0.038874	valid-auc:0.97878
# [227]	train-logloss:0.026812	train-auc:0.992749	valid-logloss:0.038877	valid-auc:0.978795
# [228]	train-logloss:0.02678	train-auc:0.992781	valid-logloss:0.038862	valid-auc:0.978824
# [229]	train-logloss:0.026767	train-auc:0.992792	valid-logloss:0.038892	valid-auc:0.978801
# [230]	train-logloss:0.026741	train-auc:0.992817	valid-logloss:0.038882	valid-auc:0.978809
# [231]	train-logloss:0.026693	train-auc:0.992845	valid-logloss:0.038874	valid-auc:0.978808
# [232]	train-logloss:0.026672	train-auc:0.992862	valid-logloss:0.038872	valid-auc:0.978833
# [233]	train-logloss:0.026654	train-auc:0.992872	valid-logloss:0.038871	valid-auc:0.97883
# [234]	train-logloss:0.026628	train-auc:0.992894	valid-logloss:0.038862	valid-auc:0.978859
# [235]	train-logloss:0.026589	train-auc:0.992915	valid-logloss:0.038857	valid-auc:0.978846
# [236]	train-logloss:0.026564	train-auc:0.992935	valid-logloss:0.038862	valid-auc:0.978842
# [237]	train-logloss:0.026531	train-auc:0.992955	valid-logloss:0.038848	valid-auc:0.978862
# [238]	train-logloss:0.026478	train-auc:0.992992	valid-logloss:0.038879	valid-auc:0.978831
# [239]	train-logloss:0.026452	train-auc:0.993017	valid-logloss:0.038875	valid-auc:0.978836
# [240]	train-logloss:0.026442	train-auc:0.993026	valid-logloss:0.038876	valid-auc:0.978837
# [241]	train-logloss:0.02641	train-auc:0.993057	valid-logloss:0.038881	valid-auc:0.978844
# [242]	train-logloss:0.026397	train-auc:0.993066	valid-logloss:0.038885	valid-auc:0.978854
# [243]	train-logloss:0.026353	train-auc:0.993096	valid-logloss:0.038899	valid-auc:0.978857
# [244]	train-logloss:0.026326	train-auc:0.993119	valid-logloss:0.038923	valid-auc:0.978841
# [245]	train-logloss:0.026311	train-auc:0.993129	valid-logloss:0.038928	valid-auc:0.978839
# [246]	train-logloss:0.02628	train-auc:0.993159	valid-logloss:0.038816	valid-auc:0.978916
# [247]	train-logloss:0.026248	train-auc:0.993177	valid-logloss:0.038819	valid-auc:0.978919
# [248]	train-logloss:0.026211	train-auc:0.993205	valid-logloss:0.038819	valid-auc:0.978926
# [249]	train-logloss:0.02617	train-auc:0.993231	valid-logloss:0.03881	valid-auc:0.978896
# [250]	train-logloss:0.026131	train-auc:0.993261	valid-logloss:0.038809	valid-auc:0.978906
# [251]	train-logloss:0.026124	train-auc:0.993268	valid-logloss:0.038814	valid-auc:0.978903
# [252]	train-logloss:0.02607	train-auc:0.993295	valid-logloss:0.038795	valid-auc:0.978927
# [253]	train-logloss:0.026015	train-auc:0.993328	valid-logloss:0.038794	valid-auc:0.978941
# [254]	train-logloss:0.025974	train-auc:0.993348	valid-logloss:0.038764	valid-auc:0.978958
# [255]	train-logloss:0.025925	train-auc:0.993384	valid-logloss:0.038761	valid-auc:0.978941
# [256]	train-logloss:0.025889	train-auc:0.99342	valid-logloss:0.038757	valid-auc:0.978952
# [257]	train-logloss:0.025852	train-auc:0.993437	valid-logloss:0.038741	valid-auc:0.978977
# [258]	train-logloss:0.025836	train-auc:0.993448	valid-logloss:0.03875	valid-auc:0.97897
# [259]	train-logloss:0.025826	train-auc:0.993456	valid-logloss:0.038752	valid-auc:0.978974
# [260]	train-logloss:0.0258	train-auc:0.99347	valid-logloss:0.03875	valid-auc:0.978976
# [261]	train-logloss:0.025759	train-auc:0.993505	valid-logloss:0.038757	valid-auc:0.978958
# [262]	train-logloss:0.02575	train-auc:0.993512	valid-logloss:0.038755	valid-auc:0.978962
# [263]	train-logloss:0.025711	train-auc:0.993536	valid-logloss:0.03875	valid-auc:0.978961
# [264]	train-logloss:0.025665	train-auc:0.993568	valid-logloss:0.038745	valid-auc:0.978999
# [265]	train-logloss:0.025629	train-auc:0.993589	valid-logloss:0.038755	valid-auc:0.978982
# [266]	train-logloss:0.025595	train-auc:0.993618	valid-logloss:0.038775	valid-auc:0.978907
# [267]	train-logloss:0.025586	train-auc:0.993625	valid-logloss:0.038774	valid-auc:0.978906
# [268]	train-logloss:0.025561	train-auc:0.993641	valid-logloss:0.038771	valid-auc:0.978909
# [269]	train-logloss:0.025532	train-auc:0.99366	valid-logloss:0.038771	valid-auc:0.978918
# [270]	train-logloss:0.025494	train-auc:0.993681	valid-logloss:0.038763	valid-auc:0.978908
# [271]	train-logloss:0.025479	train-auc:0.993695	valid-logloss:0.038775	valid-auc:0.978917
# [272]	train-logloss:0.025436	train-auc:0.993721	valid-logloss:0.038782	valid-auc:0.978888
# [273]	train-logloss:0.02539	train-auc:0.993766	valid-logloss:0.038776	valid-auc:0.978907
# [274]	train-logloss:0.025357	train-auc:0.993791	valid-logloss:0.038759	valid-auc:0.978917
# [275]	train-logloss:0.025353	train-auc:0.993795	valid-logloss:0.038762	valid-auc:0.9789
# [276]	train-logloss:0.025331	train-auc:0.993803	valid-logloss:0.038771	valid-auc:0.9789
# [277]	train-logloss:0.025298	train-auc:0.993822	valid-logloss:0.03878	valid-auc:0.978888
# [278]	train-logloss:0.025264	train-auc:0.993841	valid-logloss:0.038784	valid-auc:0.978867
# [279]	train-logloss:0.025242	train-auc:0.993852	valid-logloss:0.038789	valid-auc:0.978887
# [280]	train-logloss:0.025213	train-auc:0.993872	valid-logloss:0.038768	valid-auc:0.978896
# [281]	train-logloss:0.025173	train-auc:0.993888	valid-logloss:0.038765	valid-auc:0.978903
# [282]	train-logloss:0.025148	train-auc:0.993907	valid-logloss:0.038781	valid-auc:0.978891
# [283]	train-logloss:0.02514	train-auc:0.993919	valid-logloss:0.038788	valid-auc:0.978876
# [284]	train-logloss:0.025102	train-auc:0.993943	valid-logloss:0.038759	valid-auc:0.978862
# [285]	train-logloss:0.025062	train-auc:0.993962	valid-logloss:0.038767	valid-auc:0.978871
# [286]	train-logloss:0.025013	train-auc:0.994016	valid-logloss:0.038732	valid-auc:0.978898
# [287]	train-logloss:0.024981	train-auc:0.994036	valid-logloss:0.038734	valid-auc:0.978886
# [288]	train-logloss:0.024947	train-auc:0.994059	valid-logloss:0.03876	valid-auc:0.978887
# [289]	train-logloss:0.024916	train-auc:0.994076	valid-logloss:0.038765	valid-auc:0.978878
# [290]	train-logloss:0.024895	train-auc:0.994093	valid-logloss:0.038773	valid-auc:0.978872
# [291]	train-logloss:0.024853	train-auc:0.994119	valid-logloss:0.038794	valid-auc:0.978862
# [292]	train-logloss:0.024807	train-auc:0.994146	valid-logloss:0.038792	valid-auc:0.978869
# [293]	train-logloss:0.024774	train-auc:0.99416	valid-logloss:0.038789	valid-auc:0.97888
# [294]	train-logloss:0.024745	train-auc:0.994176	valid-logloss:0.038782	valid-auc:0.978885
# [295]	train-logloss:0.024721	train-auc:0.994195	valid-logloss:0.038786	valid-auc:0.978859
# [296]	train-logloss:0.024689	train-auc:0.994225	valid-logloss:0.03879	valid-auc:0.978857
# [297]	train-logloss:0.024663	train-auc:0.994236	valid-logloss:0.038777	valid-auc:0.978869
# [298]	train-logloss:0.02464	train-auc:0.994249	valid-logloss:0.038782	valid-auc:0.978872
# [299]	train-logloss:0.024618	train-auc:0.994263	valid-logloss:0.03879	valid-auc:0.978859
# [300]	train-logloss:0.02459	train-auc:0.99429	valid-logloss:0.038783	valid-auc:0.978886
# [301]	train-logloss:0.024569	train-auc:0.994315	valid-logloss:0.0388	valid-auc:0.978876
# [302]	train-logloss:0.024552	train-auc:0.994323	valid-logloss:0.038792	valid-auc:0.97889
# [303]	train-logloss:0.024536	train-auc:0.99434	valid-logloss:0.038813	valid-auc:0.978846
# [304]	train-logloss:0.024499	train-auc:0.994362	valid-logloss:0.038801	valid-auc:0.978867
# [305]	train-logloss:0.02448	train-auc:0.994372	valid-logloss:0.038795	valid-auc:0.978876
# [306]	train-logloss:0.024456	train-auc:0.994385	valid-logloss:0.038796	valid-auc:0.978872
# [307]	train-logloss:0.024407	train-auc:0.99442	valid-logloss:0.038781	valid-auc:0.978867
# [308]	train-logloss:0.024375	train-auc:0.99444	valid-logloss:0.0388	valid-auc:0.978855
# [309]	train-logloss:0.024336	train-auc:0.994473	valid-logloss:0.038796	valid-auc:0.978835
# [310]	train-logloss:0.024318	train-auc:0.994481	valid-logloss:0.038803	valid-auc:0.978859
# [311]	train-logloss:0.024281	train-auc:0.994502	valid-logloss:0.038792	valid-auc:0.978873
# [312]	train-logloss:0.024253	train-auc:0.994523	valid-logloss:0.038841	valid-auc:0.978849
# [313]	train-logloss:0.024221	train-auc:0.994544	valid-logloss:0.038833	valid-auc:0.978848
# [314]	train-logloss:0.024186	train-auc:0.994566	valid-logloss:0.038825	valid-auc:0.97884
# Stopping. Best iteration:
# [264]	train-logloss:0.025665	train-auc:0.993568	valid-logloss:0.038745	valid-auc:0.978999
#
# Final score of validation is 0.4098067915690866

# %%
for i in range(0,9,2):
    day_target = list(set([tmp+1 for tmp in range(31)])-\
                      set([10*tmp+i+1 if 10*tmp+i+1<=31 else 10*tmp+i-9 for tmp in range(4)]+\
                          [10*tmp+i+2 if 10*tmp+i+2<=31 else 10*tmp+i-8 for tmp in range(4)]))
    # print(day_target)
    train = data[data.Day.isin(day_target)]
    
    # set up the parameters
    params = {'max_depth': 6, 'eta': 0.1, 'silent': 1, 'objective': 'binary:logistic'}
    params['nthread'] = 4
    params['eval_metric'] = ['logloss','auc']
    params["scale_pos_weight"] = 2
    params["subsample"] = 0.7
    params["colsample_bytree "] = 0.8
    num_rounds = 10000
    early_stopping_rounds = 50

    # set up the random seed for testing
    params["seed"] = 6
    
    xgtrain = xgb.DMatrix(train.drop(['id','date','label','Day'],axis=1).values, train.label.values)
    
    evallist = [(xgtrain, 'train'), (xgvalid, 'valid')]
    bst = xgb.train(params,
                    xgtrain,
                    num_rounds,
                    evallist,
                    #feval=my_score3,
                    early_stopping_rounds=early_stopping_rounds)
    # save the model
    bst.save_model('model_log/multi_2/part_{}.model'.format(i//2))
    
    valid_pred += bst.predict(xgvalid, ntree_limit=bst.best_iteration)
    cv_pred += bst.predict(xgtest, ntree_limit=bst.best_iteration)

valid_pred /= 5    
cv_pred /= 5

print('Final score of validation is {}'.format(my_score1(valid.label.values, valid_pred)))

pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0002.csv', index=False)

# %% [markdown]
# **** Predict on the testset ****

# %%
test_id = test.id
cv_pred = np.zeros(len(test_id))
xgtest = xgb.DMatrix(test.drop(['id','date','Day'],axis=1).values)

# %%
tuned_rounds = [226, 327, 136, 418, 289]
for i in range(0,9,2):
    day_target = list(set([tmp+1 for tmp in range(31)])-\
                      set([10*tmp+i+1 if 10*tmp+i+1<=31 else 10*tmp+i-9 for tmp in range(4)]+\
                          [10*tmp+i+2 if 10*tmp+i+2<=31 else 10*tmp+i-8 for tmp in range(4)]))
    # print(day_target)
    train = data[data.Day.isin(day_target)]
    
    # set up the parameters
    params = {'max_depth': 6, 'eta': 0.1, 'silent': 1, 'objective': 'binary:logistic'}
    params['nthread'] = 4
    params['eval_metric'] = ['logloss','auc']
    params["scale_pos_weight"] = 2
    params["subsample"] = 0.7
    params["colsample_bytree "] = 0.8
    num_rounds = tuned_rounds[i//2]
    early_stopping_rounds = 50

    # set up the random seed for testing
    params["seed"] = 6
    
    xgtrain = xgb.DMatrix(train.drop(['id','date','label','Day'],axis=1).values, train.label.values)
    
    evallist = [(xgtrain, 'train')]
    bst = xgb.train(params,
                    xgtrain,
                    num_rounds,
                    evallist,
                    #feval=my_score3,
                    early_stopping_rounds=early_stopping_rounds)
    # save the model
    bst.save_model('model_log/multi_3/part_{}.model'.format(i//2))
    
    cv_pred += bst.predict(xgtest, ntree_limit=bst.best_iteration)

cv_pred /= 5
pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0002.csv', index=False)
