# %%
import lightgbm as lgbm
import pandas as pd
import numpy as np
from pandas.api.types import is_numeric_dtype
import matplotlib
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import pickle
from sklearn import preprocessing
from sklearn.metrics import roc_curve
from scipy import stats
from scipy.stats import zscore
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold as SKF
from sklearn import metrics
# from fancyimpute import *

from utils import *
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

dtype = load_obj('dict_dtype')
my_dict = load_obj('my_dict')

# %%
data = pd.read_csv("atec_anti_fraud_train.csv",parse_dates=['date'], dtype = dtype)
test = pd.read_csv("atec_anti_fraud_test_b.csv",parse_dates=['date'], dtype = dtype)

data = process_dates(data, 'date')
test = process_dates(test, 'date')

# %%
# set the label of unlabeled data to 1
data.loc[data['label']==-1,'label'] = 1

#data = data[data['label']!=-1]

# sort the data with date
data.sort_values('date',inplace=True)

print(data.shape)
# Out:
# (994731, 304)

# %% [markdown]
# ### xgboost without 5-fold (local: 0.409, lb: 0.309)

# %%
# set up the parameters
params = {'max_depth': 6, 'eta': 0.1, 'silent': 1, 'objective': 'binary:logistic'}
params['nthread'] = 4
params['eval_metric'] = ['logloss','auc']
params["scale_pos_weight"] = 2
params["subsample"] = 0.7
params["colsample_bytree "] = 0.8
num_rounds = 10000
early_stopping_rounds = 50

# set up the random seed for testing
params["seed"] = 6

xgtrain = xgb.DMatrix(data.drop(['id','date','label','Day'],axis=1).values, data.label.values)

evallist = [(xgtrain, 'train'), (xgvalid, 'valid')]
bst = xgb.train(params,
                xgtrain,
                num_rounds,
                evallist,
                # feval=my_score3,
                early_stopping_rounds=early_stopping_rounds)
# save the model
bst.save_model('model_log/single_1/0001.model')

cv_pred += bst.predict(xgtest)
valid_pred += bst.predict(xgvalid, ntree_limit=bst.best_iteration)

print('Final score of validation is {}'.format(my_score1(valid.label.values, valid_pred)))
pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0003.csv', index=False)

# %% [markdown]
# ### 5-fold time dependent cv train on first 80% data xgboost (local:0.42, lb:0.3383)

# %%
# use the last 20% data as validation set
valid = data.iloc[data.shape[0]*4//5:,:]
data = data.iloc[:data.shape[0]*4//5,:]

print(data.shape[0] + valid.shape[0], data.shape[1])

test_id = test.id
cv_pred = np.zeros(len(test_id))
xgtest = xgb.DMatrix(test.drop(['id','date','Day'],axis=1).values)

valid_pred = np.zeros(valid.shape[0])
valid_id = valid.id
xgvalid = xgb.DMatrix(valid.drop(['id','date','label','Day'],axis=1).values, valid.label.values)

# %%
for i in range(0,9,2):
    day_target = list(set([tmp+1 for tmp in range(31)])-\
                      set([10*tmp+i+1 if 10*tmp+i+1<=31 else 10*tmp+i-9 for tmp in range(4)]+\
                          [10*tmp+i+2 if 10*tmp+i+2<=31 else 10*tmp+i-8 for tmp in range(4)]))
    # print(day_target)
    train = data[data.Day.isin(day_target)]
    
    # set up the parameters
    params = {'max_depth': 6, 'eta': 0.1, 'silent': 1, 'objective': 'binary:logistic'}
    params['nthread'] = 4
    params['eval_metric'] = ['logloss','auc']
    params["scale_pos_weight"] = 2
    params["subsample"] = 0.7
    params["colsample_bytree "] = 0.8
    num_rounds = 10000
    early_stopping_rounds = 50

    # set up the random seed for testing
    params["seed"] = 6
    
    xgtrain = xgb.DMatrix(train.drop(['id','date','label','Day'],axis=1).values, train.label.values)
    
    evallist = [(xgtrain, 'train'), (xgvalid, 'valid')]
    bst = xgb.train(params,
                    xgtrain,
                    num_rounds,
                    evallist,
                    #feval=my_score3,
                    early_stopping_rounds=early_stopping_rounds)
    # save the model
    bst.save_model('model_log/multi_2/part_{}.model'.format(i//2))
    
    valid_pred += bst.predict(xgvalid, ntree_limit=bst.best_iteration)
    cv_pred += bst.predict(xgtest, ntree_limit=bst.best_iteration)

valid_pred /= 5    
cv_pred /= 5

print('Final score of validation is {}'.format(my_score1(valid.label.values, valid_pred)))

pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0002.csv', index=False)

# %% [markdown]
# ### oversampling + 5-fold time dependent cv train on first 80% data xgboost (local: 0.418)

# %%
# use the last 20% data as validation set
valid = data.iloc[data.shape[0]*4//5:,:]
data = data.iloc[:data.shape[0]*4//5,:]
# positive = data[data['label']==1]
# data = data[data['label']==0]

print(data.shape[0] + valid.shape[0], data.shape[1])

test_id = test.id
cv_pred = np.zeros(len(test_id))
xgtest = xgb.DMatrix(test.drop(['id','date','Day'],axis=1).values)

valid_pred = np.zeros(valid.shape[0])
valid_id = valid.id
xgvalid = xgb.DMatrix(valid.drop(['id','date','label','Day'],axis=1).values, valid.label.values)

# %%
for i in range(0,9,2):
    day_target = list(set([tmp+1 for tmp in range(31)])-\
                      set([10*tmp+i+1 if 10*tmp+i+1<=31 else 10*tmp+i-9 for tmp in range(4)]+\
                          [10*tmp+i+2 if 10*tmp+i+2<=31 else 10*tmp+i-8 for tmp in range(4)]))
    
    train = data[data.Day.isin(day_target)]
#     train = train.append(positive)
    
    # set up the parameters
    params = {'max_depth': 6, 'eta': 0.1, 'silent': 1, 'objective': 'binary:logistic'}
    params['nthread'] = 4
    params['eval_metric'] = ['logloss','auc']
    params["scale_pos_weight"] = 2
#     params["subsample"] = 0.7
    params["colsample_bytree "] = 0.8
    num_rounds = 10000
    early_stopping_rounds = 50

    # set up the random seed for testing
    params["seed"] = 6
    
    xgtrain = xgb.DMatrix(train.drop(['id','date','label','Day'],axis=1).values, train.label.values)
    
    evallist = [(xgtrain, 'train'), (xgvalid, 'valid')]
    bst = xgb.train(params,
                    xgtrain,
                    num_rounds,
                    evallist,
                    #feval=my_score3,
                    early_stopping_rounds=early_stopping_rounds)
    # save the model
    bst.save_model('model_log/multi_2/part_{}.model'.format(i//2))
    
    valid_pred += bst.predict(xgvalid, ntree_limit=bst.best_iteration)
    cv_pred += bst.predict(xgtest, ntree_limit=bst.best_iteration)

valid_pred /= 5    
cv_pred /= 5

print('Final score of validation is {}'.format(my_score1(valid.label.values, valid_pred)))

pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0007.csv', index=False)

# %% [markdown]
# ### Train on the whole dataset xgboost 5-fold (no local, lb:0.3394)

# %%
test_id = test.id
cv_pred = np.zeros(len(test_id))
xgtest = xgb.DMatrix(test.drop(['id','date','Day'],axis=1).values)

# %%
tuned_rounds = [226, 327, 136, 418, 289]
for i in range(0,9,2):
    day_target = list(set([tmp+1 for tmp in range(31)])-\
                      set([10*tmp+i+1 if 10*tmp+i+1<=31 else 10*tmp+i-9 for tmp in range(4)]+\
                          [10*tmp+i+2 if 10*tmp+i+2<=31 else 10*tmp+i-8 for tmp in range(4)]))
    # print(day_target)
    train = data[data.Day.isin(day_target)]
    
    # set up the parameters
    params = {'max_depth': 6, 'eta': 0.1, 'silent': 1, 'objective': 'binary:logistic'}
    params['nthread'] = 4
    params['eval_metric'] = ['logloss','auc']
    params["scale_pos_weight"] = 2
    params["subsample"] = 0.7
    params["colsample_bytree "] = 0.8
    num_rounds = tuned_rounds[i//2]
    early_stopping_rounds = 50

    # set up the random seed for testing
    params["seed"] = 6
    
    xgtrain = xgb.DMatrix(train.drop(['id','date','label','Day'],axis=1).values, train.label.values)
    
    evallist = [(xgtrain, 'train')]
    bst = xgb.train(params,
                    xgtrain,
                    num_rounds,
                    evallist,
                    #feval=my_score3,
                    early_stopping_rounds=early_stopping_rounds)
    # save the model
    bst.save_model('model_log/multi_3/part_{}.model'.format(i//2))
    
    cv_pred += bst.predict(xgtest, ntree_limit=bst.best_iteration)

cv_pred /= 5
pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0002.csv', index=False)

# %% [markdown]
# ### oversampling + 5-fold time dependent cv train on first 80% data lightGBM (local: 0006.csv->0.4155)

# %%
# use the last 20% data as validation set
valid = data.iloc[data.shape[0]*4//5:,:]
data = data.iloc[:data.shape[0]*4//5,:]
# positive = data[data['label']==1]
# data = data[data['label']==0]

# print(data.shape[0] + valid.shape[0], data.shape[1])

test_id = test.id
cv_pred = np.zeros(len(test_id))

valid_pred = np.zeros(valid.shape[0])
valid_id = valid.id

# %%
learning_rate = 0.1
num_leaves = 15
min_data_in_leaf = 2000
feature_fraction = 0.6
num_boost_round = 10000
params = {"objective": "binary",
          "boosting_type": "gbdt",
          "learning_rate": learning_rate,
          "num_leaves": num_leaves,
          "max_bin": 256,
          "feature_fraction": feature_fraction,
          "verbosity": 0,
          "drop_rate": 0.1,
          # "is_unbalance": True,
          "max_drop": 50,
          "min_child_samples": 10,
          "min_child_weight": 150,
          "min_split_gain": 0,
          "subsample": 0.9,
          "scale_pos_weight": 10
          }
for i in range(0,9,2):
    params['seed'] = i
    day_target = list(set([tmp+1 for tmp in range(31)])-\
                      set([10*tmp+i+1 if 10*tmp+i+1<=31 else 10*tmp+i-9 for tmp in range(4)]+\
                          [10*tmp+i+2 if 10*tmp+i+2<=31 else 10*tmp+i-8 for tmp in range(4)]))
    
    train = data[data.Day.isin(day_target)]
#     train = train.append(positive)
    
    dtrain = lgbm.Dataset(train.drop(['id','date','label','Day'],axis=1).values, train.label.values)
    dvalid = lgbm.Dataset(valid.drop(['id','date','label','Day'],axis=1).values, valid.label.values, reference=dtrain)
    bst = lgbm.train(params, dtrain, num_boost_round, valid_sets=dvalid, feval=my_score2, verbose_eval=100,
                     early_stopping_rounds=100)
    # make the predictions
    cv_pred += bst.predict(test.drop(['id','date','Day'],axis=1).values, num_iteration=bst.best_iteration)
    valid_pred += bst.predict(valid.drop(['id','date','label','Day'],axis=1).values, num_iteration=bst.best_iteration)

valid_pred /= 5    
cv_pred /= 5

print('Final score of validation is {}'.format(my_score1(valid.label.values, valid_pred)))

pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0008.csv', index=False)

# %% [markdown]
# ### 5-fold time dependent cv train on whole data lightGBM ( no local, lb: 0.33)

# %%
# use the last 20% data as validation set
# valid = data.iloc[data.shape[0]*4//5:,:]
# data = data.iloc[:data.shape[0]*4//5,:]

# print(data.shape[0] + valid.shape[0], data.shape[1])

test_id = test.id
cv_pred = np.zeros(len(test_id))

# valid_pred = np.zeros(valid.shape[0])
# valid_id = valid.id

# %%
learning_rate = 0.1
num_leaves = 15
min_data_in_leaf = 2000
feature_fraction = 0.6
num_boost_rounds = [166, 125, 266, 159, 266]
params = {"objective": "binary",
          "boosting_type": "gbdt",
          "learning_rate": learning_rate,
          "num_leaves": num_leaves,
          "max_bin": 256,
          "feature_fraction": feature_fraction,
          "verbosity": 0,
          "drop_rate": 0.1,
          "is_unbalance": False,
          "max_drop": 50,
          "min_child_samples": 10,
          "min_child_weight": 150,
          "min_split_gain": 0,
          "subsample": 1,
          #"metric": 'auc'
          }
for i in range(0,9,2):
    params['seed'] = i
    day_target = list(set([tmp+1 for tmp in range(31)])-\
                      set([10*tmp+i+1 if 10*tmp+i+1<=31 else 10*tmp+i-9 for tmp in range(4)]+\
                          [10*tmp+i+2 if 10*tmp+i+2<=31 else 10*tmp+i-8 for tmp in range(4)]))
    # print(day_target)
    train = data[data.Day.isin(day_target)]
    
    dtrain = lgbm.Dataset(train.drop(['id','date','label','Day'],axis=1).values, train.label.values)
    bst = lgbm.train(params, dtrain, num_boost_rounds[i//2],\
                     #valid_sets=dvalid,\
                     feval=my_score2,\
                     verbose_eval=100)
    # make the predictions
    cv_pred += bst.predict(test.drop(['id','date','Day'],axis=1).values, num_iteration=bst.best_iteration)

cv_pred /= 5

# print('Final score of validation is {}'.format(my_score1(valid.label.values, valid_pred)))

pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0011.csv', index=False)

# %% [markdown]
# ### 5-fold time dependent cv train on first 80% data lightGBM (local: 0.415, lb: 0.3413)

# %% [markdown]
# #### training process

# %%
# use the last 20% data as validation set
valid = data.iloc[data.shape[0]*4//5:,:]
data = data.iloc[:data.shape[0]*4//5,:]

# print(data.shape[0] + valid.shape[0], data.shape[1])

test_id = test.id
cv_pred = np.zeros(len(test_id))

valid_pred = np.zeros(valid.shape[0])
#valid_id = valid.id

# %%
print(data.date.max(), valid.date.max())
# Out:
# 2017-10-24 00:00:00 2017-11-05 00:00:00

# %%
learning_rate = 0.1
num_leaves = 15
min_data_in_leaf = 2000
feature_fraction = 0.6
num_boost_round = 10000
params = {"objective": "binary",
          "boosting_type": "gbdt",
          "learning_rate": learning_rate,
          "num_leaves": num_leaves,
          "max_bin": 256,
          "feature_fraction": feature_fraction,
          "verbosity": 0,
          "drop_rate": 0.1,
          "is_unbalance": False,
          "max_drop": 50,
          "min_child_samples": 10,
          "min_child_weight": 150,
          "min_split_gain": 0,
          "subsample": 0.9,
          #"metric": 'auc'
          }
for i in range(0,9,2):
    params['seed'] = i
    day_target = list(set([tmp+1 for tmp in range(31)])-\
                      set([10*tmp+i+1 if 10*tmp+i+1<=31 else 10*tmp+i-9 for tmp in range(4)]+\
                          [10*tmp+i+2 if 10*tmp+i+2<=31 else 10*tmp+i-8 for tmp in range(4)]))
    # print(day_target)
    train = data[data.Day.isin(day_target)]
    
    dtrain = lgbm.Dataset(train.drop(['id','date','label','Day'],axis=1).values, train.label.values)
    dvalid = lgbm.Dataset(valid.drop(['id','date','label','Day'],axis=1).values, valid.label.values, reference=dtrain)
    bst = lgbm.train(params, dtrain, num_boost_round, valid_sets=dvalid,\
                     feval=my_score2,\
                     verbose_eval=100,
                     early_stopping_rounds=100)
    # make the predictions
    cv_pred += bst.predict(test.drop(['id','date','Day'],axis=1).values, num_iteration=bst.best_iteration)
    valid_pred += bst.predict(valid.drop(['id','date','label','Day'],axis=1).values, num_iteration=bst.best_iteration)

valid_pred /= 5    
cv_pred /= 5

print('Final score of validation is {}'.format(my_score1(valid.label.values, valid_pred)))

# pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0009.csv', index=False)
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.0391239	valid_0's score: 0.408669
# [200]	valid_0's binary_logloss: 0.0382933	valid_0's score: 0.409345
# Early stopping, best iteration is:
# [166]	valid_0's binary_logloss: 0.0383707	valid_0's score: 0.4139
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.0393144	valid_0's score: 0.403379
# [200]	valid_0's binary_logloss: 0.0386405	valid_0's score: 0.40047
# Early stopping, best iteration is:
# [125]	valid_0's binary_logloss: 0.0388871	valid_0's score: 0.408022
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.0385751	valid_0's score: 0.411784
# [200]	valid_0's binary_logloss: 0.0378128	valid_0's score: 0.414575
# [300]	valid_0's binary_logloss: 0.0377245	valid_0's score: 0.414487
# Early stopping, best iteration is:
# [266]	valid_0's binary_logloss: 0.0376993	valid_0's score: 0.417896
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.0393511	valid_0's score: 0.399794
# [200]	valid_0's binary_logloss: 0.0385745	valid_0's score: 0.401205
# Early stopping, best iteration is:
# [159]	valid_0's binary_logloss: 0.0386549	valid_0's score: 0.406818
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.0389993	valid_0's score: 0.404614
# [200]	valid_0's binary_logloss: 0.0383746	valid_0's score: 0.406935
# [300]	valid_0's binary_logloss: 0.0382511	valid_0's score: 0.409021
# Early stopping, best iteration is:
# [266]	valid_0's binary_logloss: 0.0382429	valid_0's score: 0.41293
# Final score of validation is 0.41513370555392304

# %% [markdown]
# #### analysis on false negatives

# %%
train_cate = pd.read_csv("obj/id_cate_train.csv")
valid_pred = pd.DataFrame({'id': valid.id, 'score': valid_pred, 'label':  valid.label})
valid_pred = valid_pred.merge(train_cate, how='inner', on='id')
valid_pred.head()
# Out:
#                                                   id     score  label  cate
# 0  96c11ea394631bcc2ae77455cd10cc3dc147f78632921e...  0.000395      0     2
# 1  eafae698fc60c7a192a1d13074215a25ac24a2e47e12c2...  0.000187      0     0
# 2  02dc77c122c4036ccab9f003aa760865b6f79632f930e5...  0.000227      0     2
# 3  e8c3a7fbd718708534a436d217a76c86ac2e0683b65ae1...  0.003345      0     7
# 4  d89c7b05241c510b3b24371fccd7be3667099f89f4a2ec...  0.248242      1     7

# %%
percent = valid_pred.label.values.sum()/valid_pred.shape[0]

threshold = valid_pred.score.quantile(1-percent)
valid_pred['pred_label'] = valid_pred.score.apply(lambda x: int(x>threshold))
valid_pred['isCorrect'] = valid_pred['label']==valid_pred['pred_label']
valid_pred['isCorrect'] = valid_pred['isCorrect'].astype('int')
valid_pred.head()
# Out:
# 0.01710505813106003

# %%
valid_pred[valid_pred['isCorrect']==0].groupby('cate').id.count()
# Out:
# cate
# 0      935
# 1       29
# 2      431
# 3        4
# 4        1
# 5       81
# 6        3
# 7     1303
# 8       12
# 9       51
# 10      15
# 11      16
# 13       1
# 14      18
# 18      10
# 21       1
# Name: id, dtype: int64

# %%
valid_pred.groupby('cate').id.count()
# Out:
# cate
# 0     86839
# 1      5361
# 2     41173
# 3      9274
# 4       319
# 5      9410
# 6      3603
# 7     24768
# 8     10426
# 9      1549
# 10     1934
# 11      602
# 12       27
# 13      196
# 14     3010
# 15       41
# 16      120
# 17       37
# 18      151
# 19        4
# 20       55
# 21        2
# 22        4
# 23       16
# 24       11
# 25        3
# 26        3
# 28        6
# 30        1
# 31        1
# 32        1
# Name: id, dtype: int64

# %%
valid_pred[valid_pred['label']==1][valid_pred['isCorrect']==0].groupby('cate').id.count()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# cate
# 0     396
# 1      11
# 2     160
# 3       4
# 5      64
# 6       3
# 7     738
# 8      12
# 9      28
# 10     12
# 11     14
# 13      1
# 14     12
# 18      1
# Name: id, dtype: int64

# %%
valid_pred[valid_pred['label']==1].groupby('cate').id.count()
# Out:
# cate
# 0     1300
# 1       21
# 2      486
# 3        4
# 5       64
# 6        3
# 7     1415
# 8       19
# 9       35
# 10      15
# 11      16
# 13       9
# 14      15
# 18       1
# Name: id, dtype: int64

# %%
display_all(valid_pred[valid_pred['label']==1][valid_pred['isCorrect']==0])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                        id     score  label  \
# 4       d89c7b05241c510b3b24371fccd7be3667099f89f4a2ec...  0.248242      1
# 124     694cf434f6355cfc7856a1568ac3ff488609fadcb5fe8a...  0.273763      1
# 244     40eb54700d247e26fb28f56a18ce9b6aa5254b7f3d41a4...  0.050994      1
# 254     d9112cda7ae661fd2dad10a5f929e61d5fa17fdef124bb...  0.002252      1
# 293     30821797d2f24d7f1dc2dcce21cc3c96be719928abd76e...  0.226805      1
# 392     27f2a4d7eaeb69a2d45f8a5a143d48677afd456a9dcffa...  0.024728      1
# 766     678e3ef9449e3d53153660ea0d9411760e2cd83390a4ba...  0.036332      1
# 875     9333010380982d928c22dc3493d0278612166f010695bd...  0.086421      1
# 1005    34f99ed9074858c2f5ae38f2e7df27619c6254144f426a...  0.181416      1
# 1085    52dafb68c5f8c8e36730f1705843422e2c418ec5867df9...  0.174863      1
# 1213    41b3e5df31c1bc86b9bc547775b194e1e00a575ec3484d...  0.183224      1
# 1228    02a07a3b183137ee884e1f8425f3b36454cb967909325d...  0.176886      1
# 1267    f182f348604d5ff8a522b6f8efc2a6ac7735c908a58f57...  0.047333      1
# 1318    1a762381d69075c452cd5ae4167f0197c6e94aff07812e...  0.079215      1
# 1562    e790585727fda4b812bde9f89e6e1cf5ac5a1f8e1ae413...  0.274428      1
# 2018    9a61848ed8494f898bcdd0c986799421d24124dafd2726...  0.194435      1
# 2043    5539bb818c901c20ce2c250f7f6f1f4f266aa702e14508...  0.004996      1
# 2233    06c8a652dbc6f0b5a8ce11752e2f3041e9c4636498f135...  0.289789      1
# 2585    76c220b2db55e649bbd89f592d4ee60dfdb7c01da2c983...  0.267127      1
# 2652    db32b775eb7852fcef1479ab7c0286b8827c283964f5df...  0.249689      1
# 2808    1c54f0c31784d7ca6d37464e989741ccb873d0a9150574...  0.176826      1
# 3001    8d0ab3e70c6e2c79ce748c25ebaa820d21ce990224ee9b...  0.258885      1
# 3219    d23f0c65a23765a11fd34deba52a230fec00acc11ab892...  0.005732      1
# 3234    4e9a77482dc320b4659e4c6f916f81560f21d8b410a98c...  0.289594      1
# 3270    21c930d557c3640709dcb77540d590c69060d95f7b059f...  0.135661      1
# 3435    2e00ceebf3e457aa2d4dda4a3416132f3594b6b35f340d...  0.009381      1
# 3697    4f569d1494e029a5efbdcba849d08d50200793d7e6e55d...  0.265211      1
# 3705    e84b71bcd52e974b269c8312e3d00caf0d0af678d2e34b...  0.266635      1
# 4052    2d9535620e6775daef23914e030f147da55767247e2ad0...  0.158901      1
# 4088    3b480d8ea853cdd08832bec0b473ae89bc10e34d8e3099...  0.002722      1
# 4212    5592e7ea018d4e69ac886e49ab1be93ee3ecb9874a0b0c...  0.085960      1
# 4765    0d9c128592af9aaf15dd74ae5735fa6588e50ff4cd6ff8...  0.277827      1
# 4932    3f4f0fd44b9d7427027c93f6c4ebf7a2ab764c89f43171...  0.002803      1
# 5196    13daaee9a6e272cf2f24ca319b7778ae5d8de30d2fd286...  0.303052      1
# 5256    f71d4cd580a8e5eb9c8aa4ad679bfcdb9f5f046d659cd9...  0.067055      1
# 5356    8e55514d131ef15a5bb2e7f559ea6b254695f1dfd9ee31...  0.025541      1
# 5375    461786509625bfbd2fa1246c6ab3aaaa22bee5ea894079...  0.219229      1
# 5527    884a62eb6f5506fdbdb50caa437812aaa6558317cf0ba3...  0.232811      1
# 5654    26cb965f2df1e98e12ba895dca919d3a295e7483c129b5...  0.074198      1
# 5830    5cef215795ca2f7528acb1a7642a84a30fe675844a0bb4...  0.304150      1
# 5978    c36d84cc5836e754e21c97ffd144c71b36df28806af80a...  0.100913      1
# 6102    4d5d7d336e9e1db74ca300cc71b86a829e225893298c3d...  0.245718      1
# 6199    ed1a5a07ab1b6ad368c31ddd837a60ace87483efdfcef9...  0.311097      1
# 6227    33ebf35ba2d511337058e9ff53d3888441d416b9f1378b...  0.297444      1
# 6413    cacbeb03d9520d83040d030fc175d154d899f19eb2c54d...  0.131990      1
# 6479    8292c0739c201e1924b057b9c278915312ff8a23e200d6...  0.227138      1
# 6596    d9d9dd8c9c43d2398b3663e86ff0f56dfe75f2096744b2...  0.003172      1
# 6642    bebaed56e602f046f227c21ec71ad53d5f05ab8cbed46a...  0.001841      1
# 6710    728db15f5076d3b2113f8e047b2285092676962e42b877...  0.181809      1
# 6968    96363495e9b6ef698c2147d527b92119394ed498b4d991...  0.008617      1
# 7420    9f939cc08fcb30b1d867a5fb2a29614051f654baab9b42...  0.141008      1
# 7473    eb0c5289bdb1aeb090092bc38a6d55fb7afc4269b5d0a8...  0.001243      1
# 7533    9c106d3fa15253b47df1b01da34e66a6b3cf1ceac39156...  0.098552      1
# 7854    337655a7cd464081a3e214e2d6a31d5c6bc669f9f55a7c...  0.256350      1
# 8022    e623631efb7b6c4d12b5b110a5bed5ba7ff79cd61c480e...  0.250027      1
# 8028    255332f4ef7905953db69b8b8d27897942f4bf7db37890...  0.021073      1
# 8057    b0ada9fccc95cfafa5e16c0042287a119f450ec1b24bc8...  0.108931      1
# 8122    7517651e81e8bd1c79e0d565435d6e458a1d40a3b7ea15...  0.149377      1
# 8457    968a2d278d5991a5efb0c1e91cc9544eb619650f2bead9...  0.178433      1
# 8528    36e67a18958dbebd1c4ce8c7eb599c7d56134e0a557b92...  0.197251      1
# 8689    308ac93c651fdfbada4844b509f8dc50aa37d72f4aabab...  0.154351      1
# 8807    392985abb23441a75cd7860e968123fcecf1e48e2cfb76...  0.292327      1
# 8958    2c3b9908eae21222dceff9cae30139a5f6a491e2a4ec4c...  0.000496      1
# 9104    0956b969044c8b9f78e2c4ced8f25d024dd3b23b7fb84e...  0.196037      1
# 9438    8b04bb92018723740bd815d47b3376ac2423c96eb85a1d...  0.220874      1
# 9450    ab24be834889f1bab8c9a6cf1d02ad37219f9bbab5ac5a...  0.135717      1
# 9534    93d1527c7dbc12d8d86f57014797e909039872c6488ec7...  0.120642      1
# 10029   aa1f5a7e618f9c989cdb003c1f2ad3b51d165c3a268fc0...  0.156521      1
# 10137   06dd490253ab616bb8d9aaadb6c37a1760ac16a6065fe3...  0.231522      1
# 10293   3e0ec11ad9478f5392511414e7c96c99e1b3cfa2783502...  0.278275      1
# 10297   aad839a1f49073749948f6d1b38dec47999b7444f1da7c...  0.039162      1
# 10568   47af0eeabb6b40404c8a0217043306d46955f214fc2ebd...  0.258240      1
# 11065   e9ecb529ac61ae84f826ef7344ddc4524d6053ec701240...  0.001248      1
# 11190   5eebe9b9a75187fb5bf54dc59d45e5e41d229792561c54...  0.204760      1
# 11534   160c2d6536cb12fb3a9ccead45df324eacffefc511e862...  0.016276      1
# 11635   91023a48d8ac3b4ac84201fb6653daa5f2655eee2125cb...  0.005096      1
# 11951   66b1b6123b632672c1d846f32b6e9a8fbc9502f63ea6af...  0.288205      1
# 12099   5bf1a6ec66297e4c283c72c049ccba39fa934b765874bc...  0.198712      1
# 12236   ddc6f66630558e9b7d904cb68dbc049899e8c3e9406090...  0.274883      1
# 12542   be003233151cdd95f5d4b8a96276844afab8ee6a195f90...  0.053039      1
# 12762   59bb30cdcfc1afd8648cd3df62ebb09380e407cb1da452...  0.092785      1
# 12788   c4c3afe6f8b9ca47ea7d58013d0a7208f9f44c15e2b416...  0.164222      1
# 12910   ebc6b5a2356a0869a42b2fc28c709890a5cfa69a2c43c0...  0.304791      1
# 13361   1d97eafd9a1b1acc9ac862c3599d1ef28df59b9a586acb...  0.234280      1
# 13589   ace1019fa29fe32345fd52dc75203b520d011f536af82e...  0.049008      1
# 13913   5b7c407c65ad4b8a9414afcaea97a4793082cf582db2d8...  0.309287      1
# 13917   caa8d5acc8d9a1d27363d305f7e847e1fe41ca83481fb4...  0.019058      1
# 14043   b7dbae98857ae6ea1f3efc83037570ea40cc95e4380a65...  0.000814      1
# 14492   9be9e000ffc4db6a5ca1b7e23d4e16cd147df0c4490f11...  0.256247      1
# 14542   40a260544e1ab5b2b971b4cab6c0d20baf764934d135ec...  0.133585      1
# 14871   d87a5e4595dc732ea738c9f55ebb3a959077bafca4fa67...  0.032147      1
# 14934   d02b129c7718de717eeab56a098142a26157c126c6b616...  0.015981      1
# 14974   4cd7eda744b15b0db12f32798da239ad75c52a025e9ab6...  0.008344      1
# 15088   96e404c6705cfa422eaa679d2a1e18bfd9dd0d290b2850...  0.049674      1
# 15247   7b002e0a50083f328fa7510e302883e2e8365e4d56fc3c...  0.146640      1
# 15712   152b7026360509fdc425306e305d3548ae2dbfc5bfcdd3...  0.300845      1
# 16188   414cd645b09e8c5e93071a7a78a78d57120f4d62f50279...  0.227135      1
# 16214   2400f64b1d71301f2f15d7ba485c93a4ae5a9e3f93505a...  0.225373      1
# 16726   68866b8e0d428e22d044f99427013a7516f8eb32917cfb...  0.169053      1
# 16732   60123f3359197c7017183a47b4734ea47cdd669a3cabc1...  0.094744      1
# 16785   c8a913d7c28133395d6c92429835fb9ac54f2852730100...  0.249307      1
# 17247   d66fc68ffa5b41d6c9d45947a5d4ba0cfdbea5ef923d1f...  0.194023      1
# 17353   fb34730c45c0676ad960c69d96c3560553fab6009c0ea2...  0.001239      1
# 17444   9bc23e2231eed17d8f0b208d7fc90ed4df0ebd0644cf50...  0.000887      1
# 17448   717c99c4f21ac0d6eecc817e1737cdfc3d5362b61b90f7...  0.000653      1
# 17458   8ac36c4f35eec785d6cb48813bef4511ab8477ef2fc5cf...  0.181814      1
# 17487   449200fa8cb9d8b2de337ff0abd1089e52684a18122aac...  0.315834      1
# 17596   b7855f8387e9f90373d129f69feed3c77d325ea650c013...  0.129015      1
# 17772   79ee5492c1712befb84fefcadeaa8ceeabeb4e3b8f991e...  0.309085      1
# 17887   037c04d793bf80a02ac1e03e383f3aec83135cd296b5d2...  0.114293      1
# 18511   23253cf1d3ce2930814aa0552df6466b3b205c1baded29...  0.004048      1
# 18531   9f25f3c8a07a73de8ce56469e1d7fb45882c490c3dc348...  0.002961      1
# 18601   d548fdf3afd6e42a016fc981006e06e4f3cf332a05ee56...  0.011570      1
# 18679   715efe9aa81bfde4c2b2af99b4220eda9485966cd022c0...  0.158908      1
# 18699   c346a9d3175d3b8c127d8f8dc814aaf10482522a5294e7...  0.050592      1
# 18754   caab2c0d2a8e9fcc844b2322e45709f435f75283608e82...  0.170072      1
# 18770   f6b33a54190c7b53effa570cb65076e9eb267d0b87252e...  0.030399      1
# 18862   848d6f68b3fbdb8cfa3d1c5ef0fffcc041c14357786eb7...  0.003033      1
# 18966   5fdb1af0d09c590f2ebb160b2b9b4781834b4d4e28422e...  0.003767      1
# 19049   accb84d2534c14b4f931683e1e246120b302eee049ef9e...  0.035060      1
# 19221   c3fbc0c93992595b67bc2fa555f20581cb62e4aec81fd6...  0.004622      1
# 19283   7ba3edec1a9d1b65ff7082b8849534a6c2ec728899f7c8...  0.156895      1
# 19351   74441aec5fc277d0f8a28d2d896605e074dd4eca14e6b4...  0.199463      1
# 19651   c1399e74f7161e3b46d5775133b88ca4a7c3398cac6c13...  0.012509      1
# 19848   1f3e477b0a4ec68939de18f783f189bf9081e46246f252...  0.244898      1
# 19939   c6931fd72c017cbdaba7262977792e9c3665b166d8db5e...  0.103609      1
# 20063   4227182bf7cce89ec9d5ff48c220c6c6b001e9ac48aaeb...  0.144473      1
# 20129   8fa8c5511d24ac3fd7ab077e06a050b7644697e1ab9aa3...  0.032691      1
# 20169   d01270f44036d6a2633683f245247a4e454e9ba962e678...  0.209272      1
# 20201   8aea1af7a572821c1dbedb80dcef8cb878ca716b61a44a...  0.005212      1
# 20233   33730c0ccdc02930de4ce964d5aa46c1c4551371237c76...  0.091225      1
# 20238   161b7c69ca9f924f48d364fd6306ac06578f89c80e8266...  0.026446      1
# 20655   434f6ed7068945bb25ac74dfdb79b8ef351cb2a1a6e9af...  0.033292      1
# 20908   79e1c833d261a20fe8d3f8615165a4a4a1d676f5ea00db...  0.080089      1
# 20960   9043cbf3a70502410d376ad0b3afa7418809b7b7a76809...  0.223209      1
# 21215   60919554ef21f0e79af68fc5e5ba2f7fdcd0a964760c6a...  0.285754      1
# 21240   46fc1f8040dcd7dbeb40c39516328cb92659b7d8ba007c...  0.309522      1
# 21274   4d56cbb00471af12823b86db052d6bbe8d5f33d4b0b241...  0.003280      1
# 21501   13a17685670b07080b104921c4caad205fca57dbdc3f34...  0.172145      1
# 21565   4b824899ab31d2783b05e840cf9a890606902112a04f4e...  0.153794      1
# 21613   b6e28ec7cf8345cb75981b412e20b8ca81ca2f920fda6b...  0.094201      1
# 22022   e1501c35fd189f63530e1d180a8806d616eae0d3a627fe...  0.143576      1
# 22162   5de350d7355a8b32eb13fdf4eb6c2234e4208444b4272d...  0.001735      1
# 22453   f07e76fc0a05ef481faf6ed6b801df7a158f5658cb7493...  0.117279      1
# 22468   f341ce2aa38ba2ed2fee7af3703e8f8a795dc0565746a1...  0.209518      1
# 22490   390a89719c2e5b2283823f481e43c9604aa25dcde66c01...  0.040201      1
# 22544   d5c9854057386deb67488c3eec0119bfcb96236a13db92...  0.267933      1
# 22635   c1ac44e6c4a051685e0e5cc15390310188732778f4c400...  0.004250      1
# 22835   da0f67d14b7cd8050927edb455776acc38f8d3f6d9f46e...  0.205719      1
# 23032   6bd0f92aab362961335ffbf41f832ebe6009af678e4fd9...  0.079658      1
# 23064   a73e095772fcbd56d12fb0eb1f8bbd02fbbfb4227da662...  0.078193      1
# 23089   b3d147b7b77f6b25bf357114f3a3e4f107f9bc21bde587...  0.002213      1
# 23310   a3e0f6802b34af0b3e2a8a7a9975e0ef593b01055c4d10...  0.299678      1
# 23316   ca6a277abcda28e1749816a77624dac20cd7b7c4f9679c...  0.112154      1
# 23318   388ccaa344c8c8056c1b507c96f3185f362ead1dfe4d64...  0.129058      1
# 23448   74f48abfec977a32e6b246bd84f183921eadfc0d5c908f...  0.056811      1
# 23580   2e2e48dfc66d448ffe93ab772f24ffc50d765f1b25f114...  0.044359      1
# 23927   97f9598f5ef34a2b9c741c1712102f57b312093740dde4...  0.005859      1
# 24145   88660b4026c0eed2003a6593f751de4b046cc4f899a1d7...  0.033219      1
# 24465   dbb5945d0c4f66ff6daa79660f2f88ba01aa94b30fc16d...  0.014502      1
# 24493   3e77dae37e69a4298a51f65ec04754a41c0c2cfc6e2ede...  0.068046      1
# 24667   2a3d970b8e6c480aba904ebf3a14ce6be627ecd75018ae...  0.273629      1
# 24763   8c18448e1c0ce8acd3a32b95262ac03280eff8ee79b0f6...  0.063477      1
# 24804   a066bbcf9a18771a475595adc7a4d9432356ac8d80f43f...  0.001608      1
# 25167   d4d7294b44a218737abe8e2c155f9aedd27473de2333a2...  0.291430      1
# 25344   cf10ab867c85f1c6c1dbf274ca47080b4b690377825a5a...  0.316870      1
# 25533   029d79c73e6364c1ee6004a880f1f0740c1904f6db5329...  0.009930      1
# 25882   b0075aaefa7b76322a48df82ea4f54605608d1db3becec...  0.091303      1
# 26050   c811b8aebd48117e4f4afee43c8a8bcf2d247504eba221...  0.207980      1
# 26137   4087d810ad40a688c336d9aaf443e14bee54b4ee6594a9...  0.004018      1
# 26179   b31e15bcef6ab292f70b937e4337969e197134dc5b4b41...  0.125905      1
# 26225   17747afb0658d5c59db07ee8eef83ed4c174236451e32a...  0.101213      1
# 26249   caf19b8c1379980629a1420f30d5ab830e2912d82b5945...  0.008945      1
# 26302   abbe72a343c993d73a9f944f6ae7911b26176f83e23ab4...  0.215445      1
# 26514   aebfddb66f3c585942e6f600664afac5b53657a25a1902...  0.002566      1
# 26810   bb314c19d054883795d51f366b56201d8c7536401aee01...  0.001875      1
# 27124   8e918390267f26c3bdfab1ce66491a3a04ee43c841012f...  0.004748      1
# 27186   ee16bdc2946b714c4561a5967ef9f682a9a7edba490af3...  0.084200      1
# 27203   819f240cb69fde55021bc33a9b1a41027b0e1edf3c35b3...  0.056474      1
# 27239   fb8c534a55f2ff7d3383687c81840e72205921e21da664...  0.069345      1
# 27266   38bcd9cacaf71df8dd3574efb0f53ca1271bceddb71668...  0.041306      1
# 27352   64ac6357091842072f2bdd0c3d9c03859cdb558a01da67...  0.091442      1
# 27426   f892ac5ee64cd01823fafe35fe45efdc1c67c778220ec4...  0.142966      1
# 27486   789ec5ca3d3b838374222692b07a1ec3d3d2567c7c46f7...  0.236473      1
# 27811   f0039dfddc66538b7df7f67cadf8c552f437b85da0221c...  0.002633      1
# 27812   77c13bb88f8c491739a4d7857cabfd41f44659209b8aef...  0.003449      1
# 27814   002a46d7e9d77d629906a97ac0e7a7049bf1890e697396...  0.060544      1
# 27844   de276d8a90d2b5159061880fad7de12ae42f209b47d7e1...  0.161767      1
# 27936   abd089103c8882065d4943570b4039e1f63631a9ff811c...  0.146192      1
# 28653   ad2a17e1bfb4fbc4bc5415fead5dbbdecfbffa416d67a2...  0.117480      1
# 28680   be3e91b50824894b951c86d8808571653937f675a6d7f6...  0.003492      1
# 28739   25426bc579cb608b9366006833a6f93a43aa635ab56994...  0.287842      1
# 28802   8d4ab05db54ed6cec5b139a21ffcf850a4c9a63e1dd5bc...  0.220967      1
# 28936   8e6369f2dd4aeca7a110c87f5224d4af76463d263722ae...  0.224805      1
# 29043   b2793f020322fef1a9293173e63d7528cbbc45a1d3dd78...  0.002314      1
# 29213   9c30bb3edc30faf4131de003725024a771be4e7293410a...  0.133032      1
# 29240   e2c764dcd5fe4ffaa03ecb52b3e92df70e2b4cd2eb5d26...  0.301152      1
# 29408   c57ded5a4829059bf827621abb263d482b19ae613a1ce9...  0.047550      1
# 29777   9cc3c82f7e972f04f997c13e259e46d98dfd71bcdebc95...  0.017385      1
# 29913   4b387e9ffba6d150fe7e77cc049027b0beeb5343bc4be8...  0.063570      1
# 29914   aa37768668d1c76acccd0f50cf41f8581eb8e0e1681a33...  0.112276      1
# 29936   c11850a756f5670f5710dcaa4cbd62a8482a5ed7bd352a...  0.076325      1
# 30000   46b8cbed2a9475e0cf72dc831c5da89db29da877553854...  0.006119      1
# 30279   fc3b43cda0e6ce21afce14bb868ada168d60ee749f56a4...  0.094683      1
# 30547   c8d77f8f83ac9289b993dc3b9b7cd86124a43d5dbc81f1...  0.006179      1
# 30638   03de9c33723ec517d6a7bc1d941777b7c70ae327dc95aa...  0.114836      1
# 30642   d315b262bd38fe4c56dc652105a5f5afb06a28522394e9...  0.035120      1
# 30829   4198d6290d97eacfbbd0a5fae2a6f408eebe625aae3f12...  0.052938      1
# 31048   76b809084b1c1ee96ad6c15b9072ddd515c14a3ec0db82...  0.053667      1
# 31107   e79eb878dbd0581e4785e1eebf5f0b0998633b4af0e3a9...  0.047244      1
# 31533   acbb1fc991363674f463f89f33d983b08a207d32fab7a0...  0.176238      1
# 31723   c8068adeb787ae5d70128ed10989515b3344fc488d06e3...  0.002679      1
# 32054   f4df312106aec9a1de95c1e9f32f5713ba87a6644be4bb...  0.205538      1
# 32131   5a283396bb4da41f9985313c9a125754d4e8a1513b3c89...  0.002526      1
# 32142   f068a4db2e698da816b5e3871a64307984eb1d282cc8e6...  0.269638      1
# 32239   d163d2cc0bec706b9a5e9be698edf66bba880e2fd91477...  0.265228      1
# 32605   349cf349d342364766f84dfc6e083dcc95d4f551a22bea...  0.066338      1
# 33114   f93d6d081fddaae36cfd0aa9e24ce2cb9e7832e4212dc7...  0.037123      1
# 33165   28ff6d7b9521bf75b3620c0d6586b27b9e9d6cf048fcae...  0.004654      1
# 33372   1738fd60d54bfcf4ef08002085444d894122208b739c11...  0.020296      1
# 33529   048e04bbb0fd10c7677be9fbb05f80906e8b51a0a8dbda...  0.002614      1
# 33625   dd7b7fa40b35a0226d0597f1ee226116fc1de2aed873fd...  0.007133      1
# 33967   db2cf39b5a56484a424994c5d3bb22a67b7306028531e3...  0.001223      1
# 34064   d5df0dc0e1ddd92302b192bbb16331b9c2acc33f49dc43...  0.031044      1
# 34133   bb043f153df58a93536045cbcc156feae8cedee595f16a...  0.109817      1
# 34141   a9678b8177a07bf452c7ac40fedb7b53b24a80032bde6b...  0.030869      1
# 34150   db403e8e32a98056d8b5c35990ecbf63529079f80b66c6...  0.302342      1
# 34586   7aabba14b1cd8169359d65e8ae4ba13821573da5587779...  0.029154      1
# 35032   d0c48ea4598212644c69baeed306be80262dc5271780af...  0.290633      1
# 35231   501b853582d8f674885dba29122b33eb3938ec652dbfce...  0.245096      1
# 35319   10d83bec0135585e43d2623fc924f302b01e1814f74951...  0.079939      1
# 35725   0f8a99488e8f3e805b0002c0bc8b8eca0c6e3b1055f940...  0.050831      1
# 35796   48737620122f83ead2027c4cbf58512d49495b9a2cf133...  0.141924      1
# 35875   c1b3e4bbc587c38adf2496643246e760a27ec57a5c971d...  0.181510      1
# 36082   10ac50ac67e0a206a228cdd07a359fee5fd150073ad058...  0.030506      1
# 36200   88958e672620cc84103d71c31982bc94e7eed077be1440...  0.084125      1
# 36318   008af93071e66a3323f62c5f8dbf6fee62bf82e56fde9a...  0.192068      1
# 36337   c2453244b81674d931ce4a0b12fdc6b92af78939e3f675...  0.135635      1
# 36725   1f686db8a1efdd7e6d6931c26bced6ced2762483b96a8e...  0.223222      1
# 36778   0c96209f350fd13fcd9397e3bb0fbfd4f11ba3003e5c16...  0.136589      1
# 36808   6f190dbd467a82189d31174d72b3d4492008a8ada8c611...  0.188120      1
# 36820   5bfba0b14e0154327b389cf702964a7c12c73a1d9ae12b...  0.024063      1
# 37038   570a7d975f7e271b2a62d2b7e870e87f00c9d91986abbd...  0.003966      1
# 37100   3b39958f0aa7dfe962f4b30d59d24c1c541d5995a07804...  0.030779      1
# 37103   518be8e22861c2d64b84cce2af0a4bb464437efa3eb34b...  0.246724      1
# 37149   7394300dab73458ac103069a7873ff743c6567dc5c9fef...  0.079448      1
# 37239   fbb2659db0fec78d35cd944da5d550ed00853617eebb74...  0.152063      1
# 37342   bdc7d654542d29ba4b0db116bd47575ae958e97f02c03a...  0.031896      1
# 37433   1064f003f0b2d83b1880427d2f7b78c475eaa350bf816c...  0.176717      1
# 37509   8af525c3b06be1419073a61c5fffac39c8a6a47c29da0f...  0.076220      1
# 37710   4e797c6f1e45844d4c05de05ac4c0a6c64ab14293779b0...  0.108558      1
# 38031   80c88274b1adb8f3bcbe0ba4cd116d324862c8d810a1d3...  0.221488      1
# 38045   fa8388b7b76552d6c936908d082d4b97fc49e9ae043757...  0.006973      1
# 38253   f32907752572ca56020a675ebd10785a4a7168d071cd41...  0.209774      1
# 38351   ad11127a436d06ff729f886a8aadfb0bdb92d5f9176504...  0.282972      1
# 38447   19e1ef772851944da57ebea2934f356cfad2cde485b05f...  0.299817      1
# 38692   4529b101258a4f85885c3a28c3fa6642d762059fb73f03...  0.080868      1
# 38781   e846213050e0e76ef4f83601899679e9e4032ab5b45912...  0.276252      1
# 38841   71e65bb1805cb7a755f025fc225d9dc31e257df12de205...  0.304528      1
# 38907   07ea5014b06e632cd94dea058007b4dd63cc5c8947045a...  0.041604      1
# 38930   6330c5b48f14ff058ee8338b28d39d96c24b8e68224518...  0.001613      1
# 38976   2f1e25a64dd37608596dc6bbeb3cfae0f15b907cc591bb...  0.157584      1
# 39099   a7313c2ed83f2f3ed104cb884263076b6b53ea061e9676...  0.246016      1
# 39150   1c671a43538056e5a584fdc27f7b6b9a143f091f761748...  0.019265      1
# 39227   d2d803c9ccbf8c92d5404ea59a4705bbd72ed730c7809d...  0.081931      1
# 39685   b69f630e58f84d419f7a85e2b259a15b53a9737a9f84cf...  0.166344      1
# 39751   5458b5b8237d38092d912e7c0710bea9e14c722c4d5d4a...  0.238353      1
# 39953   6b4aa8ceb07c15e1de9b5d2bcb60a160fa29ddbdfcb357...  0.058840      1
# 39971   81d4be2c8526f8ee484922a8f03403573e5ef492c28573...  0.011590      1
# 40162   b401e00becdfd119cacd1bc83d4616afc985b74f42e631...  0.184437      1
# 40194   e3f8ac520ddb9729fbf35cff6a5cde39f2767506e90b35...  0.308926      1
# 40397   43ede99e0956048d43eca3dc51d5d374ce27a94d59acf3...  0.218857      1
# 40513   f9c7d591685501641e084f19a7891c86484331ed609229...  0.116681      1
# 40554   1b1fc7de1079e793beda3cfd803c874fb9cffef6233609...  0.215245      1
# 40580   edacf06b8b0a5306c08763cd7fda4866021f23abf87b7e...  0.028710      1
# 40630   048750015011d5624ac22b6493c8f2273f418888be65a7...  0.028553      1
# 40633   5173fd88a08dd14fc65ca686420e5a937158f4a20f4813...  0.000692      1
# 40741   40a4e3844d664871ae4ca45440cb7773e7825f0a0aac3c...  0.270332      1
# 40766   2e292280d147284d6afb7e6e258c1cdf2f2e1c4c9bf3a7...  0.091961      1
# 40781   726ae079e28646559428788d9a9a104a743017da685817...  0.144863      1
# 41126   43416a586f5bb9657cd0010eeb279b9ce2a52ef73c85f2...  0.140586      1
# 41342   aee967bf8ac898583eb0bda4f9f435c940504dee9305c6...  0.045762      1
# 41346   a011c9a4865720356e407e02bedbb3e877a9036cdc4195...  0.251768      1
# 41581   4d14650c266526a200f19ac886a1c7902b7d3ce31c98a4...  0.309971      1
# 41665   aae63899b0eff6e026c05dd368fdbb8f76aea467ec910d...  0.230044      1
# 41789   136862c0dd5f2a6b651275bad49898db8d78374c8fc69f...  0.067505      1
# 42427   ee57a38c09664907b18d75ce2b446896be5aa6f8249643...  0.301697      1
# 42477   5be70a6508ad3090d887d751ce6a0e3afa1965a82f6224...  0.185115      1
# 42906   5b1423d7b7e43cb08a12ff19a9a8477b11f744f6e4f70a...  0.196226      1
# 43158   56f130515f684f4f4113389442c05971291b2d7c50a13b...  0.020758      1
# 43474   7a8c697b8f8d51b9b48688697718a90cc6231b27445600...  0.094127      1
# 43695   430e25d0c1b3f655dcbbae6e3c6926812d622adeb11465...  0.006292      1
# 43770   4e4f00d9ccfc7e262781d601842ff09cfb741dcb49e6ef...  0.152767      1
# 43796   a4bfab92fd0254e994d0e81d4f0efaf4f2e09fef8136a1...  0.269917      1
# 43930   ec45cd9bef5ca1213ef724c1fe62c143a583f0a06f4ebe...  0.052498      1
# 44156   bf6887af6d9fbf108a7ea0cf008d049850c741d649022f...  0.220843      1
# 44276   9a38fe032114ce899601bedeb70bcd148635d49195653e...  0.061938      1
# 44334   00c350341286fb44db0d33c8279ce8c2202213ea0383cf...  0.031236      1
# 44549   0305f597abfa80c7273e742cf8d0584f32cce7e5be8f4d...  0.207613      1
# 44687   929d3e4d2b66ef1ccb2a8413e7d2d1125efd9162751f6d...  0.108714      1
# 44698   c6dd11544de9fff916896dbb27f5d56de94314b9106c94...  0.067273      1
# 44745   499bb915537711db4a408fe080168fbb38ada24b5cdfa1...  0.271136      1
# 44830   5875476f9d525c1828183105d742efba927d9510037a39...  0.087034      1
# 44853   29c1b4af25f0d5e3d0aa38dbc0c7b9b0489e8a5b837b79...  0.063877      1
# 44974   eb940b5c016bf7a41cde896f4b38424010e67a7e42eb6d...  0.304149      1
# 45123   cef9ea3968c45c9362a5c5839e8955a7aa455f543a574f...  0.009506      1
# 45234   84c61a214eec2e65cd77355ada5501402d78dc294f3d3b...  0.025342      1
# 45254   a6b3d0f366abe65ea67c4c33acaea99cdd0192f41f9f8a...  0.126761      1
# 45269   22f2c34c8afa37b714abcf6f28353795ccb8215a92164a...  0.276118      1
# 45280   b9dff96a2dd686dd607abe4a7e60694b9c6fa1a7b574de...  0.239311      1
# 45454   a272c7c8e28fa804e6363fdf48b6dd97d9a2c958328587...  0.057052      1
# 45498   2ea0f3a01865829a9825422a7af31ca821496c8def9d4a...  0.040031      1
# 45595   404f6ce480fc1b41c5fcb625f7d6a68309359bcbd71f95...  0.034054      1
# 45837   2c6ef84f0621aabb8b88bb7882589a9718754cd666b4ee...  0.023087      1
# 45982   48423ca4db142f9c79eeb9f8ab0679a0d321257fc5efae...  0.270337      1
# 46054   1c280da5f89d4c5e6243722102ddc20f7ae249c17fcd49...  0.032647      1
# 46099   0c13a0054dd106ad5fb2c9c0cc9eac776fa613a0e02a54...  0.085883      1
# 46130   9bdfba3dbfa07d4c4be497378950a52adce760379dbf51...  0.168524      1
# 46292   fbc65ebdb0754a1ad0d3205f9eeb72cd6af05694bbb81f...  0.279480      1
# 46319   ace6024079d845b7dad1c7d52426e84079939f69e0959d...  0.267917      1
# 46616   2ad41224fc7f3e77b398b6e9640a2abb6b0ed274e358be...  0.158523      1
# 46805   7fe06bc4613547589aeef655870771b543cf8a1ff3b0d2...  0.026100      1
# 46889   31b59a0be5c09ab681d25c2b6f93f50a79deb073c0d1c4...  0.053472      1
# 46890   def927fa4193750b6a0c27d51753cc4949553e321616a9...  0.313295      1
# 46973   7a9cae780f9f4babcffdcded4843348e05f744d6e2b585...  0.021538      1
# 47036   a59ab6fd16e846dee3f029747e29654393e861c4d3900f...  0.048657      1
# 47041   603287dd321165b778f32f426acab27a9f5fe011803b9e...  0.018552      1
# 47306   a786b636d6a432074d1876ec9e91234255b2cc409e93d4...  0.054875      1
# 47454   5a982f074706ca5e5e3d1bccbae9c63f30bc58f1cbdb7a...  0.029934      1
# 47467   e2be2c853d6a7f84c3a2604b929da66241e710c21d1908...  0.025242      1
# 47469   25d9acd5a86851b29ba738ae4f3b0ba29f5a356c0ee100...  0.203425      1
# 47502   b7d583229119ca394e454e1cd0ed8828043378a3f2c5ba...  0.185476      1
# 47719   c4360b2ee64bba66bf21df8c9da4db10bac1a1e5b3e04f...  0.097091      1
# 47902   2ec069533be5114b0aea7165ec1ce5dc6129adaca55a69...  0.059952      1
# 47907   d58ffdbd1eb058ce4a6db6c57286efdeb015899ec45ee4...  0.295669      1
# 48013   03e2e58b8558d359aceab2029b4435a2227bce99d9ed76...  0.019227      1
# 48038   8b082d55e9ad02f49611b91d8e6ec96165673261e7f636...  0.121635      1
# 48045   5c8806bccca5f15bc7b16926de8aeaf8f1c78863c845f8...  0.090743      1
# 48265   3664a447da5557f3bafb67e829b863b7a3dcc18c336d6c...  0.018941      1
# 48568   1a6c4d0b97dde9ee5b4597be535149f361b8c93b139d29...  0.162414      1
# 48597   d53dbea42378a283f8c994120e8d4c46db4e268a391a9b...  0.217975      1
# 48705   f20a0d772d96540268d4f060ae954558468665b58c8ab7...  0.051320      1
# 48746   ee2e31c6de5ce8d147caca52a6679b76e6b4c7ec5b8e57...  0.289950      1
# 48884   54b579eecb345767aac770f336747a0ac25bd9e5b61cd9...  0.008478      1
# 48974   d57dcc5a249948006f4e89bcb0871ff8ee9cf1dbccb409...  0.064500      1
# 48986   62e7921f897e70a245934d3b6858d66e5af71d6cbfc7a7...  0.033207      1
# 49155   516a101c53cb6d5fabccc727ebbe36b8cb17e002519e35...  0.117375      1
# 49231   97c69a97ee31eaf449e3fa7818a7123eff4aaec9dc574a...  0.039116      1
# 49300   b31ab658723f54ae8c95cd5fd75f1868c608906c26959d...  0.186522      1
# 49359   92e1c860903950ba19215cce3a8d2331ae3ee9167dd0c8...  0.065245      1
# 49671   97a176011764c114367e637b9a385f38411fa85a277f22...  0.283185      1
# 49779   72b0409feb780a17d2ec79a3c69af88570a667b3a272f6...  0.003424      1
# 50025   44d230364db0321f7b9d14b389d538c2fceb3a7db6700f...  0.150257      1
# 50095   bbc7ad759a250dad1ae4c941938a2c0ed804bb81ce06da...  0.211940      1
# 50146   f404ed431c2e6602d5418c1cff6b1934928eb59d0e8a70...  0.138169      1
# 50701   7b21b1ce03f0de62deeaa2889756feed11c7914cbbdff6...  0.267553      1
# 50707   3a1deaa9d7b16f3205b1a25330c112b8583e8b8efc6e70...  0.033804      1
# 50837   2e789393c69fe7901bca718293fe165803be15993a6384...  0.016775      1
# 51082   74ed9299d2bfa9e553947138ff3fca4a18bc4b5ed8a81a...  0.034056      1
# 51102   8d7f3af4016bd41f6ea9925df1fb5b4a57fbbb85577d2d...  0.155665      1
# 51103   42d15af224125f7b641dfbbc80ab52fd80560e02e87896...  0.039359      1
# 51282   cc42e8410ab0bb44c57701aa3225a7a68db869d1cbfd39...  0.107298      1
# 51588   ff1ecb7668fd0240ef0549787848addead4c83a013aa99...  0.079758      1
# 51594   db87d8617bb00a1e0728757b26badf6152b554a0c59b5c...  0.046007      1
# 51617   88108670d90f7101f87ac55515c267e367527184cf1d45...  0.293916      1
# 51695   c599ff36560791b00a064c32cec1c6477207fef07f26dd...  0.086832      1
# 51733   def7857da252b0b26deb66cbff34b036ebe9556014eb1e...  0.093364      1
# 52104   782a772202238098d6d951845e359b736defe4916be8af...  0.147225      1
# 52118   f36f4fe386815bd124a396edb8e8926e09e39ce4478efd...  0.255009      1
# 52260   fbfb3f55edc9ae6577e7bb29ec35926912f7bd363360ac...  0.037590      1
# 52403   a7cd1c6f054d5fdd52ff02580cd38c3c37b2d2906541f4...  0.014985      1
# 52631   5e771852ecca6d130d83a7ce852c7b562bfd5469989041...  0.038249      1
# 52652   9f42017eee32531a194552f12b99d89c4762a489c01122...  0.016729      1
# 52727   4b13beed153ef52a011c61770ee27009d03e88e7b258b5...  0.185024      1
# 52955   df2a07b5865a12e502efd3c735d684f771cc52f2693355...  0.075126      1
# 53382   0dff231a4a29f4a3224d7cf604edb5ad7bf8dc68f3c0ea...  0.194938      1
# 53681   1c1d4d43a706b407a51acc56f34d90db8bcf499ca3e469...  0.301473      1
# 53695   5a703c752efb8646b1ab8e66ab7fd5e5d40325b7c61a0a...  0.224804      1
# 53716   a5a0bb05498d78299d3296910d1ac0af1d6a4bd71a84c5...  0.013607      1
# 53970   719e48c815e756d6a6022131e1006f0304831dcd445de4...  0.172976      1
# 53974   a62f1a4989d140abe41f7583956d67a1528ed8fbc8ed0a...  0.014341      1
# 54058   a8841bd001d9b84467f05af9138c5d6e7124e793254f74...  0.142760      1
# 54074   cac8a694c461df5d0c4f0c5de10fb3e0eb54efc247dd88...  0.087535      1
# 54134   685b4402d449bd121e23707e2c73086e8e598e5d1820fc...  0.017922      1
# 54514   8e292f4bd3fe7eb5ca6318e53c9d91aa79d1ce5a7b7e0b...  0.218198      1
# 54585   79a4889b0bd414eb72b65ff89e66454c2410daaad2894a...  0.031747      1
# 54685   babd0a72b76c220cd2e89dd71fb75020b28d0234f7d7bd...  0.272762      1
# 54872   61671f6d5047074722137061b557c2a7b85a9115a7366a...  0.005670      1
# 55206   a8faf9ab108aadc81b041d8c4ad05e2dcf07cc159ce9d5...  0.016272      1
# 55222   b0bc062a1eab813b1c624d205a6120f705ee5a32f8ab97...  0.025022      1
# 55294   07038ae3f9bc6d13cfba6c4f851a00d4883449861e059f...  0.083289      1
# 55328   410e1397f0d477c09119096f749f3230ec62ae200d3e65...  0.032291      1
# 55440   fc058cd5e58e916b9747256822d2d18ef6d04b307064c9...  0.038848      1
# 55482   dd836b436a26c9cc78accb9d128925ab0232988671773e...  0.002069      1
# 55492   18b5a6bc4f0e3dd5304c916ec7f4fe91879e4bc466a583...  0.024025      1
# 55706   bf29ee58703c63685886c1d2890c59cf57376a3a0623a2...  0.173478      1
# 55770   802ace595791bc169134bcf6770bd93ede62d2da7326c7...  0.225534      1
# 55979   de3efd4e590d6f94f7952d9d3d287206ecb28935b015ff...  0.112037      1
# 56000   3949b4ae44b46e04cc0da18ad0b79e689957c1ff009ace...  0.096482      1
# 56050   7ee1d493a8a6e6413ceb634a4a8b0f44ab0b64685403fc...  0.314553      1
# 56203   cb37db060a58365d4e473126a4c73d92e204b523db6a49...  0.132946      1
# 56298   a81c0b76a05f04985b5fe1e22dbc4f745cea5db550a5c0...  0.085328      1
# 56358   e707a7176093a6d24ebf8169046b949754e84f033b207f...  0.018257      1
# 56424   fa4d98352a8860891a31e3253174d058979398e204ff07...  0.037991      1
# 56452   a999eb3218dd2e8d412e8bb04e27ad06df41e78c303752...  0.020452      1
# 56594   cbf32b23b23617dc187d50ce711dfe02e7fac2f089b851...  0.010505      1
# 56666   6a94465b8a87ca1c9006b7016406821faa3abb8e0bfa9a...  0.214834      1
# 56723   6271462368e9af14c5d2cf470de07e67427e83dce45f1d...  0.026575      1
# 56829   b3386b4ee86fb6cfb536ee9395c837b3d80030f352f7da...  0.093143      1
# 56872   9d3c0f85a02e24562b67d470a986bd481d36ce00beb525...  0.291219      1
# 56937   4f9200d4902ace4b01cff557832f4004c9152f67f9ac0e...  0.220780      1
# 57013   b1e96ee888849368d99c6cb73176e7f5252d1e9b65602d...  0.010263      1
# 57232   bdeca0e3b856158b05f8eee71a15cd095ba372a4e5feee...  0.267524      1
# 57270   943dea9ffed1145274a107fd1e67d961cb2639d6675f15...  0.089514      1
# 57442   8cac6396cde423c6e42b169081438284ba1fa4adcf49e1...  0.022997      1
# 57507   d2f43733eb95832818ff02ecb340dd72190cf9a7e0f55c...  0.072507      1
# 57641   4268f151b6f1208341553a037cf395dff87a29807bd1d6...  0.013984      1
# 57666   124a572dc1c62f01b4df57d274a4ad9aea9a5485653916...  0.046679      1
# 57783   0804e512ffd7030ecc413031c22fdaa87d8e3112acd8a3...  0.016130      1
# 57829   c933cef1c420bcb97323770b4f2492ba9e62f3b545968c...  0.164150      1
# 57863   16ddfc6b314a711b8d613ccf58ed1c3402b0dddca75dd5...  0.263011      1
# 57952   e2e4a65a284b6c4304821a21f3bbb6a8d918db6e0c88fb...  0.096818      1
# 58007   1b93da205c57ec0b5d47b7b26d3ace4e746f97d1b5154e...  0.019241      1
# 58199   ae5907e9825fe283d1284881755eda14a9576a64759dcc...  0.036891      1
# 58374   2264d94b48bb875abb533ad56402fefdf861e58b4bb845...  0.302904      1
# 58468   b183ae1c3c383372597ae99094593e658694f5b28550ca...  0.074799      1
# 58683   7703864fca6958add0d5352ed9cc32ec9ad484d9155471...  0.051668      1
# 58702   47de0a57b70dd5c7bdf1b831e5afacd21096a916f0e7c5...  0.014575      1
# 58782   f05615d0be4ae13fc629dccf7c1f318b283b3655a906cc...  0.030415      1
# 58961   d8a4b170bfa3c13af6607619b54fbe2f8906ea4b65f58c...  0.230013      1
# 59128   f1133069cf465532d729613b03b85c83f877273516b074...  0.036006      1
# 59456   30813610443053f32873f52da07f81f07e4266895dbf69...  0.105446      1
# 59556   9ba60162dfb05f98a722dd757919accf252e3e8ff15b0f...  0.164676      1
# 59643   880f5aed692106f581d01232a4c7d85f334b2e583e039c...  0.190625      1
# 59845   7e3e12593eaea174763d870ec931d43aeb8a0295010910...  0.036607      1
# 59851   ef2ded49523f17808e93002a1ce90143048811cba8bb36...  0.019322      1
# 59866   aeb1492e48df875e22682c142ae3ea04e680b7a6e53caa...  0.083655      1
# 59963   a4f46c683e4f96ff382a3e2c0f1377e2a765b0ff0daf27...  0.023335      1
# 60277   ecfcc53c58ed7d343ea9329b417cf515127ea13963252e...  0.312967      1
# 60560   a26c5282b0bd7e648dbf19912e0a00327c4b0d2f04c971...  0.017878      1
# 60660   fe470315b546720a134fbf2d47446f5bc04541419f32e9...  0.022970      1
# 60773   e88f8b5a248bd67d7d0a4bb009a5af7c812e5063454e13...  0.069758      1
# 60782   84b93f6f0655753c1dea28928a81e329a7a82cb8e70c66...  0.163265      1
# 60848   d1328b1f3aeba3fb0c50b2fde341ee4d2ba6fe9aec73a4...  0.029194      1
# 60895   22033f8e48fff0379441e04c123e140fa261d8d27d86b0...  0.012329      1
# 60967   49bda45e0f0971d5c647d03aace6ea38777c2bda8a5f21...  0.044664      1
# 61085   923493429d4afb99e85031d8ed4d9a9dc90e8fedd8454c...  0.177618      1
# 61134   61a426e1855a74ec9161d46cc353232a4dcf5b2b6b8311...  0.172999      1
# 61142   b1adbd136d76a1a9843050c63d00f9449865b6c25bb734...  0.085110      1
# 61159   329c15e238eadb6005994b911a793495c6201a57f21a64...  0.011259      1
# 61203   431f55cd93cbb9930003a4dad981e8d7b3ec87baf35663...  0.052630      1
# 61204   7de487db9eff64159740f6cf79594bc684ad02e70b6f18...  0.249781      1
# 61225   b3d77832540933398a122026d8ce79e9815dc0de31ce85...  0.023028      1
# 61246   1d320e88e338f79b175b73b625772fa3ae50788a139c2b...  0.322022      1
# 61275   ec1f752d336c9d3dc7e991be57b013a8273c33f7344dc1...  0.198459      1
# 61341   fe199d20e32d27091a71b67be2512df7a610e10b16999b...  0.021793      1
# 61344   f0f7cca2c9e3b45155adc59fb99d6b891cf692957f135c...  0.000473      1
# 61546   7f2104680280cedbfe3b6e46ab0f6bdd1e0c056c7ce788...  0.038969      1
# 61624   4685be56ae86e912def407e7871b7f4aa82dd66d322a8b...  0.012815      1
# 61635   81cdb725c4e98bd965e69ba745423bd3aada711e8323e4...  0.009313      1
# 61665   2e5fe5bfbd385b035468e8d75ac94fec64fdd10de3e45b...  0.032347      1
# 61673   7a0aea32ddc7bb756bb28de58b77d19593023d689fe86e...  0.088367      1
# 61686   9938cdc44158327b23d9c43ded9f021be8713c2c77ffb7...  0.116976      1
# 61711   5f837c31982736362ee5b1ecae10200206710c9bb28aca...  0.001572      1
# 61793   a8fde3b2cf64db3b76ced997fea0cac8a9fe81e220b9ec...  0.206192      1
# 61831   aa4c77ef78e2aa607fdcb93836166fe4d603687c2c4bc8...  0.103720      1
# 61843   f10cf4231060d946c96b84b3d3217a96cd863aa3a5a4f5...  0.312114      1
# 61885   082cb0632e4778031427316ab7ad020543466af79c7ad1...  0.165790      1
# 62156   5b8da1c3c55662788c17f4d2741b5fa87c3c6461cde5b7...  0.047779      1
# 62280   58a46a9b5433edd27999926c60fe0fc1e1fb4287c99f20...  0.021181      1
# 62379   17e76f0511bb8e2ba0dc31957053e52921e1863bcbc022...  0.030665      1
# 62404   3a67d47ebfdd63bfb6664a1fae74918ae0654f338428b7...  0.017823      1
# 62486   f706c0b727269174eab4121e5af9ef15b275d3164172b9...  0.041185      1
# 62560   59adad3f85de7301dd80f9231883b0fe9292888fad8da6...  0.020607      1
# 62645   4f379c48a95dfea8b1853d3c0432d4d08e3d904e8b51c5...  0.089475      1
# 62649   7ec53d3df60daaf3d9e2d4f80ed757e1899dba78b5fe1b...  0.219329      1
# 62856   62e2d9ec891896b758395cfeb05e8f8b051103fd591f8a...  0.047717      1
# 63199   263790c9d13ffd0cfb41837aae721a4600baae4c49a080...  0.303882      1
# 63210   17950332afb822f1c8900acf611214ab4428e7cef6fab4...  0.104128      1
# 63290   c1bb678ba6fb0dac1715ed0404ccf474174c0c9cc01931...  0.181383      1
# 63760   72854eabfa7f4d2014d124d656cbe807c283f1e693641d...  0.013984      1
# 63782   70fdb18f1e4ffba3c7588c2db490fd5a84adb0f12c163a...  0.188425      1
# 63810   10f4653926f6fed9ee9d9698654b6c58b54447667acd68...  0.233606      1
# 63870   3ddfe02b56b6c19f9f8c39d481e7d8b64db5534d74cf22...  0.038312      1
# 63914   6fe41b5cd00ae908fa535c1a2b89fb5158e134dee038aa...  0.056565      1
# 63938   2f5a2dd470e4155eeed9669ab9d3b85647ab4d9f815d8b...  0.131719      1
# 63999   908ef8ff4aff5a8bb277a6c2f98f3ea503a569ac5655a3...  0.012657      1
# 64108   c5f05aed66677c185736e96e419c00f661eddbea3d5b55...  0.004411      1
# 64164   5269a575c052aea665475eded6cc2044cdb0dd4003a45b...  0.035964      1
# 64256   97b3e7b9d05e19fb82d16209529f2c0434186d30b668d1...  0.322882      1
# 64297   19a839cd5c080722e2ba8a1f4f29a3a9e29600dcaba6ed...  0.279324      1
# 64637   16a97bff6db80e76b0bc3f2271d66772213dfb6943ba6f...  0.015584      1
# 64639   f431b3f94c89b85ba829a1b10214c0d226d36a20715a25...  0.317782      1
# 64729   c987629ba091f5e0cbda9382b26037529535b79691015d...  0.208526      1
# 64733   523e76f0a92b5dbf5fb18f524a312e6251ccf5e846449f...  0.195583      1
# 64811   392907c82109cb343bc87048cf79ec69e1f611d482bf30...  0.083712      1
# 64902   332efd29fc4e05cbfbd52645e5a13d12c68f879d1f1a31...  0.015503      1
# 65380   8e17569df43306daabe511edd239fa744e5ca5d8438f98...  0.029543      1
# 65520   341fe608c53f08172b8119a7515c67ebf2c29565850ee1...  0.242462      1
# 65570   f53117b750dc37d205170e5a6163b96093cf693e2fbf28...  0.029376      1
# ...                                                   ...       ...    ...
# 121919  6dc78ccfdb5d6c0878443959dd4520396b5958c83f276a...  0.003258      1
# 122072  76ff3e3420c0d2c77dfcb15e5dab2ade86ef751871fd19...  0.089247      1
# 122369  a029097123d77f18605b3cd89b7b706b136f9fa4f4d672...  0.306916      1
# 122620  74f9e14230df76308b7eae63199eebe4b29ef93d3a7f3c...  0.026000      1
# 122669  010fe3f7bb4af500504043e41574a3e1cdd38ca52b49a5...  0.104715      1
# 122679  5e67d9af6e17c0d6458413058f825697915230214c897e...  0.159130      1
# 122792  fbd963bdee2e548448acfe5d91356349ee09bddfa271e7...  0.013112      1
# 122869  386c7a7c40f5b3c330b004e8a305bf088dbf3c4856a1d4...  0.015990      1
# 123256  f0503372ed9fb223b70c87dbb85db242d32e0f1bc0ca3e...  0.098521      1
# 123346  be7c4d1a8ed67de8b7c3b13a50cfd34a4c090ecf385623...  0.139490      1
# 123738  5b6aa3bc753c40bd598476a2393947a93891f2b12fe35e...  0.298063      1
# 123950  1b0d74646b4f51bc55e40c04f972baa90aea221d0affc2...  0.064989      1
# 124239  42caafb38ee3b0432841099d5e581e480dc1ddc37ed0d8...  0.001666      1
# 124389  69a5d1d2c493b8c6f183ed9c97096051cdece0443ee978...  0.035161      1
# 124427  cf38c685959abff9cf28c9ad461d2750960d0547bc147b...  0.053026      1
# 124513  54d7adfc10a7df4c4600513729d98a4db0fb0e152c2b12...  0.007278      1
# 125397  8efa1f359288dfd1c2de0d516b30cfa0a2a26b1e2e786c...  0.052564      1
# 125559  0c1072a6e64b7cc7f9dd32347d8aea601ea9dd7838fa84...  0.044346      1
# 125660  e03c739955cf40d6ae3d25ec3d17b92197ab9387959e9a...  0.301630      1
# 125702  e31b2de2fee368b371f28244ae04b2b609f5246f8c4d62...  0.139753      1
# 126262  d76efc583a487e4eb3dabc2f9ebe49f3f068adbad96a44...  0.014355      1
# 126282  e504d5783a621322fae8df2379a2899ec397cc8b8c969a...  0.019196      1
# 126309  a55b6daa5e7a8b293a0cd6a6bfea389e53a96085ba8357...  0.293490      1
# 126326  e02dfcbc4685a31194f5f0e64efca3b942f04dd4ff08fc...  0.152646      1
# 126349  794a01577d9ffe739da842de1d7e2be5a80b42b1a6e53c...  0.022178      1
# 126801  553116685275e04311cde4550f6e9ab08a4aafc8caf8bd...  0.262300      1
# 126968  c9f23380660c4acfdfe5eb2c17a4ac164700eaffcb8d04...  0.022908      1
# 127024  06f6d440e34286a04417e8018adeacf995f7d9a607b8d0...  0.299637      1
# 127178  e56aaf51b5bb6e2c1eedff3e4b333247111805f4051ceb...  0.002792      1
# 127309  5c7253416c16be67df7afc8abcd1d498044e5be7346fb2...  0.286804      1
# 127561  4197b1d36ebd95905d87f9f377a7ec0348e04c812aac5c...  0.132574      1
# 127695  a3d9e2c583945791e329d2d33851521d2251a44a5648e6...  0.112490      1
# 127715  af453670b779e60e28449341911cc36a472a9388e04658...  0.318586      1
# 127836  99370a93b3f15cb32a0f2d67eb880c420d29f835f88263...  0.012302      1
# 127942  fe683ffcb994025a2167e165d1f38f6293f852318a6d4e...  0.011318      1
# 128074  0f21e7cb20927867a4dd0de6f5167e3b8eb4a90a2d6747...  0.005716      1
# 128255  22b0ec8fe39c9be2d92a88b657cbd8e7917c76f73683ff...  0.170871      1
# 128288  8c970632c2b699ccb8f49417f16367602a8b37623e7507...  0.031505      1
# 128312  4dadfe31fb1f0266920b25ed4f99c5912a1163464bbc56...  0.238478      1
# 128313  9fc9d57eb5fba003bbd6c1f951f6699a5b4943d86d0f43...  0.000954      1
# 128332  70ef8b47fa58c96cfd83d35883aef4883e0c5bef74360f...  0.015525      1
# 128358  a749b21bb1dd4eb0250fd64baa4bb631c8fcd9239a4cf6...  0.017075      1
# 128619  1c7ec069994ee7e92190be1d558ad9cbd06f006d24399e...  0.128159      1
# 128833  4df3375ec200e25cb558ec181931351c7ce5e8b510e9fa...  0.091878      1
# 129133  eaae9a5affbf60474c122cf79fcba72c6931e00a9cf5cc...  0.012845      1
# 129170  191857d5f8af96ba990d076ba6ea5b838b8786aa3bbbc1...  0.190219      1
# 129219  90e5c73befc9e490c611326c3644d7c08877e9ff68daca...  0.013951      1
# 129462  6f78c420d0c50a8e63d657c8d6941e3d27f1fc2fb76bfa...  0.193467      1
# 129601  471961f143c1c467595262b4ee31b8127dc83661612175...  0.225780      1
# 129603  c3922aaad4b4a07a0ba9144d6567cda3bc6b6bd47d1459...  0.273354      1
# 129893  e7537808dde3ae601fddc152a4877c943cc2cfed1eb5d1...  0.257006      1
# 130145  c1f015f1501afed9cee5f19f8c9c370b6a448601f3205a...  0.082030      1
# 130160  85b0d6dfba679541801bf7779085f344aa33e2b8e0f22a...  0.079791      1
# 130276  1b8fc22a6c37965726e0440f5c915c51e1bc3f284ea85c...  0.008585      1
# 130334  0e52ed45da422aa804a6346def92b1580dd0a81a6d5951...  0.038327      1
# 130665  b8a1d7c59808ddc1a90a7be80ea5d662b1948ea085e569...  0.060414      1
# 130842  6209b5523591ec9462e4d667cf55ebca51806d75520943...  0.269209      1
# 131262  2b5ee749157cf8f7624bf2d7dfd902ce792b47203977ed...  0.057231      1
# 131665  2469f76a7a4662c1b9f7c3902b3b304cee3a456d175b2a...  0.185229      1
# 132036  fdbc99b502cb15ad35297af1170c825f94a24c0c899fde...  0.026382      1
# 132339  a5230a77ad793811404929acbc08577f64e09a565dfd86...  0.000758      1
# 132533  a3adb1fae9f461ad95c023997c123082411a91deb25a3e...  0.293755      1
# 132544  58f7056eef223eb2ed8e96afe915341ce6c7880c801e01...  0.107300      1
# 132908  bc7d08c6bfa431ca8c27b7970d8e3907a126a3b16a4656...  0.159151      1
# 133020  f06e8f406a88e12ceb4a90072304d6b3910d1afe751311...  0.028237      1
# 133528  ab1d005804f6b80cc1c58e86c4c7c2aed0b53aeee160ba...  0.123898      1
# 133605  8c9b330cff165cef0421206344a167ce19ecf29d9b5860...  0.045316      1
# 133708  dde843cd94e4c99e444ec799e6f4933c5bf82d2ef6609e...  0.259359      1
# 133991  8531bad42f081d1a6383c3aa25068d16e9b7909cee7d32...  0.016835      1
# 134023  88dc51af6a2d0fb600a8b96e09cff2cb4241af9841f9af...  0.198588      1
# 134038  27dff795695cf20ab08f8ac5b5d1dec4dab8c44449cd25...  0.002005      1
# 134130  f1477305b7be7c759c4c38f990bfaa9bb7d3b1847852ea...  0.183801      1
# 134670  27f1987c6cc72080b93443070581a2fba65b5b1756c46f...  0.086057      1
# 134737  ece842dadfd96ea91299bdb99458c2e7df747b0e908987...  0.063736      1
# 134745  3558bb5aa0c891e0eb5ad08ef01d05069ea33933842c55...  0.245169      1
# 135052  d9e4436f640c78aeab2259e8bae165720e9771970d0f1f...  0.272663      1
# 135077  9b8b540ea5c3741e07d9663078a09db51edd3da4d2086a...  0.039555      1
# 135108  53b0f03838468846497c6bd095ffc2f1d68d6fb69fe74a...  0.002796      1
# 135235  f29900592a827aa4e89c6947677c9781221d7237ff6d36...  0.075941      1
# 135484  69eb0a3192af23889758ae5b9374ed723be80723cf4a2b...  0.105997      1
# 135517  eb4d658a7d5b057ce9ad8b32c1ddc5e1b91ce9d4815177...  0.103992      1
# 135612  d557ba51ae4c4267213aa6ad954e87619e0b448c9aa61b...  0.204432      1
# 135924  068eeaf735cbacdda2b0ff010b6a1bbf67ccbf340434da...  0.318268      1
# 136046  2e15f57965fa1d2416ca13cb10b0c488ea996b993c4957...  0.125840      1
# 136109  4ec3666b59f8a336902781975c919dc9bb7265cb9d60c9...  0.079135      1
# 136111  6d8f4949c0641d63d38a11dd2cc6a6f7a5c8dd1f1d4c15...  0.031125      1
# 136195  3da53ac1ce531ae4f2815c58924d0cc8978d2cbcbbc983...  0.227927      1
# 136284  0aef7d22296ed9b8cee18d99e26b1a71eb7ef0ec110064...  0.003325      1
# 136397  0aa3bfa01d50ffd965fb833813ecf20f179692cd83e9a9...  0.274867      1
# 136433  ccb259348241b8d32d12661f807b38c3c63c815f1302eb...  0.210219      1
# 136466  4bb10539e63188a0f238bf947996d6e581eee891c2a86d...  0.142220      1
# 136467  53a11a552e2de334fe94fcf863b73b2a6ed2af76248fc5...  0.303465      1
# 136631  7b8265061499e6243548466982278ba0dcd27e4ab366d3...  0.002850      1
# 136728  50367d2d7a7e3fd8478de00b54cebc94569acf64df477b...  0.148872      1
# 136964  e7c92d4c0e09b84083bbf08e8ab8860b3b2f9a1df702bd...  0.320860      1
# 137003  015eee8ff188c5071ec89c2bbf8f7ad833003ccfb294aa...  0.132850      1
# 137149  2430e28851b2f046433a8ab7eb033cff634174cdb57f65...  0.250940      1
# 137232  c7a988d36a930332c3d1b460c9fc732a49a6566b46e962...  0.003596      1
# 137362  67053cb8b44bba83b29048df1d0305a45f1fff0ad14bca...  0.223008      1
# 137439  3a8e92d461c88f58f81242593d5f8b481315086c8e06c3...  0.202531      1
# 137543  39212c4eeda435d60ade45892ad4d31531514ffd2e7c23...  0.029899      1
# 138057  34130f73a3c0d7e13ae6350c09ad8981d29bc5e86b4339...  0.210952      1
# 138714  f75c55e790c1112c866b62cb9c9ba4c66d7f70fe15306a...  0.240760      1
# 138753  19932c89f93093f08a30e1e692d885741896bfb1e261c5...  0.136236      1
# 138956  411e08cf4c3ff12979a54e6ddf24d0042552cf659f5044...  0.132182      1
# 139624  927954b2553bb73c44a67008ae6cc9c114a595ddc762a3...  0.269378      1
# 139649  e338495e48e2fdb489f875a82a7f2f1a6b48b1458a8061...  0.264178      1
# 139788  56b828bfa7e79a30a97145f67a2566146a92534918e102...  0.273536      1
# 140003  bc925f3dbb9b620809531310b2faa78c7f966852a79ab1...  0.003248      1
# 140144  cc8058b2827ede630a97a39ca2301ad862bcf52c5dd6c9...  0.294984      1
# ...
# 135517     7           0          0
# 135612     7           0          0
# 135924     7           0          0
# 136046     7           0          0
# 136109    10           0          0
# 136111     7           0          0
# 136195     7           0          0
# 136284     7           0          0
# 136397     9           0          0
# 136433     7           0          0
# 136466     7           0          0
# 136467     0           0          0
# 136631     8           0          0
# 136728     7           0          0
# 136964     7           0          0
# 137003     2           0          0
# 137149     0           0          0
# 137232     7           0          0
# 137362     7           0          0
# 137439     7           0          0
# 137543     7           0          0
# 138057     7           0          0
# 138714     1           0          0
# 138753     7           0          0
# 138956     7           0          0
# 139624     7           0          0
# 139649     2           0          0
# 139788     7           0          0
# 140003     7           0          0
# 140144     7           0          0
# 140156     0           0          0
# 140346     7           0          0
# 140401     0           0          0
# 140518     7           0          0
# 140628     7           0          0
# 140768     7           0          0
# 140780     7           0          0
# 140919     0           0          0
# 141015     0           0          0
# 141038     7           0          0
# 141130     5           0          0
# 141168     7           0          0
# 141170    10           0          0
# 141324     7           0          0
# 141357     7           0          0
# 141430     7           0          0
# 141868     8           0          0
# 142021     0           0          0
# 142138     0           0          0
# 142170     7           0          0
# 142278     7           0          0
# 142631     7           0          0
# 142845     0           0          0
# 142860     9           0          0
# 143173     7           0          0
# 143279     7           0          0
# 143376     7           0          0
# 143442     7           0          0
# 143470     5           0          0
# 143487     5           0          0
# 143856     7           0          0
# 143903     2           0          0
# 143911     7           0          0
# 143943     0           0          0
# 144146     2           0          0
# 144168     2           0          0
# 144261     2           0          0
# 144274     7           0          0
# 144368     0           0          0
# 144748     7           0          0
# 144831     2           0          0
# 145039     8           0          0
# 145123     1           0          0
# 145774     7           0          0
# 145846     7           0          0
# 146379     0           0          0
# 146424     0           0          0
# 146569    11           0          0
# 146582     9           0          0
# 146665     7           0          0
# 146781     0           0          0
# 146891     9           0          0
# 147246     7           0          0
# 147253     0           0          0
# 147480     7           0          0
# 147487     7           0          0
# 147647     0           0          0
# 147803     0           0          0
# 147869     8           0          0
# 148054     5           0          0
# 148057     7           0          0
# 148107     5           0          0
# 148352    11           0          0
# 148482     0           0          0
# 148690     7           0          0
# 148778     7           0          0
# 148814     0           0          0
# 148892     7           0          0
# 149056     7           0          0
# 149098     7           0          0
# 149218     7           0          0
# 149400     7           0          0
# 149452     7           0          0
# 149527     0           0          0
# 149701     7           0          0
# 149858     7           0          0
# 149971     7           0          0
# 150010     2           0          0
# 150079     7           0          0
# 150180     7           0          0
# 150288     7           0          0
# 150677     9           0          0
# 150903     7           0          0
# 150931     7           0          0
# 151016     0           0          0
# 151278     0           0          0
# 151728     7           0          0
# 151821     2           0          0
# 152220     7           0          0
# 152360     0           0          0
# 152627     0           0          0
# 152640     7           0          0
# 152808    11           0          0
# 152886     7           0          0
# 153056     7           0          0
# 153171     7           0          0
# 153372     7           0          0
# 153651     0           0          0
# 153807     7           0          0
# 154276     7           0          0
# 154364     0           0          0
# 154456     7           0          0
# 154505     7           0          0
# 154549     7           0          0
# 154704     7           0          0
# 154738     7           0          0
# 154848     0           0          0
# 155193     7           0          0
# 155234     7           0          0
# 155329     7           0          0
# 155330     7           0          0
# 155358     7           0          0
# 155368     7           0          0
# 155413     7           0          0
# 155436     0           0          0
# 155457     7           0          0
# 155589     7           0          0
# 155627     7           0          0
# 155742     7           0          0
# 155826     0           0          0
# 156115     7           0          0
# 156152    11           0          0
# 156326     7           0          0
# 156608     7           0          0
# 156803     5           0          0
# 156805    11           0          0
# 156880     7           0          0
# 156929     2           0          0
# 157090     7           0          0
# 157215     0           0          0
# 157396     7           0          0
# 157506     7           0          0
# 157593     7           0          0
# 158438     7           0          0
# 158448     7           0          0
# 158551     0           0          0
# 158862     0           0          0
# 159207     0           0          0
# 159364     7           0          0
# 159372     7           0          0
# 159386     7           0          0
# 159939     0           0          0
# 160426     7           0          0
# 160452     7           0          0
# 160513     2           0          0
# 160557     0           0          0
# 160682     0           0          0
# 160745     2           0          0
# 160872     8           0          0
# 161412     7           0          0
# 161417     7           0          0
# 161546     7           0          0
# 161674     2           0          0
# 161897     7           0          0
# 161915     0           0          0
# 162155     7           0          0
# 162241     7           0          0
# 162295     2           0          0
# 162505     7           0          0
# 162549     6           0          0
# 162572     0           0          0
# 162708     9           0          0
# 162810     7           0          0
# 163337     0           0          0
# 163423     7           0          0
# 163427     0           0          0
# 163475     7           0          0
# 163782     0           0          0
# 163794     0           0          0
# 163872     7           0          0
# 164056     0           0          0
# 164432     7           0          0
# 164463     0           0          0
# 164616     0           0          0
# 164646     7           0          0
# 164674     2           0          0
# 164941     7           0          0
# 165338     0           0          0
# 165411     5           0          0
# 165735     7           0          0
# 165988     7           0          0
# 166086     7           0          0
# 166152     7           0          0
# 166218     2           0          0
# 166340     0           0          0
# 166820     0           0          0
# 167242     0           0          0
# 167328     7           0          0
# 167347     7           0          0
# 167448     7           0          0
# 167637     2           0          0
# 167862     7           0          0
# 167927     7           0          0
# 168012    10           0          0
# 168274     0           0          0
# 168432     2           0          0
# 168681     7           0          0
# 168835     7           0          0
# 168933     0           0          0
# 168983    10           0          0
# 169009     7           0          0
# 169307     7           0          0
# 169308     7           0          0
# 169310     7           0          0
# 169337     0           0          0
# 170386     2           0          0
# 170655     7           0          0
# 170776     7           0          0
# 170940     3           0          0
# 171122    10           0          0
# 171160     7           0          0
# 171221     7           0          0
# 171302     0           0          0
# 171836     7           0          0
# 171933     2           0          0
# 172100     7           0          0
# 172184     7           0          0
# 172205     2           0          0
# 172280    14           0          0
# 172494     7           0          0
# 172712     7           0          0
# 172958     7           0          0
# 172976     7           0          0
# 173105     0           0          0
# 173173     0           0          0
# 173321     2           0          0
# 173493     7           0          0
# 173548     7           0          0
# 173592     7           0          0
# 173617     7           0          0
# 173831     2           0          0
# 173881     7           0          0
# 173922     7           0          0
# 174212    11           0          0
# 174628     0           0          0
# 174629     2           0          0
# 174643     7           0          0
# 174647     2           0          0
# 174805     8           0          0
# 175818     2           0          0
# 175917     0           0          0
# 176057    10           0          0
# 176066     7           0          0
# 176425     7           0          0
# 176432     7           0          0
# 176646     7           0          0
# 176683     7           0          0
# 176718     7           0          0
# 176972     7           0          0
# 177246     7           0          0
# 177464     7           0          0
# 177596     1           0          0
# 177955     7           0          0
# 178256     7           0          0
# 178267     7           0          0
# 178289     7           0          0
# 178433     7           0          0
# 178482     7           0          0
# 178492     0           0          0
# 178502     7           0          0
# 178641     7           0          0
# 178666     2           0          0
# 178757     2           0          0
# 178836     7           0          0
# 178928     2           0          0
# 178967     0           0          0
# 179088     7           0          0
# 179138     0           0          0
# 179495     2           0          0
# 179973     7           0          0
# 179979     7           0          0
# 180179     0           0          0
# 180248     7           0          0
# 180285     7           0          0
# 180289     7           0          0
# 180526     7           0          0
# 180538     5           0          0
# 180572     7           0          0
# 180603     7           0          0
# 180683     7           0          0
# 180903     7           0          0
# 180959     7           0          0
# 181262     7           0          0
# 181281     0           0          0
# 181460     7           0          0
# 181508     0           0          0
# 181515     7           0          0
# 181627     7           0          0
# 181756     0           0          0
# 181790     7           0          0
# 182290     7           0          0
# 182565     7           0          0
# 182629     7           0          0
# 182766     7           0          0
# 182802     7           0          0
# 183294     1           0          0
# 183333     0           0          0
# 183473     0           0          0
# 183865     0           0          0
# 183962     7           0          0
# 184272     0           0          0
# 184505     0           0          0
# 184534     2           0          0
# 184559     7           0          0
# 184833     0           0          0
# 184922     7           0          0
# 185125    10           0          0
# 185255     0           0          0
# 185279     5           0          0
# 185706     0           0          0
# 185795     7           0          0
# 185961     0           0          0
# 185969     7           0          0
# 186004     0           0          0
# 186447     0           0          0
# 186540     7           0          0
# 186713     9           0          0
# 187104     7           0          0
# 187160     0           0          0
# 187235     7           0          0
# 187415     0           0          0
# 187559     7           0          0
# 187676     0           0          0
# 187706     0           0          0
# 187810     0           0          0
# 187872     7           0          0
# 187873     7           0          0
# 187963     7           0          0
# 187964     0           0          0
# 188088     2           0          0
# 188248     0           0          0
# 188847     7           0          0
# 188988     5           0          0
# 188997     0           0          0
# 189076     0           0          0
# 189375     0           0          0
# 189413     5           0          0
# 189641     0           0          0
# 189757     7           0          0
# 189971     0           0          0
# 190004     7           0          0
# 190109     7           0          0
# 190161     7           0          0
# 190421     2           0          0
# 190439     0           0          0
# 190530     0           0          0
# 190559     0           0          0
# 190598     7           0          0
# 190869     7           0          0
# 190924     7           0          0
# 191139     7           0          0
# 191338     7           0          0
# 191479     7           0          0
# 191555     9           0          0
# 191746     7           0          0
# 191920     7           0          0
# 192297     0           0          0
# 192690    13           0          0
# 192837     7           0          0
# 192941     7           0          0
# 193208     5           0          0
# 193278     7           0          0
# 193314     7           0          0
# 193450     0           0          0
# 193505     0           0          0
# 193519     0           0          0
# 193919    14           0          0
# 193982     9           0          0
# 194522     2           0          0
# 194691     7           0          0
# 194750     7           0          0
# 194977     0           0          0
# 195127     0           0          0
# 195340    11           0          0
# 195637     2           0          0
# 195737     0           0          0
# 195838     7           0          0
# 195930     7           0          0
# 196370     0           0          0
# 196374     7           0          0
# 196545    11           0          0
# 196858     7           0          0
# 197296     7           0          0
# 197323     0           0          0
# 197529     0           0          0
# 197533     0           0          0
# 197553     0           0          0
# 197588     0           0          0
# 197682     5           0          0
# 198317     0           0          0
#
# [1456 rows x 6 columns]

# %% [markdown]
# #### add weights depending on cate (failed)

# %%
data = pd.read_csv("atec_anti_fraud_train.csv",parse_dates=['date'], dtype = dtype)
data = data.merge(train_cate, how='inner', on='id')
data = data[['id', 'label', 'cate']]

tmp1 = data[data['label']==0].groupby('cate').id.count()
tmp2 = data[data['label']==1].groupby('cate').id.count()

df_tmp = pd.concat([tmp1,tmp2],axis=1).fillna(0)
df_tmp.columns = ['total', 'num_positive']

df_tmp['cate'] = df_tmp.index
df_tmp['weight'] = df_tmp['num_positive']/df_tmp['total']
df_tmp['weight'] = df_tmp['weight']/df_tmp['weight'].sum()

pred_valid_withWeight = pd.merge(valid_pred, df_tmp, how='left', on='cate')
pred_valid_withWeight['weighted_score'] = pred_valid_withWeight.score.multiply(pred_valid_withWeight.weight)

print('Final score of validation is {}'.format(my_score1(valid.label.values, pred_valid_withWeight.weighted_score.values)))

# %%
pred_valid_withWeight['weighted_score'] = pred_valid_withWeight.score

pred_valid_withWeight.loc[pred_valid_withWeight.cate==7,'weighted_score'] = pred_valid_withWeight.loc[pred_valid_withWeight.cate==7,'weighted_score']
pred_valid_withWeight.loc[pred_valid_withWeight.cate==0,'weighted_score'] = pred_valid_withWeight.loc[pred_valid_withWeight.cate==0,'weighted_score']

# %%
print('Final score of validation is {}'.format(my_score1(valid.label.values, pred_valid_withWeight.weighted_score.values)))
# Out:
# Final score of validation is 0.268939171319424

# %% [markdown]
# #### just focus on category 7

# %%
train_cate = pd.read_csv("obj/id_cate_train.csv")
data = pd.read_csv("atec_anti_fraud_train.csv",parse_dates=['date'], dtype = dtype)
data.loc[data['label']==-1,'label'] = 1
data = process_dates(data, 'date')
data = data.merge(train_cate, how='inner', on='id')
data.sort_values('date',inplace=True)

# %%
temp = data[data['cate']==7].head(1)\
    .drop(['id','label','date', 'cate', 'Day', 'Dayofweek', 'Is_month_end', 'Is_month_start'], axis=1).values[0]
temp_list = list()
for j in range(297):
    if np.isnan(temp[j]):
        temp_list.append(0)
    else:
        temp_list.append(1)

feature_list = list()
for i in range(297):
    if temp_list[i]:
        feature_list.append('f{}'.format(i+1))

# %%
valid = data.iloc[data.shape[0]*4//5:,:][['id','label','date', 'cate', 'Day', 'Dayofweek', 'Is_month_end', 'Is_month_start']+feature_list]
data = data.iloc[:data.shape[0]*4//5,:][['id','label','date', 'cate', 'Day', 'Dayofweek', 'Is_month_end', 'Is_month_start']+feature_list]
valid = valid[valid['cate']==7]
#data = data[data['cate']==7]

# %%
# initialize the predictions
valid_pred = np.zeros(valid.shape[0])

# %%
# set up the parameters
params = {'max_depth': 5, 'eta': 0.009, 'silent': 1, 'objective': 'binary:logistic'}
params['nthread'] = 4
params['eval_metric'] = ['logloss','auc']
params["scale_pos_weight"] = 2
params["subsample"] = 0.5
params["colsample_bytree "] = 0.5
num_rounds = 10000
early_stopping_rounds = 200

# set up the random seed for testing
params["seed"] = 6

xgtrain = xgb.DMatrix(data.drop(['id','date','label','Day','cate'],axis=1).values, data.label.values)
xgvalid = xgb.DMatrix(valid.drop(['id','date','label','Day','cate'],axis=1).values, valid.label.values)

evallist = [(xgtrain, 'train'), (xgvalid, 'valid')]
bst = xgb.train(params,
                xgtrain,
                num_rounds,
                evallist,
                # feval=my_score3,
                early_stopping_rounds=early_stopping_rounds)
# # save the model
# bst.save_model('model_log/single_1/0001.model')

valid_pred += bst.predict(xgvalid, ntree_limit=bst.best_iteration)

print('Final score of validation is {}'.format(my_score1(valid.label.values, valid_pred)))
# pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0003.csv', index=False)
# Out:
# [0]	train-logloss:0.684848	train-auc:0.874014	valid-logloss:0.686086	valid-auc:0.808284
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 200 rounds.
# [1]	train-logloss:0.676695	train-auc:0.874631	valid-logloss:0.679138	valid-auc:0.811398
# [2]	train-logloss:0.668684	train-auc:0.874739	valid-logloss:0.672319	valid-auc:0.814056
# [3]	train-logloss:0.660814	train-auc:0.886912	valid-logloss:0.665545	valid-auc:0.822289
# [4]	train-logloss:0.653086	train-auc:0.886881	valid-logloss:0.658985	valid-auc:0.82283
# [5]	train-logloss:0.645485	train-auc:0.887078	valid-logloss:0.652497	valid-auc:0.823653
# [6]	train-logloss:0.638013	train-auc:0.888848	valid-logloss:0.646004	valid-auc:0.826896
# [7]	train-logloss:0.63066	train-auc:0.888533	valid-logloss:0.639737	valid-auc:0.825335
# [8]	train-logloss:0.623428	train-auc:0.888684	valid-logloss:0.633567	valid-auc:0.825992
# [9]	train-logloss:0.616321	train-auc:0.888851	valid-logloss:0.627465	valid-auc:0.825642
# [10]	train-logloss:0.609333	train-auc:0.88924	valid-logloss:0.621444	valid-auc:0.827442
# [11]	train-logloss:0.602453	train-auc:0.890999	valid-logloss:0.615506	valid-auc:0.827312
# [12]	train-logloss:0.595686	train-auc:0.890779	valid-logloss:0.60973	valid-auc:0.826895
# [13]	train-logloss:0.589032	train-auc:0.890906	valid-logloss:0.604008	valid-auc:0.827439
# [14]	train-logloss:0.582484	train-auc:0.89092	valid-logloss:0.598365	valid-auc:0.827081
# [15]	train-logloss:0.576031	train-auc:0.890931	valid-logloss:0.592814	valid-auc:0.827367
# [16]	train-logloss:0.569679	train-auc:0.891042	valid-logloss:0.587358	valid-auc:0.826834
# [17]	train-logloss:0.563433	train-auc:0.891036	valid-logloss:0.581981	valid-auc:0.82671
# [18]	train-logloss:0.557284	train-auc:0.891092	valid-logloss:0.576744	valid-auc:0.82707
# [19]	train-logloss:0.551227	train-auc:0.891066	valid-logloss:0.571478	valid-auc:0.827085
# [20]	train-logloss:0.545266	train-auc:0.891108	valid-logloss:0.566335	valid-auc:0.827159
# [21]	train-logloss:0.539401	train-auc:0.891146	valid-logloss:0.561322	valid-auc:0.827502
# [22]	train-logloss:0.533615	train-auc:0.891113	valid-logloss:0.556375	valid-auc:0.826985
# [23]	train-logloss:0.527915	train-auc:0.891148	valid-logloss:0.551522	valid-auc:0.827186
# [24]	train-logloss:0.522308	train-auc:0.891181	valid-logloss:0.54678	valid-auc:0.827478
# [25]	train-logloss:0.516781	train-auc:0.891147	valid-logloss:0.542045	valid-auc:0.827237
# [26]	train-logloss:0.511335	train-auc:0.890989	valid-logloss:0.537414	valid-auc:0.827241
# [27]	train-logloss:0.505974	train-auc:0.890971	valid-logloss:0.532869	valid-auc:0.827509
# [28]	train-logloss:0.500685	train-auc:0.891168	valid-logloss:0.528276	valid-auc:0.827551
# [29]	train-logloss:0.495468	train-auc:0.891157	valid-logloss:0.523843	valid-auc:0.827772
# [30]	train-logloss:0.490335	train-auc:0.891018	valid-logloss:0.519471	valid-auc:0.82809
# [31]	train-logloss:0.485279	train-auc:0.891165	valid-logloss:0.515111	valid-auc:0.827909
# [32]	train-logloss:0.480293	train-auc:0.891191	valid-logloss:0.510888	valid-auc:0.828408
# [33]	train-logloss:0.475379	train-auc:0.897421	valid-logloss:0.506677	valid-auc:0.82711
# [34]	train-logloss:0.470533	train-auc:0.900389	valid-logloss:0.502532	valid-auc:0.828955
# [35]	train-logloss:0.465757	train-auc:0.900376	valid-logloss:0.498468	valid-auc:0.8293
# [36]	train-logloss:0.461043	train-auc:0.900455	valid-logloss:0.494378	valid-auc:0.829151
# [37]	train-logloss:0.456398	train-auc:0.900436	valid-logloss:0.490411	valid-auc:0.829722
# [38]	train-logloss:0.45182	train-auc:0.900367	valid-logloss:0.486486	valid-auc:0.828736
# [39]	train-logloss:0.447302	train-auc:0.900512	valid-logloss:0.482574	valid-auc:0.8287
# [40]	train-logloss:0.442846	train-auc:0.90051	valid-logloss:0.478711	valid-auc:0.828647
# [41]	train-logloss:0.438455	train-auc:0.900532	valid-logloss:0.474971	valid-auc:0.828908
# [42]	train-logloss:0.434122	train-auc:0.90057	valid-logloss:0.471276	valid-auc:0.829138
# [43]	train-logloss:0.429854	train-auc:0.90054	valid-logloss:0.467674	valid-auc:0.829096
# [44]	train-logloss:0.425639	train-auc:0.900477	valid-logloss:0.464098	valid-auc:0.829165
# [45]	train-logloss:0.421478	train-auc:0.900579	valid-logloss:0.460501	valid-auc:0.829199
# [46]	train-logloss:0.417374	train-auc:0.901012	valid-logloss:0.457015	valid-auc:0.832835
# [47]	train-logloss:0.41333	train-auc:0.900987	valid-logloss:0.453572	valid-auc:0.833215
# [48]	train-logloss:0.409333	train-auc:0.90092	valid-logloss:0.450123	valid-auc:0.832315
# [49]	train-logloss:0.405393	train-auc:0.900801	valid-logloss:0.446787	valid-auc:0.832356
# [50]	train-logloss:0.401505	train-auc:0.900799	valid-logloss:0.44348	valid-auc:0.83243
# [51]	train-logloss:0.397672	train-auc:0.900462	valid-logloss:0.440237	valid-auc:0.832752
# [52]	train-logloss:0.393888	train-auc:0.900358	valid-logloss:0.43696	valid-auc:0.832205
# [53]	train-logloss:0.390147	train-auc:0.900613	valid-logloss:0.433759	valid-auc:0.832968
# [54]	train-logloss:0.386455	train-auc:0.901241	valid-logloss:0.430519	valid-auc:0.833415
# [55]	train-logloss:0.382813	train-auc:0.900888	valid-logloss:0.427368	valid-auc:0.833529
# [56]	train-logloss:0.379218	train-auc:0.900962	valid-logloss:0.424244	valid-auc:0.833665
# [57]	train-logloss:0.375669	train-auc:0.900753	valid-logloss:0.421203	valid-auc:0.833583
# [58]	train-logloss:0.372166	train-auc:0.901215	valid-logloss:0.418169	valid-auc:0.833569
# [59]	train-logloss:0.368704	train-auc:0.901067	valid-logloss:0.415172	valid-auc:0.834683
# [60]	train-logloss:0.365288	train-auc:0.901117	valid-logloss:0.41223	valid-auc:0.835068
# [61]	train-logloss:0.361922	train-auc:0.901519	valid-logloss:0.409314	valid-auc:0.835067
# [62]	train-logloss:0.358596	train-auc:0.90165	valid-logloss:0.406447	valid-auc:0.835154
# [63]	train-logloss:0.355309	train-auc:0.901679	valid-logloss:0.403632	valid-auc:0.835387
# [64]	train-logloss:0.35206	train-auc:0.901747	valid-logloss:0.400787	valid-auc:0.835404
# [65]	train-logloss:0.348854	train-auc:0.901765	valid-logloss:0.398056	valid-auc:0.835416
# [66]	train-logloss:0.34569	train-auc:0.901837	valid-logloss:0.39532	valid-auc:0.836469
# [67]	train-logloss:0.342562	train-auc:0.901844	valid-logloss:0.392576	valid-auc:0.83741
# [68]	train-logloss:0.339468	train-auc:0.90188	valid-logloss:0.389899	valid-auc:0.837459
# [69]	train-logloss:0.336422	train-auc:0.901908	valid-logloss:0.387277	valid-auc:0.837277
# [70]	train-logloss:0.33341	train-auc:0.904106	valid-logloss:0.384717	valid-auc:0.837761
# [71]	train-logloss:0.330437	train-auc:0.904125	valid-logloss:0.382154	valid-auc:0.837732
# [72]	train-logloss:0.327496	train-auc:0.904142	valid-logloss:0.37961	valid-auc:0.837791
# [73]	train-logloss:0.324591	train-auc:0.904129	valid-logloss:0.377124	valid-auc:0.837697
# [74]	train-logloss:0.321726	train-auc:0.904136	valid-logloss:0.374632	valid-auc:0.837778
# [75]	train-logloss:0.318893	train-auc:0.90419	valid-logloss:0.372234	valid-auc:0.837777
# [76]	train-logloss:0.316095	train-auc:0.90419	valid-logloss:0.36982	valid-auc:0.837467
# [77]	train-logloss:0.313328	train-auc:0.904204	valid-logloss:0.367477	valid-auc:0.837587
# [78]	train-logloss:0.310595	train-auc:0.904244	valid-logloss:0.365103	valid-auc:0.837765
# [79]	train-logloss:0.307893	train-auc:0.904235	valid-logloss:0.362756	valid-auc:0.837631
# [80]	train-logloss:0.30523	train-auc:0.904266	valid-logloss:0.360442	valid-auc:0.837705
# [81]	train-logloss:0.302598	train-auc:0.904278	valid-logloss:0.358168	valid-auc:0.837703
# [82]	train-logloss:0.299995	train-auc:0.904273	valid-logloss:0.356006	valid-auc:0.837718
# [83]	train-logloss:0.297417	train-auc:0.904284	valid-logloss:0.353755	valid-auc:0.837734
# [84]	train-logloss:0.294871	train-auc:0.904336	valid-logloss:0.35152	valid-auc:0.837678
# [85]	train-logloss:0.292358	train-auc:0.906133	valid-logloss:0.349376	valid-auc:0.838076
# [86]	train-logloss:0.289879	train-auc:0.906109	valid-logloss:0.347281	valid-auc:0.837998
# [87]	train-logloss:0.287423	train-auc:0.90609	valid-logloss:0.345186	valid-auc:0.838193
# [88]	train-logloss:0.284997	train-auc:0.906078	valid-logloss:0.343121	valid-auc:0.838303
# [89]	train-logloss:0.282604	train-auc:0.90602	valid-logloss:0.341076	valid-auc:0.837894
# [90]	train-logloss:0.280233	train-auc:0.906015	valid-logloss:0.339033	valid-auc:0.838363
# [91]	train-logloss:0.277893	train-auc:0.906023	valid-logloss:0.337056	valid-auc:0.838845
# [92]	train-logloss:0.27558	train-auc:0.906047	valid-logloss:0.335057	valid-auc:0.838922
# [93]	train-logloss:0.273293	train-auc:0.906083	valid-logloss:0.333051	valid-auc:0.839414
# [94]	train-logloss:0.27103	train-auc:0.906098	valid-logloss:0.331139	valid-auc:0.83948
# [95]	train-logloss:0.268795	train-auc:0.906127	valid-logloss:0.329214	valid-auc:0.839313
# [96]	train-logloss:0.266585	train-auc:0.906195	valid-logloss:0.327246	valid-auc:0.840025
# [97]	train-logloss:0.264398	train-auc:0.906203	valid-logloss:0.325385	valid-auc:0.839863
# [98]	train-logloss:0.26224	train-auc:0.906228	valid-logloss:0.323552	valid-auc:0.839796
# [99]	train-logloss:0.260108	train-auc:0.906195	valid-logloss:0.321776	valid-auc:0.839733
# [100]	train-logloss:0.257999	train-auc:0.906241	valid-logloss:0.319925	valid-auc:0.839806
# [101]	train-logloss:0.255913	train-auc:0.906239	valid-logloss:0.318153	valid-auc:0.839955
# [102]	train-logloss:0.25385	train-auc:0.90626	valid-logloss:0.316395	valid-auc:0.83981
# [103]	train-logloss:0.251813	train-auc:0.906231	valid-logloss:0.314687	valid-auc:0.839671
# [104]	train-logloss:0.249799	train-auc:0.906272	valid-logloss:0.312969	valid-auc:0.839885
# [105]	train-logloss:0.247801	train-auc:0.906263	valid-logloss:0.311298	valid-auc:0.839899
# [106]	train-logloss:0.245829	train-auc:0.906241	valid-logloss:0.309624	valid-auc:0.840034
# [107]	train-logloss:0.243882	train-auc:0.907161	valid-logloss:0.30798	valid-auc:0.839897
# [108]	train-logloss:0.241958	train-auc:0.907169	valid-logloss:0.30635	valid-auc:0.839856
# [109]	train-logloss:0.240049	train-auc:0.907232	valid-logloss:0.304726	valid-auc:0.839963
# [110]	train-logloss:0.238162	train-auc:0.907276	valid-logloss:0.303093	valid-auc:0.840009
# [111]	train-logloss:0.236297	train-auc:0.907251	valid-logloss:0.301498	valid-auc:0.840013
# [112]	train-logloss:0.234456	train-auc:0.907291	valid-logloss:0.299935	valid-auc:0.840008
# [113]	train-logloss:0.232634	train-auc:0.907401	valid-logloss:0.298338	valid-auc:0.840174
# [114]	train-logloss:0.230834	train-auc:0.907394	valid-logloss:0.296819	valid-auc:0.839967
# [115]	train-logloss:0.229041	train-auc:0.907598	valid-logloss:0.295297	valid-auc:0.841133
# [116]	train-logloss:0.227275	train-auc:0.907575	valid-logloss:0.293752	valid-auc:0.840916
# [117]	train-logloss:0.225526	train-auc:0.907732	valid-logloss:0.292255	valid-auc:0.84131
# [118]	train-logloss:0.223808	train-auc:0.907786	valid-logloss:0.290813	valid-auc:0.841222
# [119]	train-logloss:0.222104	train-auc:0.907809	valid-logloss:0.289376	valid-auc:0.841308
# [120]	train-logloss:0.220417	train-auc:0.907719	valid-logloss:0.287953	valid-auc:0.841272
# [121]	train-logloss:0.218752	train-auc:0.907784	valid-logloss:0.286508	valid-auc:0.841284
# [122]	train-logloss:0.217099	train-auc:0.908062	valid-logloss:0.285142	valid-auc:0.842202
# [123]	train-logloss:0.215469	train-auc:0.908126	valid-logloss:0.283767	valid-auc:0.842137
# [124]	train-logloss:0.213856	train-auc:0.908181	valid-logloss:0.282345	valid-auc:0.842241
# [125]	train-logloss:0.21226	train-auc:0.908227	valid-logloss:0.280945	valid-auc:0.842299
# [126]	train-logloss:0.210681	train-auc:0.908252	valid-logloss:0.2796	valid-auc:0.842159
# [127]	train-logloss:0.209124	train-auc:0.908242	valid-logloss:0.278291	valid-auc:0.842036
# [128]	train-logloss:0.207582	train-auc:0.90825	valid-logloss:0.276978	valid-auc:0.842119
# [129]	train-logloss:0.206054	train-auc:0.908221	valid-logloss:0.275685	valid-auc:0.842164
# [130]	train-logloss:0.204542	train-auc:0.908293	valid-logloss:0.274375	valid-auc:0.842187
# [131]	train-logloss:0.203043	train-auc:0.908217	valid-logloss:0.273159	valid-auc:0.842156
# [132]	train-logloss:0.201564	train-auc:0.908278	valid-logloss:0.27186	valid-auc:0.84235
# [133]	train-logloss:0.200093	train-auc:0.908535	valid-logloss:0.270635	valid-auc:0.843099
# [134]	train-logloss:0.198645	train-auc:0.908526	valid-logloss:0.269438	valid-auc:0.84262
# [135]	train-logloss:0.197216	train-auc:0.908531	valid-logloss:0.26826	valid-auc:0.842594
# [136]	train-logloss:0.195791	train-auc:0.908974	valid-logloss:0.267053	valid-auc:0.844021
# [137]	train-logloss:0.194389	train-auc:0.908959	valid-logloss:0.26581	valid-auc:0.844064
# [138]	train-logloss:0.193006	train-auc:0.908971	valid-logloss:0.264643	valid-auc:0.844097
# [139]	train-logloss:0.191633	train-auc:0.908998	valid-logloss:0.263448	valid-auc:0.844154
# [140]	train-logloss:0.190269	train-auc:0.90923	valid-logloss:0.262308	valid-auc:0.844512
# [141]	train-logloss:0.188925	train-auc:0.909225	valid-logloss:0.261102	valid-auc:0.844629
# [142]	train-logloss:0.187594	train-auc:0.909192	valid-logloss:0.26004	valid-auc:0.844563
# [143]	train-logloss:0.186279	train-auc:0.909208	valid-logloss:0.258885	valid-auc:0.844615
# [144]	train-logloss:0.184976	train-auc:0.909232	valid-logloss:0.257768	valid-auc:0.8447
# [145]	train-logloss:0.183691	train-auc:0.909206	valid-logloss:0.256684	valid-auc:0.844604
# [146]	train-logloss:0.182418	train-auc:0.909203	valid-logloss:0.255612	valid-auc:0.844726
# [147]	train-logloss:0.181162	train-auc:0.909238	valid-logloss:0.254529	valid-auc:0.845105
# [148]	train-logloss:0.179909	train-auc:0.909462	valid-logloss:0.25344	valid-auc:0.845641
# [149]	train-logloss:0.178672	train-auc:0.909554	valid-logloss:0.252418	valid-auc:0.846142
# [150]	train-logloss:0.177445	train-auc:0.909729	valid-logloss:0.251429	valid-auc:0.846911
# [151]	train-logloss:0.176232	train-auc:0.909936	valid-logloss:0.250448	valid-auc:0.84783
# [152]	train-logloss:0.175037	train-auc:0.909967	valid-logloss:0.249433	valid-auc:0.847819
# [153]	train-logloss:0.173856	train-auc:0.910189	valid-logloss:0.248423	valid-auc:0.848785
# [154]	train-logloss:0.172679	train-auc:0.9105	valid-logloss:0.24745	valid-auc:0.849576
# [155]	train-logloss:0.171519	train-auc:0.910526	valid-logloss:0.246479	valid-auc:0.849571
# [156]	train-logloss:0.170367	train-auc:0.910585	valid-logloss:0.245527	valid-auc:0.849597
# [157]	train-logloss:0.169232	train-auc:0.910804	valid-logloss:0.244599	valid-auc:0.850345
# [158]	train-logloss:0.168104	train-auc:0.911006	valid-logloss:0.243666	valid-auc:0.850991
# [159]	train-logloss:0.166993	train-auc:0.911059	valid-logloss:0.24271	valid-auc:0.851204
# [160]	train-logloss:0.165894	train-auc:0.911052	valid-logloss:0.24179	valid-auc:0.851086
# [161]	train-logloss:0.164807	train-auc:0.911078	valid-logloss:0.240858	valid-auc:0.85115
# [162]	train-logloss:0.163729	train-auc:0.911035	valid-logloss:0.239995	valid-auc:0.851063
# [163]	train-logloss:0.162663	train-auc:0.911029	valid-logloss:0.239107	valid-auc:0.851003
# [164]	train-logloss:0.161603	train-auc:0.911211	valid-logloss:0.23823	valid-auc:0.85167
# [165]	train-logloss:0.160557	train-auc:0.911224	valid-logloss:0.237328	valid-auc:0.851677
# [166]	train-logloss:0.159519	train-auc:0.911395	valid-logloss:0.236486	valid-auc:0.852089
# [167]	train-logloss:0.158491	train-auc:0.911523	valid-logloss:0.235654	valid-auc:0.852428
# [168]	train-logloss:0.157472	train-auc:0.911606	valid-logloss:0.234817	valid-auc:0.852797
# [169]	train-logloss:0.156469	train-auc:0.911632	valid-logloss:0.233965	valid-auc:0.852759
# [170]	train-logloss:0.155478	train-auc:0.911644	valid-logloss:0.233131	valid-auc:0.852801
# [171]	train-logloss:0.154501	train-auc:0.911665	valid-logloss:0.232299	valid-auc:0.852809
# [172]	train-logloss:0.153522	train-auc:0.911727	valid-logloss:0.231484	valid-auc:0.852963
# [173]	train-logloss:0.152555	train-auc:0.911809	valid-logloss:0.230704	valid-auc:0.853245
# [174]	train-logloss:0.151598	train-auc:0.911881	valid-logloss:0.229939	valid-auc:0.853497
# [175]	train-logloss:0.150658	train-auc:0.911898	valid-logloss:0.229174	valid-auc:0.853834
# [176]	train-logloss:0.149728	train-auc:0.911918	valid-logloss:0.228413	valid-auc:0.853791
# [177]	train-logloss:0.148805	train-auc:0.911981	valid-logloss:0.22761	valid-auc:0.853805
# [178]	train-logloss:0.14789	train-auc:0.91205	valid-logloss:0.226876	valid-auc:0.85417
# [179]	train-logloss:0.146984	train-auc:0.912319	valid-logloss:0.226184	valid-auc:0.854328
# [180]	train-logloss:0.146087	train-auc:0.912337	valid-logloss:0.225475	valid-auc:0.854503
# [181]	train-logloss:0.145201	train-auc:0.912427	valid-logloss:0.224765	valid-auc:0.854967
# [182]	train-logloss:0.144328	train-auc:0.91244	valid-logloss:0.22403	valid-auc:0.855052
# [183]	train-logloss:0.143453	train-auc:0.912499	valid-logloss:0.223325	valid-auc:0.855414
# [184]	train-logloss:0.142598	train-auc:0.912486	valid-logloss:0.222619	valid-auc:0.855394
# [185]	train-logloss:0.14175	train-auc:0.912462	valid-logloss:0.221929	valid-auc:0.855253
# [186]	train-logloss:0.140908	train-auc:0.912464	valid-logloss:0.221225	valid-auc:0.85524
# [187]	train-logloss:0.140071	train-auc:0.912506	valid-logloss:0.220547	valid-auc:0.855474
# [188]	train-logloss:0.139243	train-auc:0.913772	valid-logloss:0.219901	valid-auc:0.855586
# [189]	train-logloss:0.138425	train-auc:0.91384	valid-logloss:0.219267	valid-auc:0.855956
# [190]	train-logloss:0.137615	train-auc:0.913895	valid-logloss:0.218609	valid-auc:0.856159
# [191]	train-logloss:0.136816	train-auc:0.913942	valid-logloss:0.217961	valid-auc:0.856696
# [192]	train-logloss:0.136018	train-auc:0.914048	valid-logloss:0.217304	valid-auc:0.856934
# [193]	train-logloss:0.135236	train-auc:0.914067	valid-logloss:0.216693	valid-auc:0.857107
# [194]	train-logloss:0.134456	train-auc:0.914121	valid-logloss:0.21604	valid-auc:0.857398
# [195]	train-logloss:0.133689	train-auc:0.914141	valid-logloss:0.215404	valid-auc:0.857337
# [196]	train-logloss:0.132921	train-auc:0.9142	valid-logloss:0.214764	valid-auc:0.85754
# [197]	train-logloss:0.132162	train-auc:0.914243	valid-logloss:0.214167	valid-auc:0.857645
# [198]	train-logloss:0.131415	train-auc:0.914319	valid-logloss:0.213548	valid-auc:0.857992
# [199]	train-logloss:0.130675	train-auc:0.914389	valid-logloss:0.212956	valid-auc:0.858244
# [200]	train-logloss:0.129944	train-auc:0.914422	valid-logloss:0.212376	valid-auc:0.858427
# [201]	train-logloss:0.129219	train-auc:0.914497	valid-logloss:0.211813	valid-auc:0.858802
# [202]	train-logloss:0.128504	train-auc:0.914542	valid-logloss:0.21126	valid-auc:0.859011
# [203]	train-logloss:0.127792	train-auc:0.914599	valid-logloss:0.210672	valid-auc:0.859153
# [204]	train-logloss:0.127091	train-auc:0.914698	valid-logloss:0.210079	valid-auc:0.859195
# [205]	train-logloss:0.126396	train-auc:0.914753	valid-logloss:0.209522	valid-auc:0.859349
# [206]	train-logloss:0.125712	train-auc:0.914747	valid-logloss:0.20895	valid-auc:0.859411
# [207]	train-logloss:0.12503	train-auc:0.914842	valid-logloss:0.208408	valid-auc:0.859485
# [208]	train-logloss:0.124353	train-auc:0.914901	valid-logloss:0.20781	valid-auc:0.859485
# [209]	train-logloss:0.123683	train-auc:0.914959	valid-logloss:0.207274	valid-auc:0.859705
# [210]	train-logloss:0.123017	train-auc:0.914993	valid-logloss:0.206729	valid-auc:0.859844
# [211]	train-logloss:0.12236	train-auc:0.915067	valid-logloss:0.206191	valid-auc:0.859974
# [212]	train-logloss:0.12171	train-auc:0.915121	valid-logloss:0.205665	valid-auc:0.860062
# [213]	train-logloss:0.121066	train-auc:0.915168	valid-logloss:0.205153	valid-auc:0.860196
# [214]	train-logloss:0.120425	train-auc:0.915213	valid-logloss:0.204619	valid-auc:0.860398
# [215]	train-logloss:0.119798	train-auc:0.915256	valid-logloss:0.204111	valid-auc:0.860666
# [216]	train-logloss:0.119178	train-auc:0.915312	valid-logloss:0.203611	valid-auc:0.860749
# [217]	train-logloss:0.118558	train-auc:0.915361	valid-logloss:0.203123	valid-auc:0.860828
# [218]	train-logloss:0.117945	train-auc:0.915413	valid-logloss:0.202626	valid-auc:0.860994
# [219]	train-logloss:0.117341	train-auc:0.915437	valid-logloss:0.202155	valid-auc:0.861008
# [220]	train-logloss:0.116736	train-auc:0.915453	valid-logloss:0.201665	valid-auc:0.861124
# [221]	train-logloss:0.11614	train-auc:0.915529	valid-logloss:0.201185	valid-auc:0.861189
# [222]	train-logloss:0.115551	train-auc:0.915563	valid-logloss:0.200726	valid-auc:0.861352
# [223]	train-logloss:0.114971	train-auc:0.915635	valid-logloss:0.200273	valid-auc:0.86148
# [224]	train-logloss:0.114396	train-auc:0.915672	valid-logloss:0.199813	valid-auc:0.861681
# [225]	train-logloss:0.113823	train-auc:0.915702	valid-logloss:0.199368	valid-auc:0.861799
# [226]	train-logloss:0.113262	train-auc:0.915735	valid-logloss:0.198934	valid-auc:0.861854
# [227]	train-logloss:0.1127	train-auc:0.915779	valid-logloss:0.198495	valid-auc:0.861927
# [228]	train-logloss:0.112144	train-auc:0.915815	valid-logloss:0.198047	valid-auc:0.862005
# [229]	train-logloss:0.111594	train-auc:0.915838	valid-logloss:0.197654	valid-auc:0.86194
# [230]	train-logloss:0.111048	train-auc:0.915858	valid-logloss:0.197193	valid-auc:0.862089
# [231]	train-logloss:0.110509	train-auc:0.915893	valid-logloss:0.196768	valid-auc:0.862214
# [232]	train-logloss:0.109974	train-auc:0.915919	valid-logloss:0.196353	valid-auc:0.862338
# [233]	train-logloss:0.109445	train-auc:0.917111	valid-logloss:0.195926	valid-auc:0.862342
# [234]	train-logloss:0.10892	train-auc:0.917149	valid-logloss:0.195515	valid-auc:0.86242
# [235]	train-logloss:0.108397	train-auc:0.917259	valid-logloss:0.195081	valid-auc:0.862592
# [236]	train-logloss:0.107882	train-auc:0.917377	valid-logloss:0.194658	valid-auc:0.862812
# [237]	train-logloss:0.107374	train-auc:0.91741	valid-logloss:0.194256	valid-auc:0.862926
# [238]	train-logloss:0.106872	train-auc:0.917518	valid-logloss:0.193846	valid-auc:0.862956
# [239]	train-logloss:0.106375	train-auc:0.917626	valid-logloss:0.193471	valid-auc:0.862906
# [240]	train-logloss:0.10588	train-auc:0.917647	valid-logloss:0.193062	valid-auc:0.862995
# [241]	train-logloss:0.105388	train-auc:0.917735	valid-logloss:0.192658	valid-auc:0.863111
# [242]	train-logloss:0.104907	train-auc:0.917797	valid-logloss:0.192273	valid-auc:0.863069
# [243]	train-logloss:0.10443	train-auc:0.917808	valid-logloss:0.191895	valid-auc:0.8633
# [244]	train-logloss:0.103954	train-auc:0.917854	valid-logloss:0.191506	valid-auc:0.863357
# [245]	train-logloss:0.103484	train-auc:0.917889	valid-logloss:0.191119	valid-auc:0.863468
# [246]	train-logloss:0.103019	train-auc:0.917903	valid-logloss:0.190753	valid-auc:0.863464
# [247]	train-logloss:0.10256	train-auc:0.917927	valid-logloss:0.190381	valid-auc:0.863661
# [248]	train-logloss:0.102103	train-auc:0.917956	valid-logloss:0.190014	valid-auc:0.863634
# [249]	train-logloss:0.101651	train-auc:0.918008	valid-logloss:0.18965	valid-auc:0.863727
# [250]	train-logloss:0.101205	train-auc:0.918062	valid-logloss:0.189305	valid-auc:0.863703
# [251]	train-logloss:0.10076	train-auc:0.918101	valid-logloss:0.188968	valid-auc:0.863811
# [252]	train-logloss:0.100321	train-auc:0.91812	valid-logloss:0.188585	valid-auc:0.863923
# [253]	train-logloss:0.099886	train-auc:0.918177	valid-logloss:0.188247	valid-auc:0.86395
# [254]	train-logloss:0.099458	train-auc:0.918212	valid-logloss:0.187894	valid-auc:0.863913
# [255]	train-logloss:0.099032	train-auc:0.918225	valid-logloss:0.187574	valid-auc:0.863864
# [256]	train-logloss:0.098608	train-auc:0.918294	valid-logloss:0.187251	valid-auc:0.86389
# [257]	train-logloss:0.09819	train-auc:0.918387	valid-logloss:0.186898	valid-auc:0.863966
# [258]	train-logloss:0.097777	train-auc:0.918465	valid-logloss:0.186559	valid-auc:0.863983
# [259]	train-logloss:0.097369	train-auc:0.918506	valid-logloss:0.186233	valid-auc:0.863996
# [260]	train-logloss:0.096965	train-auc:0.918532	valid-logloss:0.185908	valid-auc:0.864141
# [261]	train-logloss:0.096561	train-auc:0.918561	valid-logloss:0.185611	valid-auc:0.864118
# [262]	train-logloss:0.096161	train-auc:0.918661	valid-logloss:0.185293	valid-auc:0.864156
# [263]	train-logloss:0.095768	train-auc:0.918646	valid-logloss:0.18498	valid-auc:0.864258
# [264]	train-logloss:0.095377	train-auc:0.918676	valid-logloss:0.184666	valid-auc:0.864314
# [265]	train-logloss:0.09499	train-auc:0.918691	valid-logloss:0.184372	valid-auc:0.864485
# [266]	train-logloss:0.094605	train-auc:0.918686	valid-logloss:0.18408	valid-auc:0.864506
# [267]	train-logloss:0.094226	train-auc:0.918724	valid-logloss:0.183781	valid-auc:0.864633
# [268]	train-logloss:0.093853	train-auc:0.918808	valid-logloss:0.1835	valid-auc:0.864629
# [269]	train-logloss:0.093482	train-auc:0.918818	valid-logloss:0.183188	valid-auc:0.864885
# [270]	train-logloss:0.093113	train-auc:0.918876	valid-logloss:0.182915	valid-auc:0.864855
# [271]	train-logloss:0.092747	train-auc:0.918969	valid-logloss:0.18264	valid-auc:0.864803
# [272]	train-logloss:0.092384	train-auc:0.918987	valid-logloss:0.182358	valid-auc:0.864864
# [273]	train-logloss:0.092025	train-auc:0.919125	valid-logloss:0.182072	valid-auc:0.864941
# [274]	train-logloss:0.091669	train-auc:0.91919	valid-logloss:0.181808	valid-auc:0.864936
# [275]	train-logloss:0.091314	train-auc:0.923783	valid-logloss:0.181506	valid-auc:0.865044
# [276]	train-logloss:0.090969	train-auc:0.923821	valid-logloss:0.181238	valid-auc:0.865142
# [277]	train-logloss:0.090624	train-auc:0.923847	valid-logloss:0.180972	valid-auc:0.865244
# [278]	train-logloss:0.09028	train-auc:0.923934	valid-logloss:0.18069	valid-auc:0.865322
# [279]	train-logloss:0.089941	train-auc:0.923999	valid-logloss:0.18041	valid-auc:0.865338
# [280]	train-logloss:0.089607	train-auc:0.923995	valid-logloss:0.180152	valid-auc:0.865482
# [281]	train-logloss:0.089276	train-auc:0.923993	valid-logloss:0.179899	valid-auc:0.86566
# [282]	train-logloss:0.088948	train-auc:0.923986	valid-logloss:0.179622	valid-auc:0.866315
# [283]	train-logloss:0.088623	train-auc:0.92402	valid-logloss:0.179352	valid-auc:0.86635
# [284]	train-logloss:0.0883	train-auc:0.924059	valid-logloss:0.179109	valid-auc:0.866501
# [285]	train-logloss:0.087982	train-auc:0.924109	valid-logloss:0.178872	valid-auc:0.866502
# [286]	train-logloss:0.087666	train-auc:0.924122	valid-logloss:0.178625	valid-auc:0.866548
# [287]	train-logloss:0.087353	train-auc:0.924184	valid-logloss:0.178375	valid-auc:0.866603
# [288]	train-logloss:0.087044	train-auc:0.92403	valid-logloss:0.17814	valid-auc:0.866603
# [289]	train-logloss:0.086733	train-auc:0.924105	valid-logloss:0.177905	valid-auc:0.86662
# [290]	train-logloss:0.086429	train-auc:0.924128	valid-logloss:0.177669	valid-auc:0.866635
# [291]	train-logloss:0.086128	train-auc:0.924154	valid-logloss:0.177428	valid-auc:0.866728
# [292]	train-logloss:0.085831	train-auc:0.924196	valid-logloss:0.177213	valid-auc:0.866688
# [293]	train-logloss:0.085537	train-auc:0.924209	valid-logloss:0.176995	valid-auc:0.866673
# [294]	train-logloss:0.085243	train-auc:0.924241	valid-logloss:0.176764	valid-auc:0.866723
# [295]	train-logloss:0.084954	train-auc:0.924272	valid-logloss:0.17654	valid-auc:0.866722
# [296]	train-logloss:0.084665	train-auc:0.924321	valid-logloss:0.176317	valid-auc:0.86679
# [297]	train-logloss:0.08438	train-auc:0.924362	valid-logloss:0.176116	valid-auc:0.866877
# [298]	train-logloss:0.084098	train-auc:0.924408	valid-logloss:0.175897	valid-auc:0.86694
# [299]	train-logloss:0.083819	train-auc:0.924413	valid-logloss:0.175683	valid-auc:0.867059
# [300]	train-logloss:0.083542	train-auc:0.924462	valid-logloss:0.175466	valid-auc:0.867037
# [301]	train-logloss:0.083268	train-auc:0.924761	valid-logloss:0.175234	valid-auc:0.867104
# [302]	train-logloss:0.082994	train-auc:0.924852	valid-logloss:0.174996	valid-auc:0.867127
# [303]	train-logloss:0.082725	train-auc:0.924871	valid-logloss:0.174788	valid-auc:0.867099
# [304]	train-logloss:0.082457	train-auc:0.924949	valid-logloss:0.174589	valid-auc:0.867145
# [305]	train-logloss:0.082194	train-auc:0.925016	valid-logloss:0.174399	valid-auc:0.86716
# [306]	train-logloss:0.081935	train-auc:0.925062	valid-logloss:0.174204	valid-auc:0.867116
# [307]	train-logloss:0.081676	train-auc:0.925088	valid-logloss:0.174021	valid-auc:0.867118
# [308]	train-logloss:0.081418	train-auc:0.92517	valid-logloss:0.173822	valid-auc:0.867154
# [309]	train-logloss:0.081164	train-auc:0.92519	valid-logloss:0.173604	valid-auc:0.867313
# [310]	train-logloss:0.080913	train-auc:0.925256	valid-logloss:0.173395	valid-auc:0.86737
# [311]	train-logloss:0.080661	train-auc:0.925263	valid-logloss:0.173198	valid-auc:0.867331
# [312]	train-logloss:0.080412	train-auc:0.925303	valid-logloss:0.173011	valid-auc:0.867363
# [313]	train-logloss:0.080168	train-auc:0.925364	valid-logloss:0.172845	valid-auc:0.86732
# [314]	train-logloss:0.079924	train-auc:0.925408	valid-logloss:0.172642	valid-auc:0.867341
# [315]	train-logloss:0.079684	train-auc:0.925496	valid-logloss:0.172434	valid-auc:0.86743
# [316]	train-logloss:0.079446	train-auc:0.925534	valid-logloss:0.172257	valid-auc:0.867402
# [317]	train-logloss:0.079212	train-auc:0.925546	valid-logloss:0.172099	valid-auc:0.867335
# [318]	train-logloss:0.07898	train-auc:0.925556	valid-logloss:0.171926	valid-auc:0.867332
# [319]	train-logloss:0.078749	train-auc:0.925621	valid-logloss:0.171729	valid-auc:0.867347
# [320]	train-logloss:0.078521	train-auc:0.925628	valid-logloss:0.17156	valid-auc:0.867362
# [321]	train-logloss:0.078296	train-auc:0.925707	valid-logloss:0.171376	valid-auc:0.867517
# [322]	train-logloss:0.078071	train-auc:0.925727	valid-logloss:0.171204	valid-auc:0.867558
# [323]	train-logloss:0.077853	train-auc:0.92579	valid-logloss:0.171036	valid-auc:0.867605
# [324]	train-logloss:0.077633	train-auc:0.925802	valid-logloss:0.170878	valid-auc:0.86762
# [325]	train-logloss:0.077416	train-auc:0.925814	valid-logloss:0.170712	valid-auc:0.86762
# [326]	train-logloss:0.077196	train-auc:0.926995	valid-logloss:0.170548	valid-auc:0.867664
# [327]	train-logloss:0.07698	train-auc:0.927023	valid-logloss:0.170387	valid-auc:0.867639
# [328]	train-logloss:0.076769	train-auc:0.927073	valid-logloss:0.170247	valid-auc:0.867664
# [329]	train-logloss:0.076561	train-auc:0.927073	valid-logloss:0.17011	valid-auc:0.867749
# [330]	train-logloss:0.076347	train-auc:0.927132	valid-logloss:0.169942	valid-auc:0.867888
# [331]	train-logloss:0.076142	train-auc:0.927175	valid-logloss:0.169758	valid-auc:0.867992
# [332]	train-logloss:0.075936	train-auc:0.927245	valid-logloss:0.169602	valid-auc:0.868068
# [333]	train-logloss:0.07573	train-auc:0.927301	valid-logloss:0.169434	valid-auc:0.868233
# [334]	train-logloss:0.07553	train-auc:0.927416	valid-logloss:0.169252	valid-auc:0.868212
# [335]	train-logloss:0.075333	train-auc:0.927483	valid-logloss:0.1691	valid-auc:0.86826
# [336]	train-logloss:0.075136	train-auc:0.927543	valid-logloss:0.168971	valid-auc:0.868168
# [337]	train-logloss:0.07494	train-auc:0.927635	valid-logloss:0.168804	valid-auc:0.868329
# [338]	train-logloss:0.074743	train-auc:0.927666	valid-logloss:0.168667	valid-auc:0.868323
# [339]	train-logloss:0.074551	train-auc:0.927746	valid-logloss:0.168512	valid-auc:0.868282
# [340]	train-logloss:0.074362	train-auc:0.927872	valid-logloss:0.168366	valid-auc:0.868291
# [341]	train-logloss:0.074173	train-auc:0.927986	valid-logloss:0.168214	valid-auc:0.868596
# [342]	train-logloss:0.073987	train-auc:0.928077	valid-logloss:0.168064	valid-auc:0.868534
# [343]	train-logloss:0.073804	train-auc:0.928146	valid-logloss:0.167934	valid-auc:0.868658
# [344]	train-logloss:0.073621	train-auc:0.928154	valid-logloss:0.167794	valid-auc:0.868698
# [345]	train-logloss:0.073434	train-auc:0.928228	valid-logloss:0.167643	valid-auc:0.868766
# [346]	train-logloss:0.073253	train-auc:0.928304	valid-logloss:0.167498	valid-auc:0.868775
# [347]	train-logloss:0.073074	train-auc:0.928307	valid-logloss:0.167374	valid-auc:0.868924
# [348]	train-logloss:0.0729	train-auc:0.928304	valid-logloss:0.167255	valid-auc:0.86889
# [349]	train-logloss:0.072727	train-auc:0.928418	valid-logloss:0.16713	valid-auc:0.868912
# [350]	train-logloss:0.072555	train-auc:0.9285	valid-logloss:0.16697	valid-auc:0.86903
# [351]	train-logloss:0.072386	train-auc:0.928591	valid-logloss:0.166821	valid-auc:0.869121
# [352]	train-logloss:0.072217	train-auc:0.928665	valid-logloss:0.166718	valid-auc:0.869023
# [353]	train-logloss:0.072046	train-auc:0.929582	valid-logloss:0.166555	valid-auc:0.869205
# [354]	train-logloss:0.07188	train-auc:0.929788	valid-logloss:0.166421	valid-auc:0.869381
# [355]	train-logloss:0.071713	train-auc:0.929882	valid-logloss:0.166287	valid-auc:0.869613
# [356]	train-logloss:0.071548	train-auc:0.929945	valid-logloss:0.166163	valid-auc:0.869751
# [357]	train-logloss:0.071384	train-auc:0.930031	valid-logloss:0.166014	valid-auc:0.869759
# [358]	train-logloss:0.071223	train-auc:0.930083	valid-logloss:0.165911	valid-auc:0.869724
# [359]	train-logloss:0.071064	train-auc:0.930168	valid-logloss:0.165782	valid-auc:0.869762
# [360]	train-logloss:0.070904	train-auc:0.930263	valid-logloss:0.165635	valid-auc:0.869906
# [361]	train-logloss:0.070748	train-auc:0.930285	valid-logloss:0.165535	valid-auc:0.869843
# [362]	train-logloss:0.07059	train-auc:0.930437	valid-logloss:0.165416	valid-auc:0.869981
# [363]	train-logloss:0.070433	train-auc:0.930484	valid-logloss:0.165307	valid-auc:0.869967
# [364]	train-logloss:0.070279	train-auc:0.930501	valid-logloss:0.165203	valid-auc:0.869944
# [365]	train-logloss:0.070126	train-auc:0.930557	valid-logloss:0.165084	valid-auc:0.869973
# [366]	train-logloss:0.069978	train-auc:0.930734	valid-logloss:0.164963	valid-auc:0.869986
# [367]	train-logloss:0.069831	train-auc:0.930787	valid-logloss:0.164873	valid-auc:0.869907
# [368]	train-logloss:0.069681	train-auc:0.930827	valid-logloss:0.164769	valid-auc:0.869986
# [369]	train-logloss:0.069534	train-auc:0.930906	valid-logloss:0.164641	valid-auc:0.87012
# [370]	train-logloss:0.06939	train-auc:0.930969	valid-logloss:0.164536	valid-auc:0.87019
# [371]	train-logloss:0.069247	train-auc:0.931023	valid-logloss:0.164425	valid-auc:0.870177
# [372]	train-logloss:0.069106	train-auc:0.931059	valid-logloss:0.164326	valid-auc:0.870238
# [373]	train-logloss:0.068967	train-auc:0.931121	valid-logloss:0.164186	valid-auc:0.870425
# [374]	train-logloss:0.068827	train-auc:0.931199	valid-logloss:0.164093	valid-auc:0.870434
# [375]	train-logloss:0.068692	train-auc:0.93124	valid-logloss:0.163995	valid-auc:0.870571
# [376]	train-logloss:0.068557	train-auc:0.931322	valid-logloss:0.163926	valid-auc:0.87049
# [377]	train-logloss:0.068423	train-auc:0.931676	valid-logloss:0.163805	valid-auc:0.870587
# [378]	train-logloss:0.068289	train-auc:0.931718	valid-logloss:0.163677	valid-auc:0.870769
# [379]	train-logloss:0.068154	train-auc:0.931765	valid-logloss:0.163569	valid-auc:0.870823
# [380]	train-logloss:0.068022	train-auc:0.931823	valid-logloss:0.163468	valid-auc:0.870774
# [381]	train-logloss:0.067896	train-auc:0.931858	valid-logloss:0.163368	valid-auc:0.870808
# [382]	train-logloss:0.067766	train-auc:0.931935	valid-logloss:0.163279	valid-auc:0.870791
# [383]	train-logloss:0.067636	train-auc:0.932165	valid-logloss:0.163142	valid-auc:0.870857
# [384]	train-logloss:0.06751	train-auc:0.932254	valid-logloss:0.163036	valid-auc:0.871037
# [385]	train-logloss:0.067385	train-auc:0.932353	valid-logloss:0.16292	valid-auc:0.871078
# [386]	train-logloss:0.067259	train-auc:0.932416	valid-logloss:0.162836	valid-auc:0.871045
# [387]	train-logloss:0.067133	train-auc:0.932448	valid-logloss:0.162737	valid-auc:0.871034
# [388]	train-logloss:0.067009	train-auc:0.932495	valid-logloss:0.162647	valid-auc:0.871068
# [389]	train-logloss:0.06689	train-auc:0.932555	valid-logloss:0.162539	valid-auc:0.871049
# [390]	train-logloss:0.066767	train-auc:0.932672	valid-logloss:0.162448	valid-auc:0.871103
# [391]	train-logloss:0.066649	train-auc:0.932707	valid-logloss:0.162368	valid-auc:0.871132
# [392]	train-logloss:0.066531	train-auc:0.932757	valid-logloss:0.162266	valid-auc:0.871203
# [393]	train-logloss:0.066416	train-auc:0.932806	valid-logloss:0.162192	valid-auc:0.871174
# [394]	train-logloss:0.0663	train-auc:0.932941	valid-logloss:0.162128	valid-auc:0.871233
# [395]	train-logloss:0.066188	train-auc:0.933038	valid-logloss:0.16206	valid-auc:0.87126
# [396]	train-logloss:0.066073	train-auc:0.933104	valid-logloss:0.16195	valid-auc:0.871377
# [397]	train-logloss:0.06596	train-auc:0.933213	valid-logloss:0.161864	valid-auc:0.871366
# [398]	train-logloss:0.065847	train-auc:0.933236	valid-logloss:0.161789	valid-auc:0.871521
# [399]	train-logloss:0.065737	train-auc:0.933249	valid-logloss:0.161709	valid-auc:0.871622
# [400]	train-logloss:0.065627	train-auc:0.93328	valid-logloss:0.161598	valid-auc:0.871801
# [401]	train-logloss:0.065517	train-auc:0.933369	valid-logloss:0.16149	valid-auc:0.871941
# [402]	train-logloss:0.065407	train-auc:0.933464	valid-logloss:0.161398	valid-auc:0.872084
# [403]	train-logloss:0.065303	train-auc:0.933531	valid-logloss:0.161336	valid-auc:0.872074
# [404]	train-logloss:0.0652	train-auc:0.933758	valid-logloss:0.161272	valid-auc:0.872056
# [405]	train-logloss:0.065096	train-auc:0.933764	valid-logloss:0.161197	valid-auc:0.872083
# [406]	train-logloss:0.064992	train-auc:0.933713	valid-logloss:0.161113	valid-auc:0.872205
# [407]	train-logloss:0.064889	train-auc:0.93374	valid-logloss:0.161042	valid-auc:0.872194
# [408]	train-logloss:0.064783	train-auc:0.933938	valid-logloss:0.160949	valid-auc:0.87224
# [409]	train-logloss:0.064682	train-auc:0.934024	valid-logloss:0.160855	valid-auc:0.872287
# [410]	train-logloss:0.064581	train-auc:0.934102	valid-logloss:0.160768	valid-auc:0.872367
# [411]	train-logloss:0.064479	train-auc:0.934175	valid-logloss:0.160685	valid-auc:0.872437
# [412]	train-logloss:0.064381	train-auc:0.934174	valid-logloss:0.160641	valid-auc:0.872444
# [413]	train-logloss:0.064284	train-auc:0.934226	valid-logloss:0.160582	valid-auc:0.872472
# [414]	train-logloss:0.064186	train-auc:0.934295	valid-logloss:0.160523	valid-auc:0.872509
# [415]	train-logloss:0.064087	train-auc:0.934377	valid-logloss:0.160436	valid-auc:0.872721
# [416]	train-logloss:0.063993	train-auc:0.934462	valid-logloss:0.160371	valid-auc:0.872682
# [417]	train-logloss:0.063898	train-auc:0.934543	valid-logloss:0.160325	valid-auc:0.872695
# [418]	train-logloss:0.063804	train-auc:0.934632	valid-logloss:0.160251	valid-auc:0.872769
# [419]	train-logloss:0.063712	train-auc:0.934704	valid-logloss:0.160189	valid-auc:0.872825
# [420]	train-logloss:0.06362	train-auc:0.934762	valid-logloss:0.160113	valid-auc:0.872942
# [421]	train-logloss:0.063525	train-auc:0.934791	valid-logloss:0.160081	valid-auc:0.872969
# [422]	train-logloss:0.063436	train-auc:0.934829	valid-logloss:0.160002	valid-auc:0.873094
# [423]	train-logloss:0.063344	train-auc:0.934901	valid-logloss:0.159945	valid-auc:0.873175
# [424]	train-logloss:0.063253	train-auc:0.934932	valid-logloss:0.159876	valid-auc:0.873289
# [425]	train-logloss:0.063167	train-auc:0.935074	valid-logloss:0.15982	valid-auc:0.873358
# [426]	train-logloss:0.063076	train-auc:0.93509	valid-logloss:0.159808	valid-auc:0.873303
# [427]	train-logloss:0.06299	train-auc:0.935177	valid-logloss:0.159746	valid-auc:0.8733
# [428]	train-logloss:0.062905	train-auc:0.93524	valid-logloss:0.159665	valid-auc:0.873345
# [429]	train-logloss:0.062821	train-auc:0.935317	valid-logloss:0.159599	valid-auc:0.873415
# [430]	train-logloss:0.062739	train-auc:0.935365	valid-logloss:0.159557	valid-auc:0.873528
# [431]	train-logloss:0.062652	train-auc:0.935418	valid-logloss:0.15948	valid-auc:0.873652
# [432]	train-logloss:0.062572	train-auc:0.935473	valid-logloss:0.159436	valid-auc:0.873619
# [433]	train-logloss:0.062488	train-auc:0.935486	valid-logloss:0.15939	valid-auc:0.873617
# [434]	train-logloss:0.062407	train-auc:0.935517	valid-logloss:0.159319	valid-auc:0.873716
# [435]	train-logloss:0.062327	train-auc:0.935572	valid-logloss:0.159252	valid-auc:0.873739
# [436]	train-logloss:0.062248	train-auc:0.935612	valid-logloss:0.159199	valid-auc:0.873788
# [437]	train-logloss:0.06217	train-auc:0.935668	valid-logloss:0.159133	valid-auc:0.873874
# [438]	train-logloss:0.062093	train-auc:0.935725	valid-logloss:0.159094	valid-auc:0.873974
# [439]	train-logloss:0.062014	train-auc:0.935758	valid-logloss:0.159024	valid-auc:0.874045
# [440]	train-logloss:0.061936	train-auc:0.935807	valid-logloss:0.15893	valid-auc:0.874203
# [441]	train-logloss:0.06186	train-auc:0.935871	valid-logloss:0.158871	valid-auc:0.874291
# [442]	train-logloss:0.061782	train-auc:0.935929	valid-logloss:0.158821	valid-auc:0.874346
# [443]	train-logloss:0.061708	train-auc:0.936008	valid-logloss:0.15876	valid-auc:0.874426
# [444]	train-logloss:0.061634	train-auc:0.936074	valid-logloss:0.158715	valid-auc:0.874518
# [445]	train-logloss:0.06156	train-auc:0.936106	valid-logloss:0.158648	valid-auc:0.874532
# [446]	train-logloss:0.061486	train-auc:0.936161	valid-logloss:0.158597	valid-auc:0.874499
# [447]	train-logloss:0.061413	train-auc:0.936198	valid-logloss:0.158531	valid-auc:0.874619
# [448]	train-logloss:0.06134	train-auc:0.936233	valid-logloss:0.158466	valid-auc:0.874659
# [449]	train-logloss:0.061271	train-auc:0.936267	valid-logloss:0.158439	valid-auc:0.874657
# [450]	train-logloss:0.061197	train-auc:0.936292	valid-logloss:0.158389	valid-auc:0.874745
# [451]	train-logloss:0.061127	train-auc:0.936361	valid-logloss:0.158324	valid-auc:0.874828
# [452]	train-logloss:0.061056	train-auc:0.936406	valid-logloss:0.158291	valid-auc:0.87479
# [453]	train-logloss:0.060988	train-auc:0.936449	valid-logloss:0.158245	valid-auc:0.874755
# [454]	train-logloss:0.060921	train-auc:0.936501	valid-logloss:0.158206	valid-auc:0.87478
# [455]	train-logloss:0.060854	train-auc:0.936541	valid-logloss:0.158158	valid-auc:0.874799
# [456]	train-logloss:0.060787	train-auc:0.936585	valid-logloss:0.158104	valid-auc:0.87486
# [457]	train-logloss:0.060716	train-auc:0.936699	valid-logloss:0.158041	valid-auc:0.87487
# [458]	train-logloss:0.060649	train-auc:0.936795	valid-logloss:0.157981	valid-auc:0.874971
# [459]	train-logloss:0.060583	train-auc:0.936827	valid-logloss:0.157925	valid-auc:0.875064
# [460]	train-logloss:0.060518	train-auc:0.936867	valid-logloss:0.157882	valid-auc:0.875102
# [461]	train-logloss:0.060453	train-auc:0.936911	valid-logloss:0.157823	valid-auc:0.875207
# [462]	train-logloss:0.060387	train-auc:0.936987	valid-logloss:0.157759	valid-auc:0.875276
# [463]	train-logloss:0.060323	train-auc:0.937015	valid-logloss:0.15772	valid-auc:0.875276
# [464]	train-logloss:0.060261	train-auc:0.937056	valid-logloss:0.157673	valid-auc:0.875306
# [465]	train-logloss:0.060198	train-auc:0.937063	valid-logloss:0.157647	valid-auc:0.875306
# [466]	train-logloss:0.060138	train-auc:0.937091	valid-logloss:0.157589	valid-auc:0.875323
# [467]	train-logloss:0.060078	train-auc:0.937119	valid-logloss:0.157553	valid-auc:0.875356
# [468]	train-logloss:0.060016	train-auc:0.937157	valid-logloss:0.157516	valid-auc:0.8754
# [469]	train-logloss:0.059957	train-auc:0.937191	valid-logloss:0.157467	valid-auc:0.875485
# [470]	train-logloss:0.0599	train-auc:0.937268	valid-logloss:0.15741	valid-auc:0.87553
# [471]	train-logloss:0.059842	train-auc:0.937297	valid-logloss:0.157384	valid-auc:0.875519
# [472]	train-logloss:0.059782	train-auc:0.93732	valid-logloss:0.157327	valid-auc:0.875605
# [473]	train-logloss:0.059725	train-auc:0.93735	valid-logloss:0.157254	valid-auc:0.875741
# [474]	train-logloss:0.059668	train-auc:0.937378	valid-logloss:0.157213	valid-auc:0.875796
# [475]	train-logloss:0.05961	train-auc:0.937427	valid-logloss:0.15716	valid-auc:0.875869
# [476]	train-logloss:0.059552	train-auc:0.937468	valid-logloss:0.15709	valid-auc:0.875969
# [477]	train-logloss:0.059493	train-auc:0.937515	valid-logloss:0.157048	valid-auc:0.875991
# [478]	train-logloss:0.059439	train-auc:0.937542	valid-logloss:0.156994	valid-auc:0.876042
# [479]	train-logloss:0.059384	train-auc:0.937566	valid-logloss:0.156962	valid-auc:0.876127
# [480]	train-logloss:0.05933	train-auc:0.937597	valid-logloss:0.156921	valid-auc:0.876181
# [481]	train-logloss:0.059276	train-auc:0.937621	valid-logloss:0.156892	valid-auc:0.876208
# [482]	train-logloss:0.059224	train-auc:0.937663	valid-logloss:0.156854	valid-auc:0.87618
# [483]	train-logloss:0.05917	train-auc:0.93768	valid-logloss:0.1568	valid-auc:0.876274
# [484]	train-logloss:0.059117	train-auc:0.937709	valid-logloss:0.156757	valid-auc:0.876327
# [485]	train-logloss:0.059067	train-auc:0.93777	valid-logloss:0.156708	valid-auc:0.876399
# [486]	train-logloss:0.059017	train-auc:0.937804	valid-logloss:0.156685	valid-auc:0.876419
# [487]	train-logloss:0.058961	train-auc:0.937834	valid-logloss:0.156645	valid-auc:0.876388
# [488]	train-logloss:0.058913	train-auc:0.937856	valid-logloss:0.156629	valid-auc:0.876352
# [489]	train-logloss:0.058863	train-auc:0.937885	valid-logloss:0.156587	valid-auc:0.876392
# [490]	train-logloss:0.058811	train-auc:0.937907	valid-logloss:0.156522	valid-auc:0.876568
# [491]	train-logloss:0.058761	train-auc:0.937939	valid-logloss:0.156492	valid-auc:0.876623
# [492]	train-logloss:0.058712	train-auc:0.937963	valid-logloss:0.156453	valid-auc:0.876693
# [493]	train-logloss:0.058662	train-auc:0.937994	valid-logloss:0.156395	valid-auc:0.87679
# [494]	train-logloss:0.058613	train-auc:0.938051	valid-logloss:0.156381	valid-auc:0.876802
# [495]	train-logloss:0.05856	train-auc:0.938085	valid-logloss:0.156332	valid-auc:0.876912
# [496]	train-logloss:0.058512	train-auc:0.938124	valid-logloss:0.15628	valid-auc:0.876974
# [497]	train-logloss:0.058466	train-auc:0.938153	valid-logloss:0.156266	valid-auc:0.876956
# [498]	train-logloss:0.05842	train-auc:0.938169	valid-logloss:0.156242	valid-auc:0.876949
# [499]	train-logloss:0.058375	train-auc:0.93821	valid-logloss:0.156236	valid-auc:0.876951
# [500]	train-logloss:0.058328	train-auc:0.938259	valid-logloss:0.156199	valid-auc:0.876966
# [501]	train-logloss:0.058284	train-auc:0.938297	valid-logloss:0.15615	valid-auc:0.877119
# [502]	train-logloss:0.058235	train-auc:0.93834	valid-logloss:0.156112	valid-auc:0.877114
# [503]	train-logloss:0.058189	train-auc:0.938379	valid-logloss:0.156078	valid-auc:0.877142
# [504]	train-logloss:0.058145	train-auc:0.938403	valid-logloss:0.15604	valid-auc:0.877166
# [505]	train-logloss:0.058101	train-auc:0.938427	valid-logloss:0.155998	valid-auc:0.877205
# [506]	train-logloss:0.058056	train-auc:0.938464	valid-logloss:0.155952	valid-auc:0.877284
# [507]	train-logloss:0.058016	train-auc:0.93851	valid-logloss:0.155946	valid-auc:0.877275
# [508]	train-logloss:0.057976	train-auc:0.938546	valid-logloss:0.155939	valid-auc:0.877235
# [509]	train-logloss:0.057938	train-auc:0.938583	valid-logloss:0.155926	valid-auc:0.877185
# [510]	train-logloss:0.057895	train-auc:0.938605	valid-logloss:0.155914	valid-auc:0.877176
# [511]	train-logloss:0.057855	train-auc:0.938637	valid-logloss:0.155898	valid-auc:0.877126
# [512]	train-logloss:0.057815	train-auc:0.93867	valid-logloss:0.155858	valid-auc:0.877185
# [513]	train-logloss:0.057773	train-auc:0.938704	valid-logloss:0.155828	valid-auc:0.877188
# [514]	train-logloss:0.057732	train-auc:0.93874	valid-logloss:0.155784	valid-auc:0.877215
# [515]	train-logloss:0.057694	train-auc:0.938758	valid-logloss:0.155768	valid-auc:0.877231
# [516]	train-logloss:0.057654	train-auc:0.938792	valid-logloss:0.155748	valid-auc:0.877231
# [517]	train-logloss:0.057616	train-auc:0.938817	valid-logloss:0.155738	valid-auc:0.87724
# [518]	train-logloss:0.057575	train-auc:0.938844	valid-logloss:0.155698	valid-auc:0.877332
# [519]	train-logloss:0.057537	train-auc:0.93886	valid-logloss:0.155685	valid-auc:0.877325
# [520]	train-logloss:0.057499	train-auc:0.938878	valid-logloss:0.155663	valid-auc:0.877351
# [521]	train-logloss:0.057457	train-auc:0.938915	valid-logloss:0.155627	valid-auc:0.877387
# [522]	train-logloss:0.057418	train-auc:0.938951	valid-logloss:0.155594	valid-auc:0.877417
# [523]	train-logloss:0.057378	train-auc:0.938982	valid-logloss:0.155553	valid-auc:0.877419
# [524]	train-logloss:0.05734	train-auc:0.939011	valid-logloss:0.155527	valid-auc:0.877448
# [525]	train-logloss:0.057302	train-auc:0.939041	valid-logloss:0.155501	valid-auc:0.877498
# [526]	train-logloss:0.057262	train-auc:0.939084	valid-logloss:0.155477	valid-auc:0.877511
# [527]	train-logloss:0.057227	train-auc:0.939119	valid-logloss:0.155452	valid-auc:0.877553
# [528]	train-logloss:0.05719	train-auc:0.93914	valid-logloss:0.155425	valid-auc:0.877674
# [529]	train-logloss:0.057157	train-auc:0.939156	valid-logloss:0.155409	valid-auc:0.877687
# [530]	train-logloss:0.057122	train-auc:0.939176	valid-logloss:0.155394	valid-auc:0.877722
# [531]	train-logloss:0.057086	train-auc:0.939208	valid-logloss:0.155373	valid-auc:0.877763
# [532]	train-logloss:0.057047	train-auc:0.939244	valid-logloss:0.155341	valid-auc:0.877798
# [533]	train-logloss:0.05701	train-auc:0.939272	valid-logloss:0.155304	valid-auc:0.877787
# [534]	train-logloss:0.056976	train-auc:0.939307	valid-logloss:0.15528	valid-auc:0.87779
# ...
# [3382]	train-logloss:0.04478	train-auc:0.964047	valid-logloss:0.149439	valid-auc:0.894333
# [3383]	train-logloss:0.04478	train-auc:0.964051	valid-logloss:0.149441	valid-auc:0.894332
# [3384]	train-logloss:0.044777	train-auc:0.964053	valid-logloss:0.149447	valid-auc:0.894312
# [3385]	train-logloss:0.044774	train-auc:0.96406	valid-logloss:0.149449	valid-auc:0.894314
# [3386]	train-logloss:0.044773	train-auc:0.964063	valid-logloss:0.149447	valid-auc:0.894322
# [3387]	train-logloss:0.044771	train-auc:0.964067	valid-logloss:0.149448	valid-auc:0.89432
# [3388]	train-logloss:0.044771	train-auc:0.964072	valid-logloss:0.149464	valid-auc:0.894313
# [3389]	train-logloss:0.04477	train-auc:0.964074	valid-logloss:0.149464	valid-auc:0.894318
# [3390]	train-logloss:0.044768	train-auc:0.964079	valid-logloss:0.149473	valid-auc:0.894306
# [3391]	train-logloss:0.044765	train-auc:0.964081	valid-logloss:0.149471	valid-auc:0.894313
# [3392]	train-logloss:0.044762	train-auc:0.964081	valid-logloss:0.149465	valid-auc:0.894335
# [3393]	train-logloss:0.04476	train-auc:0.964084	valid-logloss:0.149473	valid-auc:0.89432
# [3394]	train-logloss:0.044758	train-auc:0.964088	valid-logloss:0.14948	valid-auc:0.89431
# [3395]	train-logloss:0.044755	train-auc:0.964091	valid-logloss:0.149479	valid-auc:0.894305
# [3396]	train-logloss:0.044752	train-auc:0.964099	valid-logloss:0.149472	valid-auc:0.894323
# [3397]	train-logloss:0.044751	train-auc:0.964103	valid-logloss:0.149465	valid-auc:0.894333
# [3398]	train-logloss:0.044748	train-auc:0.964107	valid-logloss:0.149463	valid-auc:0.894328
# [3399]	train-logloss:0.044746	train-auc:0.964109	valid-logloss:0.149469	valid-auc:0.894314
# [3400]	train-logloss:0.044745	train-auc:0.964111	valid-logloss:0.149465	valid-auc:0.894318
# [3401]	train-logloss:0.044743	train-auc:0.964114	valid-logloss:0.149468	valid-auc:0.894315
# [3402]	train-logloss:0.044743	train-auc:0.964116	valid-logloss:0.149471	valid-auc:0.894316
# [3403]	train-logloss:0.044744	train-auc:0.964118	valid-logloss:0.149473	valid-auc:0.894316
# [3404]	train-logloss:0.044745	train-auc:0.964122	valid-logloss:0.14948	valid-auc:0.894319
# [3405]	train-logloss:0.044743	train-auc:0.964125	valid-logloss:0.149476	valid-auc:0.894323
# [3406]	train-logloss:0.044742	train-auc:0.964128	valid-logloss:0.149477	valid-auc:0.894322
# [3407]	train-logloss:0.04474	train-auc:0.964131	valid-logloss:0.14947	valid-auc:0.894333
# [3408]	train-logloss:0.044737	train-auc:0.964134	valid-logloss:0.149463	valid-auc:0.894336
# [3409]	train-logloss:0.044735	train-auc:0.96414	valid-logloss:0.149466	valid-auc:0.894333
# [3410]	train-logloss:0.044731	train-auc:0.964145	valid-logloss:0.149461	valid-auc:0.894348
# [3411]	train-logloss:0.044729	train-auc:0.964151	valid-logloss:0.149467	valid-auc:0.894339
# [3412]	train-logloss:0.044729	train-auc:0.964153	valid-logloss:0.149457	valid-auc:0.894351
# [3413]	train-logloss:0.044727	train-auc:0.964157	valid-logloss:0.149461	valid-auc:0.894354
# [3414]	train-logloss:0.044725	train-auc:0.964166	valid-logloss:0.149462	valid-auc:0.89436
# [3415]	train-logloss:0.044724	train-auc:0.964169	valid-logloss:0.149465	valid-auc:0.894357
# [3416]	train-logloss:0.044724	train-auc:0.964171	valid-logloss:0.149464	valid-auc:0.89436
# [3417]	train-logloss:0.044723	train-auc:0.964173	valid-logloss:0.149465	valid-auc:0.894361
# [3418]	train-logloss:0.044722	train-auc:0.964175	valid-logloss:0.149464	valid-auc:0.894361
# [3419]	train-logloss:0.044721	train-auc:0.964178	valid-logloss:0.149465	valid-auc:0.89436
# [3420]	train-logloss:0.04472	train-auc:0.964189	valid-logloss:0.149469	valid-auc:0.894357
# [3421]	train-logloss:0.044718	train-auc:0.964195	valid-logloss:0.14947	valid-auc:0.894358
# [3422]	train-logloss:0.044716	train-auc:0.9642	valid-logloss:0.149459	valid-auc:0.894364
# [3423]	train-logloss:0.044714	train-auc:0.964206	valid-logloss:0.149464	valid-auc:0.894357
# [3424]	train-logloss:0.044713	train-auc:0.964209	valid-logloss:0.149467	valid-auc:0.894357
# [3425]	train-logloss:0.04471	train-auc:0.964215	valid-logloss:0.149467	valid-auc:0.894361
# [3426]	train-logloss:0.044706	train-auc:0.96422	valid-logloss:0.149461	valid-auc:0.894391
# [3427]	train-logloss:0.044705	train-auc:0.964225	valid-logloss:0.149461	valid-auc:0.89439
# [3428]	train-logloss:0.044703	train-auc:0.964228	valid-logloss:0.149465	valid-auc:0.89439
# [3429]	train-logloss:0.044702	train-auc:0.964232	valid-logloss:0.149472	valid-auc:0.894385
# [3430]	train-logloss:0.044698	train-auc:0.964235	valid-logloss:0.149477	valid-auc:0.894387
# [3431]	train-logloss:0.044695	train-auc:0.964236	valid-logloss:0.149472	valid-auc:0.894386
# [3432]	train-logloss:0.044693	train-auc:0.96424	valid-logloss:0.149472	valid-auc:0.894389
# [3433]	train-logloss:0.044691	train-auc:0.964245	valid-logloss:0.149473	valid-auc:0.894397
# [3434]	train-logloss:0.044689	train-auc:0.964249	valid-logloss:0.149478	valid-auc:0.894385
# [3435]	train-logloss:0.044687	train-auc:0.964252	valid-logloss:0.14948	valid-auc:0.894376
# [3436]	train-logloss:0.044683	train-auc:0.964256	valid-logloss:0.149481	valid-auc:0.894359
# [3437]	train-logloss:0.044684	train-auc:0.964258	valid-logloss:0.149484	valid-auc:0.89436
# [3438]	train-logloss:0.044682	train-auc:0.964264	valid-logloss:0.149477	valid-auc:0.894364
# [3439]	train-logloss:0.04468	train-auc:0.964267	valid-logloss:0.149479	valid-auc:0.894362
# [3440]	train-logloss:0.044679	train-auc:0.964269	valid-logloss:0.149483	valid-auc:0.894365
# [3441]	train-logloss:0.044679	train-auc:0.96427	valid-logloss:0.149484	valid-auc:0.894363
# [3442]	train-logloss:0.044678	train-auc:0.964273	valid-logloss:0.149484	valid-auc:0.894361
# [3443]	train-logloss:0.044677	train-auc:0.964275	valid-logloss:0.149485	valid-auc:0.894361
# [3444]	train-logloss:0.044676	train-auc:0.964282	valid-logloss:0.149493	valid-auc:0.894357
# [3445]	train-logloss:0.044673	train-auc:0.964286	valid-logloss:0.14949	valid-auc:0.894346
# [3446]	train-logloss:0.044671	train-auc:0.96429	valid-logloss:0.149497	valid-auc:0.894345
# [3447]	train-logloss:0.044669	train-auc:0.964293	valid-logloss:0.149505	valid-auc:0.894332
# [3448]	train-logloss:0.044669	train-auc:0.964296	valid-logloss:0.149506	valid-auc:0.894333
# [3449]	train-logloss:0.044668	train-auc:0.964298	valid-logloss:0.149508	valid-auc:0.894336
# [3450]	train-logloss:0.044666	train-auc:0.964301	valid-logloss:0.149509	valid-auc:0.894333
# [3451]	train-logloss:0.044663	train-auc:0.964303	valid-logloss:0.149519	valid-auc:0.894311
# [3452]	train-logloss:0.04466	train-auc:0.964305	valid-logloss:0.149516	valid-auc:0.894315
# [3453]	train-logloss:0.044659	train-auc:0.964309	valid-logloss:0.149512	valid-auc:0.894305
# [3454]	train-logloss:0.044658	train-auc:0.964317	valid-logloss:0.149511	valid-auc:0.894317
# [3455]	train-logloss:0.044656	train-auc:0.96432	valid-logloss:0.14952	valid-auc:0.894299
# [3456]	train-logloss:0.044654	train-auc:0.964323	valid-logloss:0.149516	valid-auc:0.8943
# [3457]	train-logloss:0.044654	train-auc:0.964327	valid-logloss:0.149515	valid-auc:0.894305
# [3458]	train-logloss:0.044651	train-auc:0.964333	valid-logloss:0.149512	valid-auc:0.894316
# [3459]	train-logloss:0.044646	train-auc:0.964338	valid-logloss:0.149503	valid-auc:0.894314
# [3460]	train-logloss:0.044647	train-auc:0.964339	valid-logloss:0.149501	valid-auc:0.894332
# [3461]	train-logloss:0.044646	train-auc:0.964344	valid-logloss:0.149507	valid-auc:0.894329
# [3462]	train-logloss:0.044643	train-auc:0.964349	valid-logloss:0.149503	valid-auc:0.894329
# [3463]	train-logloss:0.044641	train-auc:0.964352	valid-logloss:0.149506	valid-auc:0.894321
# [3464]	train-logloss:0.044639	train-auc:0.964355	valid-logloss:0.149505	valid-auc:0.894327
# [3465]	train-logloss:0.044637	train-auc:0.964358	valid-logloss:0.149499	valid-auc:0.894333
# [3466]	train-logloss:0.044636	train-auc:0.964362	valid-logloss:0.149507	valid-auc:0.894337
# [3467]	train-logloss:0.044633	train-auc:0.964367	valid-logloss:0.149506	valid-auc:0.894374
# [3468]	train-logloss:0.044631	train-auc:0.96437	valid-logloss:0.1495	valid-auc:0.894374
# [3469]	train-logloss:0.044629	train-auc:0.964377	valid-logloss:0.14951	valid-auc:0.894364
# [3470]	train-logloss:0.044627	train-auc:0.964381	valid-logloss:0.149527	valid-auc:0.894344
# [3471]	train-logloss:0.044628	train-auc:0.964382	valid-logloss:0.149523	valid-auc:0.894348
# [3472]	train-logloss:0.044625	train-auc:0.964387	valid-logloss:0.149526	valid-auc:0.894347
# [3473]	train-logloss:0.044622	train-auc:0.96439	valid-logloss:0.149515	valid-auc:0.894344
# [3474]	train-logloss:0.044621	train-auc:0.964395	valid-logloss:0.149506	valid-auc:0.894346
# [3475]	train-logloss:0.044619	train-auc:0.964398	valid-logloss:0.149512	valid-auc:0.894342
# [3476]	train-logloss:0.044616	train-auc:0.964401	valid-logloss:0.149501	valid-auc:0.894393
# [3477]	train-logloss:0.044614	train-auc:0.964406	valid-logloss:0.149502	valid-auc:0.8944
# [3478]	train-logloss:0.044612	train-auc:0.964411	valid-logloss:0.149504	valid-auc:0.894394
# [3479]	train-logloss:0.044611	train-auc:0.964416	valid-logloss:0.149505	valid-auc:0.894395
# [3480]	train-logloss:0.04461	train-auc:0.96442	valid-logloss:0.1495	valid-auc:0.894417
# [3481]	train-logloss:0.044608	train-auc:0.964425	valid-logloss:0.149502	valid-auc:0.894427
# [3482]	train-logloss:0.044606	train-auc:0.964428	valid-logloss:0.149499	valid-auc:0.894436
# [3483]	train-logloss:0.044603	train-auc:0.964432	valid-logloss:0.149489	valid-auc:0.894442
# [3484]	train-logloss:0.044602	train-auc:0.964437	valid-logloss:0.149483	valid-auc:0.894452
# [3485]	train-logloss:0.0446	train-auc:0.964439	valid-logloss:0.149485	valid-auc:0.894458
# [3486]	train-logloss:0.044598	train-auc:0.964442	valid-logloss:0.14948	valid-auc:0.894467
# [3487]	train-logloss:0.044596	train-auc:0.964443	valid-logloss:0.14948	valid-auc:0.894461
# [3488]	train-logloss:0.044594	train-auc:0.964451	valid-logloss:0.149477	valid-auc:0.894475
# [3489]	train-logloss:0.044591	train-auc:0.964453	valid-logloss:0.149481	valid-auc:0.894474
# [3490]	train-logloss:0.044589	train-auc:0.964456	valid-logloss:0.149479	valid-auc:0.894473
# [3491]	train-logloss:0.044587	train-auc:0.96446	valid-logloss:0.149485	valid-auc:0.894466
# [3492]	train-logloss:0.044584	train-auc:0.964467	valid-logloss:0.149488	valid-auc:0.894455
# [3493]	train-logloss:0.044582	train-auc:0.964471	valid-logloss:0.149496	valid-auc:0.894444
# [3494]	train-logloss:0.04458	train-auc:0.964474	valid-logloss:0.149485	valid-auc:0.894452
# [3495]	train-logloss:0.044578	train-auc:0.964475	valid-logloss:0.149489	valid-auc:0.894446
# [3496]	train-logloss:0.044576	train-auc:0.964479	valid-logloss:0.149487	valid-auc:0.894445
# [3497]	train-logloss:0.044576	train-auc:0.964481	valid-logloss:0.149487	valid-auc:0.894448
# [3498]	train-logloss:0.044575	train-auc:0.964483	valid-logloss:0.149481	valid-auc:0.894451
# [3499]	train-logloss:0.044572	train-auc:0.964485	valid-logloss:0.149477	valid-auc:0.894445
# [3500]	train-logloss:0.044571	train-auc:0.964489	valid-logloss:0.149478	valid-auc:0.894435
# [3501]	train-logloss:0.04457	train-auc:0.964493	valid-logloss:0.149476	valid-auc:0.894452
# [3502]	train-logloss:0.044568	train-auc:0.964499	valid-logloss:0.149475	valid-auc:0.894457
# [3503]	train-logloss:0.044566	train-auc:0.964502	valid-logloss:0.149478	valid-auc:0.894452
# [3504]	train-logloss:0.044566	train-auc:0.964505	valid-logloss:0.149486	valid-auc:0.894441
# [3505]	train-logloss:0.044566	train-auc:0.964507	valid-logloss:0.14949	valid-auc:0.894441
# [3506]	train-logloss:0.044563	train-auc:0.96451	valid-logloss:0.149488	valid-auc:0.894448
# [3507]	train-logloss:0.04456	train-auc:0.964513	valid-logloss:0.149496	valid-auc:0.894434
# [3508]	train-logloss:0.044558	train-auc:0.964516	valid-logloss:0.1495	valid-auc:0.894427
# [3509]	train-logloss:0.044558	train-auc:0.964521	valid-logloss:0.149503	valid-auc:0.89442
# [3510]	train-logloss:0.044556	train-auc:0.964525	valid-logloss:0.1495	valid-auc:0.894433
# [3511]	train-logloss:0.044551	train-auc:0.964532	valid-logloss:0.149501	valid-auc:0.894428
# [3512]	train-logloss:0.044551	train-auc:0.964535	valid-logloss:0.149494	valid-auc:0.894426
# [3513]	train-logloss:0.044547	train-auc:0.964538	valid-logloss:0.149497	valid-auc:0.894438
# [3514]	train-logloss:0.044548	train-auc:0.964538	valid-logloss:0.149501	valid-auc:0.894439
# [3515]	train-logloss:0.044548	train-auc:0.96454	valid-logloss:0.149505	valid-auc:0.894439
# [3516]	train-logloss:0.044545	train-auc:0.964543	valid-logloss:0.149502	valid-auc:0.894433
# [3517]	train-logloss:0.044544	train-auc:0.964549	valid-logloss:0.149498	valid-auc:0.894432
# [3518]	train-logloss:0.044544	train-auc:0.964551	valid-logloss:0.149503	valid-auc:0.894436
# [3519]	train-logloss:0.04454	train-auc:0.964557	valid-logloss:0.149506	valid-auc:0.894431
# [3520]	train-logloss:0.044538	train-auc:0.964561	valid-logloss:0.149497	valid-auc:0.894444
# [3521]	train-logloss:0.044536	train-auc:0.964563	valid-logloss:0.149494	valid-auc:0.894443
# [3522]	train-logloss:0.044533	train-auc:0.964567	valid-logloss:0.149496	valid-auc:0.894439
# [3523]	train-logloss:0.044531	train-auc:0.964567	valid-logloss:0.149496	valid-auc:0.894444
# [3524]	train-logloss:0.044529	train-auc:0.96457	valid-logloss:0.149495	valid-auc:0.894443
# [3525]	train-logloss:0.044528	train-auc:0.964574	valid-logloss:0.149501	valid-auc:0.894434
# [3526]	train-logloss:0.044526	train-auc:0.964576	valid-logloss:0.149499	valid-auc:0.894438
# [3527]	train-logloss:0.044524	train-auc:0.964581	valid-logloss:0.149489	valid-auc:0.894449
# [3528]	train-logloss:0.044522	train-auc:0.964585	valid-logloss:0.149485	valid-auc:0.894445
# [3529]	train-logloss:0.04452	train-auc:0.964588	valid-logloss:0.149484	valid-auc:0.894445
# [3530]	train-logloss:0.044518	train-auc:0.964593	valid-logloss:0.149485	valid-auc:0.894442
# [3531]	train-logloss:0.044516	train-auc:0.964598	valid-logloss:0.149484	valid-auc:0.894444
# [3532]	train-logloss:0.044514	train-auc:0.964606	valid-logloss:0.149485	valid-auc:0.894441
# [3533]	train-logloss:0.044511	train-auc:0.96461	valid-logloss:0.149486	valid-auc:0.894439
# [3534]	train-logloss:0.04451	train-auc:0.964614	valid-logloss:0.149487	valid-auc:0.894434
# [3535]	train-logloss:0.044509	train-auc:0.964619	valid-logloss:0.149482	valid-auc:0.894445
# [3536]	train-logloss:0.044508	train-auc:0.964624	valid-logloss:0.149476	valid-auc:0.894445
# [3537]	train-logloss:0.044506	train-auc:0.964627	valid-logloss:0.149479	valid-auc:0.894438
# [3538]	train-logloss:0.044503	train-auc:0.964633	valid-logloss:0.149478	valid-auc:0.894447
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7a2ba5e1781c> in <module>()
#      21                 evallist,
#      22                 # feval=my_score3,
# ---> 23                 early_stopping_rounds=early_stopping_rounds)
#      24 # # save the model
#      25 # bst.save_model('model_log/single_1/0001.model')
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost-0.72-py3.6.egg\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     202                            evals=evals,
#     203                            obj=obj, feval=feval,
# --> 204                            xgb_model=xgb_model, callbacks=callbacks)
#     205
#     206
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost-0.72-py3.6.egg\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost-0.72-py3.6.egg\xgboost\core.py in update(self, dtrain, iteration, fobj)
#     895         if fobj is None:
#     896             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# --> 897                                                     dtrain.handle))
#     898         else:
#     899             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
learning_rate = 0.1
num_leaves = 15
min_data_in_leaf = 200
feature_fraction = 0.6
num_boost_round = 10000
params = {"objective": "binary",
          "boosting_type": "gbdt",
          "learning_rate": learning_rate,
          "num_leaves": num_leaves,
          "max_bin": 256,
          "feature_fraction": feature_fraction,
          "verbosity": 0,
          "drop_rate": 0.1,
          "is_unbalance": False,
          "max_drop": 50,
          "min_child_samples": 10,
          "min_child_weight": 150,
          "min_split_gain": 0,
          "subsample": 0.9,
          #"metric": 'auc'
          }
for i in range(0,9,2):
    params['seed'] = i
    day_target = list(set([tmp+1 for tmp in range(31)])-\
                      set([10*tmp+i+1 if 10*tmp+i+1<=31 else 10*tmp+i-9 for tmp in range(4)]+\
                          [10*tmp+i+2 if 10*tmp+i+2<=31 else 10*tmp+i-8 for tmp in range(4)]))
    # print(day_target)
    train = data[data.Day.isin(day_target)]
    
    dtrain = lgbm.Dataset(train.drop(['id','date','label','Day','cate'],axis=1).values, train.label.values)
    dvalid = lgbm.Dataset(valid.drop(['id','date','label','Day','cate'],axis=1).values, valid.label.values, reference=dtrain)
    bst = lgbm.train(params, dtrain, num_boost_round, valid_sets=dvalid,\
                     feval=my_score2,\
                     verbose_eval=100,
                     early_stopping_rounds=100)
    # make the predictions
#     cv_pred += bst.predict(test.drop(['id','date','Day'],axis=1).values, num_iteration=bst.best_iteration)
    valid_pred += bst.predict(valid.drop(['id','date','label','Day'],axis=1).values, num_iteration=bst.best_iteration)

valid_pred /= 5    
# cv_pred /= 5

print('Final score of validation is {}'.format(my_score1(valid.label.values, valid_pred)))

# pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0009.csv', index=False)
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.110506	valid_0's score: 0.215695
# [200]	valid_0's binary_logloss: 0.107953	valid_0's score: 0.246487
# [300]	valid_0's binary_logloss: 0.10763	valid_0's score: 0.245516
# Early stopping, best iteration is:
# [227]	valid_0's binary_logloss: 0.107736	valid_0's score: 0.250822
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.110789	valid_0's score: 0.213602
# [200]	valid_0's binary_logloss: 0.109406	valid_0's score: 0.217638
# [300]	valid_0's binary_logloss: 0.108724	valid_0's score: 0.222123
# [400]	valid_0's binary_logloss: 0.108285	valid_0's score: 0.223842
# [500]	valid_0's binary_logloss: 0.108128	valid_0's score: 0.221898
# Early stopping, best iteration is:
# [450]	valid_0's binary_logloss: 0.108121	valid_0's score: 0.22728
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.110635	valid_0's score: 0.201644
# [200]	valid_0's binary_logloss: 0.108428	valid_0's score: 0.2142
# [300]	valid_0's binary_logloss: 0.107649	valid_0's score: 0.222123
# [400]	valid_0's binary_logloss: 0.107349	valid_0's score: 0.231166
# [500]	valid_0's binary_logloss: 0.106991	valid_0's score: 0.228475
# Early stopping, best iteration is:
# [475]	valid_0's binary_logloss: 0.10701	valid_0's score: 0.236323
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.11016	valid_0's score: 0.215994
# [200]	valid_0's binary_logloss: 0.107838	valid_0's score: 0.232287
# [300]	valid_0's binary_logloss: 0.107008	valid_0's score: 0.238341
# [400]	valid_0's binary_logloss: 0.106607	valid_0's score: 0.241256
# [500]	valid_0's binary_logloss: 0.106531	valid_0's score: 0.237743
# Early stopping, best iteration is:
# [430]	valid_0's binary_logloss: 0.106559	valid_0's score: 0.243498
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.111316	valid_0's score: 0.210837
# [200]	valid_0's binary_logloss: 0.109605	valid_0's score: 0.218984
# [300]	valid_0's binary_logloss: 0.108807	valid_0's score: 0.221076
# Early stopping, best iteration is:
# [225]	valid_0's binary_logloss: 0.109213	valid_0's score: 0.224963
# Final score of validation is 0.06180866965620329

# %%
valid_pred_df = pd.DataFrame({'id': valid.id, 'score': valid_pred, 'label':  valid.label})
valid_pred_df = valid_pred_df.merge(train_cate, how='inner', on='id')
valid_pred_df.head()
# Out:
#                                                   id     score  label  cate
# 0  e8c3a7fbd718708534a436d217a76c86ac2e0683b65ae1...  0.000091      0     7
# 1  d89c7b05241c510b3b24371fccd7be3667099f89f4a2ec...  0.755644      1     7
# 2  eb9115c595b131a80f9fc50676382f72badb8c26aa2584...  0.000325      0     7
# 3  eef20507bbf041f0231f053f3161061bcec68dae1d7ed0...  0.000518      0     7
# 4  2c3976f164024e349127ba8d5a84e48dc109ec7299d6ea...  0.360241      0     7

# %%
percent = valid_pred_df.label.values.sum()/valid_pred_df.shape[0]

threshold = valid_pred_df.score.quantile(1-percent)
valid_pred_df['pred_label'] = valid_pred_df.score.apply(lambda x: int(x>threshold))
valid_pred_df['isCorrect'] = valid_pred_df['label']==valid_pred_df['pred_label']
valid_pred_df['isCorrect'] = valid_pred_df['isCorrect'].astype('int')
valid_pred_df.head()
# Out:
#                                                   id     score  label  cate  \
# 0  e8c3a7fbd718708534a436d217a76c86ac2e0683b65ae1...  0.000091      0     7
# 1  d89c7b05241c510b3b24371fccd7be3667099f89f4a2ec...  0.755644      1     7
# 2  eb9115c595b131a80f9fc50676382f72badb8c26aa2584...  0.000325      0     7
# 3  eef20507bbf041f0231f053f3161061bcec68dae1d7ed0...  0.000518      0     7
# 4  2c3976f164024e349127ba8d5a84e48dc109ec7299d6ea...  0.360241      0     7
#
#    pred_label  isCorrect
# 0           0          1
# 1           0          0
# 2           0          1
# 3           0          1
# 4           0          1

# %%
# use training data with cate==7 
print('Incorrect predictions: {}'.format(valid_pred_df[valid_pred_df['isCorrect']==0].shape[0]))
print('Total predictions: {}'.format(valid_pred_df.shape[0]))
print('False negatives: {}'.format(valid_pred_df[valid_pred_df['label']==1][valid_pred_df['isCorrect']==0].shape[0]))
print('Total positives: {}'.format(valid_pred_df[valid_pred_df['label']==1].shape[0]))
# Out:
# Incorrect predictions: 1374
# Total predictions: 24768
# False negatives: 687
# Total positives: 1415
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# use all training data
print('Incorrect predictions: {}'.format(valid_pred_df[valid_pred_df['isCorrect']==0].shape[0]))
print('Total predictions: {}'.format(valid_pred_df.shape[0]))
print('False negatives: {}'.format(valid_pred_df[valid_pred_df['label']==1][valid_pred_df['isCorrect']==0].shape[0]))
print('Total positives: {}'.format(valid_pred_df[valid_pred_df['label']==1].shape[0]))

# %% [markdown]
# ### Add weights to training data

# %%
train_cate = pd.read_csv("obj/id_cate_train.csv")
data = data.merge(train_cate, how='inner', on='id')
data['weight'] = data.cate.apply(lambda x: 2 if x==2 or x==7 else 1)

# %%
# use the last 20% data as validation set
valid = data.iloc[data.shape[0]*4//5:,:]
data = data.iloc[:data.shape[0]*4//5,:]

# weight_valid = valid.weight
# weight_data = data.weight

# %%
test_id = test.id
cv_pred = np.zeros(len(test_id))

valid_pred = np.zeros(valid.shape[0])
#valid_id = valid.id

# %%
learning_rate = 0.1
num_leaves = 15
min_data_in_leaf = 2000
feature_fraction = 0.6
num_boost_round = 10000
params = {"objective": "binary",
          "boosting_type": "gbdt",
          "learning_rate": learning_rate,
          "num_leaves": num_leaves,
          "max_bin": 256,
          "feature_fraction": feature_fraction,
          "verbosity": 0,
          "drop_rate": 0.1,
          "is_unbalance": False,
          "max_drop": 50,
          "min_child_samples": 10,
          "min_child_weight": 150,
          "min_split_gain": 0,
          "subsample": 0.8,
          #"metric": 'auc'
          }
for i in range(0,9,2):
    params['seed'] = i
    day_target = list(set([tmp+1 for tmp in range(31)])-\
                      set([10*tmp+i+1 if 10*tmp+i+1<=31 else 10*tmp+i-9 for tmp in range(4)]+\
                          [10*tmp+i+2 if 10*tmp+i+2<=31 else 10*tmp+i-8 for tmp in range(4)]))
    # print(day_target)
    train = data[data.Day.isin(day_target)]
    
    dtrain = lgbm.Dataset(train.drop(['id','date','label','Day','weight'],axis=1).values,\
                          train.label.values, weight=train.weight.values)
    dvalid = lgbm.Dataset(valid.drop(['id','date','label','Day','weight'],axis=1).values,\
                          valid.label.values, reference=dtrain, weight=valid.weight.values)
    bst = lgbm.train(params, dtrain, num_boost_round, valid_sets=dvalid,\
                     feval=my_score2,\
                     verbose_eval=100,
                     early_stopping_rounds=300)
    # make the predictions
    cv_pred += bst.predict(test.drop(['id','date','Day'],axis=1).values, num_iteration=bst.best_iteration)
    valid_pred += bst.predict(valid.drop(['id','date','label','Day'],axis=1).values, num_iteration=bst.best_iteration)

valid_pred /= 5    
cv_pred /= 5

print('Final score of validation is {}'.format(my_score1(valid.label.values, valid_pred)))

pd.DataFrame({'id': test_id, 'score': cv_pred}).to_csv('submission/test_b/0013.csv', index=False)
# Out:
# Training until validation scores don't improve for 300 rounds.
# [100]	valid_0's binary_logloss: 0.0468065	valid_0's score: 0.412607
# [200]	valid_0's binary_logloss: 0.0460782	valid_0's score: 0.414193
# [300]	valid_0's binary_logloss: 0.0460244	valid_0's score: 0.40861
# [400]	valid_0's binary_logloss: 0.0461325	valid_0's score: 0.405995
# [500]	valid_0's binary_logloss: 0.0461557	valid_0's score: 0.404819
# Early stopping, best iteration is:
# [225]	valid_0's binary_logloss: 0.0460397	valid_0's score: 0.415604
# Training until validation scores don't improve for 300 rounds.
# [100]	valid_0's binary_logloss: 0.0472591	valid_0's score: 0.395093
# [200]	valid_0's binary_logloss: 0.0464122	valid_0's score: 0.397825
# [300]	valid_0's binary_logloss: 0.0465003	valid_0's score: 0.402028
# [400]	valid_0's binary_logloss: 0.046374	valid_0's score: 0.401704
# [500]	valid_0's binary_logloss: 0.0464695	valid_0's score: 0.399824
# Early stopping, best iteration is:
# [296]	valid_0's binary_logloss: 0.0465018	valid_0's score: 0.402468
# Training until validation scores don't improve for 300 rounds.
# [100]	valid_0's binary_logloss: 0.0465757	valid_0's score: 0.409021
# [200]	valid_0's binary_logloss: 0.0459725	valid_0's score: 0.407728
# [300]	valid_0's binary_logloss: 0.0459189	valid_0's score: 0.404819
# [400]	valid_0's binary_logloss: 0.0458705	valid_0's score: 0.40385
# Early stopping, best iteration is:
# [122]	valid_0's binary_logloss: 0.0462979	valid_0's score: 0.41293
# Training until validation scores don't improve for 300 rounds.
# [100]	valid_0's binary_logloss: 0.0471312	valid_0's score: 0.402733
# [200]	valid_0's binary_logloss: 0.0463374	valid_0's score: 0.405231
# [300]	valid_0's binary_logloss: 0.0461567	valid_0's score: 0.404349
# [400]	valid_0's binary_logloss: 0.0460691	valid_0's score: 0.404731
# [500]	valid_0's binary_logloss: 0.0460908	valid_0's score: 0.402028
# Early stopping, best iteration is:
# [244]	valid_0's binary_logloss: 0.0462074	valid_0's score: 0.40911
# Training until validation scores don't improve for 300 rounds.
# [100]	valid_0's binary_logloss: 0.0468224	valid_0's score: 0.414458
# [200]	valid_0's binary_logloss: 0.0463125	valid_0's score: 0.406729
# [300]	valid_0's binary_logloss: 0.0461248	valid_0's score: 0.408404
# [400]	valid_0's binary_logloss: 0.0460983	valid_0's score: 0.408551
# Early stopping, best iteration is:
# [105]	valid_0's binary_logloss: 0.0466756	valid_0's score: 0.415486
# Final score of validation is 0.41542756391419333
